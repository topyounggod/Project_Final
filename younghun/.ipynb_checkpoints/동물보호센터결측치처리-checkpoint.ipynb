# %%
import pandas as pd
df = pd.read_csv('./data/동물보호센터(euc-kr).csv',encoding = 'euc-kr')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# 관할구역            0
# 보호센터명           0
# 전화번호            0
# 보호센터주소          0
# 위도              6
# 경도              6
# dtype: int64

# %%
df.dropna()
# Out:
#      Unnamed: 0  Unnamed: 0.1       관할구역       보호센터명          전화번호  \
# 0             0             0  대구광역시 수성구   (사)대구수의사회  053-764-3708
# 1             1             1   대구광역시 중구  (사)대구시수의사회  053-764-3708
# 2             2             2  부산광역시 사하구    (사)하얀비둘기  051-293-9779
# 3             3             3  대구광역시 달성군     119동물병원  053-585-1195
# 4             4             4  서울특별시 용산구    21세기동물병원   02-749-6750
# ..          ...           ...        ...         ...           ...
# 300         300           300    강원도 홍천군  홍천군유기동물보호소  033-434-9435
# 301         301           301   전라남도 화순군  화순군유기동물보호소   ***********
# 302         302           302  대구광역시 달성군    화원연합동물병원  053-634-7975
# 303         303           303    강원도 화천군   화천군농업기술센터  033-440-2941
# 304         304           304    강원도 횡성군  횡성유기동물보호센터  033-731-1119
#
#                                                 보호센터주소         위도          경도
# 0                            대구광역시 북구 호국로 229 (서변동) 6층  35.922346  128.599039
# 1                  대구광역시 북구 호국로 229 (서변동) 대구경북수의사회관 6층  35.922346  128.599039
# 2                              부산광역시 강서구 제도로 726 (강동동)  41.762959  -76.888423
# 3    대구광역시 달성군 다사읍 달구벌대로 893 (다사읍, 대실요양병원 장례식장) 다사읍 관할  33.247592 -111.623181
# 4                                  서울특별시 용산구 보광동 259-1  37.193098  127.073340
# ..                                                 ...        ...         ...
# 300             강원도 홍천군 화촌면 둔덕이길 68 (화촌면, 홍천군유기동물보호센터)  37.489854  127.988566
# 301                         전라남도 화순군 한천면 덕음로 115 (한천면)  35.222450  126.881667
# 302                대구광역시 달성군 화원읍 사문진로 447 (화원읍) 화원읍 관할  35.803697  128.497458
# 303                   강원도 화천군 상서면 영서로 6387-9 화천군농업기술센터  38.114479  127.702742
# 304                        강원도 원주시 호저면 칠봉로 110-6 (호저면)  37.489854  127.988566
#
# [299 rows x 8 columns]

# %%
df['type'] = '동물보호센터'

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1       관할구역       보호센터명          전화번호  \
# 0             0             0  대구광역시 수성구   (사)대구수의사회  053-764-3708
# 1             1             1   대구광역시 중구  (사)대구시수의사회  053-764-3708
# 2             2             2  부산광역시 사하구    (사)하얀비둘기  051-293-9779
# 3             3             3  대구광역시 달성군     119동물병원  053-585-1195
# 4             4             4  서울특별시 용산구    21세기동물병원   02-749-6750
# ..          ...           ...        ...         ...           ...
# 300         300           300    강원도 홍천군  홍천군유기동물보호소  033-434-9435
# 301         301           301   전라남도 화순군  화순군유기동물보호소   ***********
# 302         302           302  대구광역시 달성군    화원연합동물병원  053-634-7975
# 303         303           303    강원도 화천군   화천군농업기술센터  033-440-2941
rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# name       0
# lat        6
# lng        6
# address    0
# type       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name       0
# lat        0
# lng        0
# address    0
# type       0
# dtype: int64

# %%
df.to_csv('동물보호센터(utf-8)최종_영훈.csv',encoding='utf-8')

# %%
df
# Out:
#            name        lat         lng  \
# 0     (사)대구수의사회  35.922346  128.599039
# 1    (사)대구시수의사회  35.922346  128.599039
# 2      (사)하얀비둘기  41.762959  -76.888423
# 3       119동물병원  33.247592 -111.623181
# 4      21세기동물병원  37.193098  127.073340
# ..          ...        ...         ...
# 300  홍천군유기동물보호소  37.489854  127.988566
# 301  화순군유기동물보호소  35.222450  126.881667
# 302    화원연합동물병원  35.803697  128.497458
# 303   화천군농업기술센터  38.114479  127.702742
# 304  횡성유기동물보호센터  37.489854  127.988566
#
#                                                address    type
# 0                            대구광역시 북구 호국로 229 (서변동) 6층  동물보호센터
# 1                  대구광역시 북구 호국로 229 (서변동) 대구경북수의사회관 6층  동물보호센터
# 2                              부산광역시 강서구 제도로 726 (강동동)  동물보호센터
# 3    대구광역시 달성군 다사읍 달구벌대로 893 (다사읍, 대실요양병원 장례식장) 다사읍 관할  동물보호센터
# 4                                  서울특별시 용산구 보광동 259-1  동물보호센터
# ..                                                 ...     ...
# 300             강원도 홍천군 화촌면 둔덕이길 68 (화촌면, 홍천군유기동물보호센터)  동물보호센터
# 301                         전라남도 화순군 한천면 덕음로 115 (한천면)  동물보호센터
# 302                대구광역시 달성군 화원읍 사문진로 447 (화원읍) 화원읍 관할  동물보호센터
# 303                   강원도 화천군 상서면 영서로 6387-9 화천군농업기술센터  동물보호센터
# 304                        강원도 원주시 호저면 칠봉로 110-6 (호저면)  동물보호센터
#
# [299 rows x 5 columns]

# %%
len(df)
# Out:
# 299

# %%
import geojson
from geojson import Point, Feature, FeatureCollection, dump

# %%
features = []
for i in range(0,len(df)): 
    #print(coordinate_df.loc[i])
    #print(coordinate_df.loc[i]['위도'])
    #print(coordinate_df.loc[i]['경도'])
    point = Point((df.loc[i]['lng'],df.loc[i]['lat']))
    features.append(Feature(geometry=point, properties={"name": df.loc[i]['name'],"address":df.loc[i]['address'],"type":df.loc[i]['type']}))

with open('동물보호센터.txt', 'w') as f:
    for item in features:
        f.write("%s\n" % item)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 89
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-d0b4781123c6> in <module>
#       4     #print(coordinate_df.loc[i]['위도'])
#       5     #print(coordinate_df.loc[i]['경도'])
# ----> 6     point = Point((df.loc[i]['lng'],df.loc[i]['lat']))
#       7     features.append(Feature(geometry=point, properties={"name": df.loc[i]['name'],"address":df.loc[i]['address'],"type":df.loc[i]['type']}))
#       8
#
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# D:\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 89
