# %%
import pandas as pd
import numpy as np

animal_deliver = pd.read_csv('./data/동물운송업최최종(utf-8).csv',encoding = 'utf-8')

# %%
animal_deliver
# Out:
#      Unnamed: 0          구분          업체명          전화번호                   소재지  \
# 0             0          운송       공병호펫택시   ***********        서울특별시 종로구 명륜3가
# 1             1          운송   GECOS(개코스)   ***********         서울특별시 종로구 평창동
# 2             2          운송          멍이요   ***********          서울특별시 중구 중림동
# 3             3          운송        엔젤펫택시     1577-0423          서울특별시 중구 신당동
# 4             4          운송           엔젤             -          서울특별시 중구 신당동
# ..          ...         ...          ...           ...                   ...
# 806         806          운송        제주펫스쿨             -  제주특별자치도 서귀포시 대정읍 신도리
# 807         807  위탁관리 미용 운송     주식회사애니멀고   ***********  제주특별자치도 서귀포시 안덕면 서광리
# 808         808     위탁관리 운송          펫소풍  064-792-4877  제주특별자치도 서귀포시 안덕면 서광리
# 809         809          운송  제주애견카페왈 사계점   ***********  제주특별자치도 서귀포시 안덕면 사계리
# 810         810  위탁관리 미용 운송      제주애견카페왈   ***********  제주특별자치도 서귀포시 남원읍 태흥리
#
#                   인허가번호
# ...

# %%
import googlemaps
import pandas as pd
places = animal_deliver['업체명']
my_key = ""
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 공병호펫택시의 위치를 찾고있습니다
# 2번 인덱스에서 GECOS(개코스)의 위치를 찾고있습니다
# 3번 인덱스에서 멍이요의 위치를 찾고있습니다
# 3번 인덱스 위치를 찾는데 실패했습니다.
# 4번 인덱스에서 엔젤펫택시의 위치를 찾고있습니다
# 5번 인덱스에서 엔젤의 위치를 찾고있습니다
# 6번 인덱스에서 꼬리살랑의 위치를 찾고있습니다
# 7번 인덱스에서 조은주펫택시의 위치를 찾고있습니다
# 8번 인덱스에서 유임정펫택시의 위치를 찾고있습니다
# 8번 인덱스 위치를 찾는데 실패했습니다.
# 9번 인덱스에서 이예슬펫택시의 위치를 찾고있습니다
# 10번 인덱스에서 해피펫드라이버의 위치를 찾고있습니다
# 10번 인덱스 위치를 찾는데 실패했습니다.
# 11번 인덱스에서 타다펫의 위치를 찾고있습니다
# 11번 인덱스 위치를 찾는데 실패했습니다.
# 12번 인덱스에서 (주)하율투어 펫피스 드라이버의 위치를 찾고있습니다
# 12번 인덱스 위치를 찾는데 실패했습니다.
# 13번 인덱스에서 정민영 펫택시의 위치를 찾고있습니다
# 14번 인덱스에서 수호펫의 위치를 찾고있습니다
# 15번 인덱스에서 이재원의 위치를 찾고있습니다
# 16번 인덱스에서 펫뜨락의 위치를 찾고있습니다
# 17번 인덱스에서 우기부기샵의 위치를 찾고있습니다
# 17번 인덱스 위치를 찾는데 실패했습니다.
# 18번 인덱스에서 디어독의 위치를 찾고있습니다
# 19번 인덱스에서 댕댕이 전용차의 위치를 찾고있습니다
# 19번 인덱스 위치를 찾는데 실패했습니다.
# 20번 인덱스에서 윤패션의 위치를 찾고있습니다
# 21번 인덱스에서 주식회사 한국화물연합의 위치를 찾고있습니다
# 22번 인덱스에서 PET me up(최윤희)의 위치를 찾고있습니다
# 22번 인덱스 위치를 찾는데 실패했습니다.
# 23번 인덱스에서 프리펫택시(FREE PET TAXI)의 위치를 찾고있습니다
# 24번 인덱스에서 반려동물 이동서비스의 위치를 찾고있습니다
# 25번 인덱스에서 멍이요의 위치를 찾고있습니다
# ...

# %%
df_fin = pd.concat([animal_deliver,df],axis = 1)

df_fin.to_csv('동물운송업경도(euc-kr).csv',encoding='euc-kr')
