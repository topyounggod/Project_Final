# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./동물병원위도경도(UTF-8)정상.csv')

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1   개방자치단체코드          관리번호       인허가일자  인허가취소일자  \
# 0             0             0  3170000.0  3.170000e+17  20180410.0      NaN
# 1             1             1  3040000.0  3.040000e+17  20030926.0      NaN
# 2             2             2  3220000.0  3.220000e+17  20210408.0      NaN
# 3             3             3  3090000.0  3.090000e+17  20190410.0      NaN
# 4             4             4  3130000.0  3.130000e+17  20000211.0      NaN
# ..          ...           ...        ...           ...         ...      ...
# 898        1417          2005  3140000.0  3.140000e+17  20210820.0      NaN
# 899        1418          2006  3130000.0  3.130000e+17  20180720.0      NaN
# 900        1419          2007  3230000.0  3.230000e+17  20210824.0      NaN
# 901        1420          2008  3140000.0  3.140000e+17  20210825.0      NaN
# 902        1421          2009  3110000.0  3.110000e+17  20170308.0      NaN
#
#      영업상태코드  영업상태명  상세영업상태코드 상세영업상태명  ...  재개업일자          전화번호   소재지면적  \
# 0       1.0  영업/정상       0.0      정상  ...    NaN      802-2811  227.32
# 1       1.0  영업/정상       0.0      정상  ...    NaN      457-4545  125.40
# 2       1.0  영업/정상       0.0      정상  ...    NaN  02-2237-7582     NaN
# 3       1.0  영업/정상       0.0      정상  ...    NaN     3491-8000     NaN
# 4       1.0  영업/정상       0.0      정상  ...    NaN   02-325-2026    0.00
# ..      ...    ...       ...     ...  ...    ...           ...     ...
# 898     1.0  영업/정상       0.0      정상  ...    NaN     226918119   62.00
# 899     1.0  영업/정상       0.0      정상  ...    NaN  02-3142-7298    0.00
# 900     1.0  영업/정상       0.0      정상  ...    NaN   02-407-7579    0.00
# 901     1.0  영업/정상       0.0      정상  ...    NaN  02-2694-7575  110.62
# 902     1.0  영업/정상       0.0      정상  ...    NaN   02-356-9475    0.00
#
#      소재지우편번호                                               지번주소  \
# 0        NaN                           서울특별시 금천구 시흥동 904-6 서우빌딩
# 1        NaN                                서울특별시 광진구 구의동 68-37
# 2        NaN                           서울특별시 강남구 청담동 46 베디베로스퀘어
# 3        NaN                           서울특별시 도봉구 방학동 680-1번지 1층
# 4        NaN                             서울특별시 마포구 합정동 411-18번지
# ..       ...                                                ...
# 898      NaN                             서울특별시 양천구 신월동 559-7 2층
# 899      NaN                                서울특별시 마포구 서교동 444-5
# 900      NaN                         서울특별시 송파구 장지동 884 위례2차아이파크
# 901      NaN                             서울특별시 양천구 신월동 536-6 1층
# 902      NaN  서울특별시 은평구 불광동 643 북한산 힐스테이트7차 상가동 지하2층 128호 지하...
#
#                                                  도로명주소  도로명우편번호         사업장명  \
# 0                        서울특별시 금천구 시흥대로 172 서우빌딩 (시흥동)   8631.0   더조은 동물의료센터
# 1                             서울특별시 광진구 광나루로 507 (구의동)   4976.0     광진동물의료센터
# 2                 서울특별시 강남구 삼성로133길 7 베디베로스퀘어 5층 (청담동)   6068.0    놀로동물행동클리닉
# 3                           서울특별시 도봉구 도봉로 669 1층 (방학동)   1346.0     현대종합동물병원
# 4                               서울특별시 마포구 독막로 45 (합정동)   4047.0     홍익동물종합병원
# ..                                                 ...      ...          ...
# 898                      서울특별시 양천구 신월로10길 22 2층층 (신월동)   8065.0      정말로동물병원
# 899                         서울특별시 마포구 월드컵로 46 2층 (서교동)   4029.0  이층애 고양이동물병원
# 900         서울특별시 송파구 위례광장로 230 119120호 (장지동 위례2차아이파크)   5849.0  위례 별 동물의료센터
# 901                         서울특별시 양천구 신월로 179 1층 (신월동)   8030.0   신월라온동물의료센터
# 902  서울특별시 은평구 통일로 796 상가동 지하2층 128호 지하1층 228호 (불광동...   3357.0       담은동물병원
#
#             위도          경도
# 0    37.449477  126.903299
# 1    37.545192  127.085929
# 2    37.511950  127.099102
# 3    37.664194  127.042264
# 4    37.548054  126.918368
# ..         ...         ...
# 898        NaN         NaN
# 899        NaN         NaN
# 900        NaN         NaN
# 901        NaN         NaN
# 902        NaN         NaN
#
# [903 rows x 23 columns]

# %%
df.to_json('동물병원.json')

# %%
coordinate_df = df[['위도','경도']].dropna()
coordinate_df
# Out:
#             위도          경도
# 0    37.449477  126.903299
# 1    37.545192  127.085929
# 2    37.511950  127.099102
# 3    37.664194  127.042264
# 4    37.548054  126.918368
# ..         ...         ...
# 396  37.519966  126.969859
# 397  37.599745  126.918113
# 398  37.535634  127.081896
# 399  37.653052  127.068132
# 400  37.553395  126.843594
#
# [401 rows x 2 columns]

# %%
coordinate_df

# %%
lan = df[['위도']].to_numpy

# %%
lng = df[['경도']].to_numpy

# %%
name = df['사업장명'].dropna()

# %%
coordinate = coordinate_df.to_numpy

# %%
coordinate
# Out:
# <bound method DataFrame.to_numpy of             위도          경도
# 0    37.449477  126.903299
# 1    37.545192  127.085929
# 2    37.511950  127.099102
# 3    37.664194  127.042264
# 4    37.548054  126.918368
# ..         ...         ...
# 396  37.519966  126.969859
# 397  37.599745  126.918113
# 398  37.535634  127.081896
# 399  37.653052  127.068132
# 400  37.553395  126.843594
#
# [401 rows x 2 columns]>

# %%
data = {'Name':df['사업장명'],
       'coordinate': coordinate}

# %%
pd.DataFrame(data)
# Out:
#             Name                                         coordinate
# 0     더조은 동물의료센터  <bound method DataFrame.to_numpy of           ...
# 1       광진동물의료센터  <bound method DataFrame.to_numpy of           ...
# 2      놀로동물행동클리닉  <bound method DataFrame.to_numpy of           ...
# 3       현대종합동물병원  <bound method DataFrame.to_numpy of           ...
# 4       홍익동물종합병원  <bound method DataFrame.to_numpy of           ...
# ..           ...                                                ...
# 898      정말로동물병원  <bound method DataFrame.to_numpy of           ...
# 899  이층애 고양이동물병원  <bound method DataFrame.to_numpy of           ...
# 900  위례 별 동물의료센터  <bound method DataFrame.to_numpy of           ...
# 901   신월라온동물의료센터  <bound method DataFrame.to_numpy of           ...
# 902       담은동물병원  <bound method DataFrame.to_numpy of           ...
#
# [903 rows x 2 columns]

# %%
from geojson import Point
import json
from geojson import Point, Feature, FeatureCollection, dump
# to string 
# 만일 없으면

# %%
a = {}
features = []
for i in range(0,len(coordinate_df)): 
    #print(coordinate_df.loc[i])
    #print(coordinate_df.loc[i]['위도'])
    #print(coordinate_df.loc[i]['경도'])
    point = Point((coordinate_df.loc[i]['위도'],coordinate_df.loc[i]['경도']))
    features.append(Feature(geometry=point, properties={"name": name[i],"type":"animal_hospital"}))

with open('your_file.txt', 'w') as f:
    for item in features:
        f.write("%s\n" % item)

# %%
import numpy as np

coords = np.random.rand(10000, 2) * 2

# %%
import random
 


def Rand(start, end, num):
    res = []
    for j in range(num):
        res = np.random.rand(start,end)
    return res
 

import numpy as np

a = np.random.randint(37584980, 37612181, size=50) / 1000000
b = np.random.randint(127031133,127058599,size = 50) / 1000000

# %%
a
# Out:
# array([37.609488, 37.590611, 37.597216, 37.601474, 37.59833 , 37.586183,
#        37.606131, 37.608059, 37.609648, 37.590309, 37.586861, 37.60828 ,
#        37.59629 , 37.593718, 37.589557, 37.591228, 37.589751, 37.609186,
#        37.595449, 37.598186, 37.596599, 37.59853 , 37.609593, 37.605929,
#        37.592566, 37.586942, 37.608796, 37.590293, 37.609566, 37.595202,
#        37.608523, 37.585611, 37.588297, 37.608581, 37.599025, 37.593782,
#        37.588376, 37.604108, 37.602648, 37.589016, 37.603286, 37.6053  ,
#        37.595449, 37.585373, 37.599712, 37.598985, 37.59989 , 37.595873,
#        37.609334, 37.606085])

# %%
b
# Out:
# array([127.035563, 127.044706, 127.032828, 127.057459, 127.058098,
#        127.05588 , 127.054434, 127.045786, 127.053522, 127.040025,
#        127.0426  , 127.047392, 127.056889, 127.055042, 127.055917,
#        127.046486, 127.036015, 127.051847, 127.049754, 127.049731,
#        127.052263, 127.056033, 127.046729, 127.050126, 127.048776,
#        127.031239, 127.05423 , 127.033965, 127.050488, 127.049205,
#        127.048469, 127.037137, 127.046533, 127.055283, 127.032821,
#        127.032477, 127.052109, 127.033824, 127.036759, 127.051224,
#        127.051906, 127.043756, 127.039532, 127.037404, 127.052949,
#        127.032257, 127.047676, 127.03865 , 127.037041, 127.045313])

# %%
import numpy as np
from geojson import Point, Feature, FeatureCollection, dump
a = np.random.randint(37584980, 37612181, size=50) / 1000000
b = np.random.randint(127031133,127058599,size = 50) / 1000000
for i in range(0,len(a)): 
    #print(coordinate_df.loc[i])
    #print(coordinate_df.loc[i]['위도'])
    #print(coordinate_df.loc[i]['경도'])
    point = Point((b[i],a[i]))
    features.append(Feature(geometry=point))

with open('random_point.txt', 'w') as f:
    for item in features:
        f.write("%s\n" % item)
