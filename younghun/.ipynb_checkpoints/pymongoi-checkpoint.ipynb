# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
db = client['fin']

# %%
park = db['park']
beauty = db['beauty']
cafe = db['cafe']
deliver = db['deliver']
equip = db['equip']
food = db['food']
funeral = db['funeral']
hospital = db['hospital']
manage = db['manage']
medical = db['medical_equip']
pharmacy = db['pharmacy']
play = db['play']
restaurant = db['restaurant']
sell = db['sell']
shelter = db['shelter']

# %%
a = []
# 0.0005 = 500m
x = 37.584980
y = 127.031133
while x < 37.612181:
    y = 127.031133
    while y < 127.058599:
        a.append((y,x))
        y += 0.0005
        y = round(y,6)
    a.append((y,x))
    x += 0.0005
    x = round(x,6)

# %%
len(a)
# Out:
# 3080

# %%
import numpy as np
from geojson import Point, Feature, FeatureCollection, dump
# a = np.random.randint(37584980, 37612181, size=5000) / 1000000
# b = np.random.randint(127031133,127058599,size = 5000) / 1000000
# 진짜 서울시 위도 경도
# a = np.random.randint(37413294, 37715133, size=10000) / 1000000
# b = np.random.randint(127269311,127734086,size = 10000) / 1000000


counts1 = []
for i in range(0,len(a)): 
    c = list(park.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
            
        }]
    ))
    counts1.append(len(c))

# %%
counts2 = []
for i in range(0,len(a)): 
    c = list(beauty.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts2.append(len(c))

# %%
counts3 = []
for i in range(0,len(a)): 
    c = list(cafe.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts3.append(len(c))

# %%
counts4 = []
for i in range(0,len(a)): 
    c = list(deliver.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts4.append(len(c))

# %%
counts5 = []
for i in range(0,len(a)): 
    c = list(equip.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts5.append(len(c))

# %%
counts6 = []
for i in range(0,len(a)): 
    c = list(food.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts6.append(len(c))

# %%
counts7 = []
for i in range(0,len(a)): 
    c = list(funeral.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts7.append(len(c))

# %%
counts8 = []
for i in range(0,len(a)): 
    c = list(hospital.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts8.append(len(c))

# %%
counts9 = []
for i in range(0,len(a)): 
    c = list(manage.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts9.append(len(c))

# %%
counts10 = []
for i in range(0,len(a)): 
    c = list(medical.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1500
            }
        }]
    ))
    counts10.append(len(c))

# %%
counts11 = []
for i in range(0,len(a)): 
    c = list(pharmacy.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts11.append(len(c))

# %%
counts12 = []
for i in range(0,len(a)): 
    c = list(play.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts12.append(len(c))

# %%
counts13 = []
for i in range(0,len(a)): 
    c = list(restaurant.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts13.append(len(c))

# %%
counts14 = []
for i in range(0,len(a)): 
    c = list(sell.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts14.append(len(c))

# %%
counts15 = []
for i in range(0,len(a)): 
    c = list(shelter.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts15.append(len(c))

# %%
import pandas as pd
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
df['cafe'] = counts3
df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
df['play'] = counts12
df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
df_int = df

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kmeans = KMeans(n_clusters = 20)

# %%
kmeans.fit(df)
# Out:
# KMeans(n_clusters=20)

# %%
labels = kmeans.fit_predict(df)

# %%
df['cluster'] = kmeans.labels_

# %%
df
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 0        3       0     0        0      2     4         1       0         0
# 1        3       0     0        0      2     4         1       0         0
# 2        4       0     0        0      2     6         1       0         0
# 3        4       0     0        0      2     6         0       0         0
# 4        4       0     0        0      2     6         0       0         0
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 3075     2       5     1        0      3     4         4       1         8
# 3076     2       5     1        0      3     4         4       1        10
# 3077     2       5     1        0      3     4         4       0        10
# 3078     2       5     1        0      3     4         4       0        11
# 3079     1       6     1        1      2     4         4       1        11
#
#       play  restaurant  sell  cluster
# 0        1           3     5       19
# 1        1           3     5       19
# 2        1           3     5       19
# 3        1           3     5       19
# 4        1           3     5       19
# ...    ...         ...   ...      ...
# 3075     0           3     8        3
# 3076     0           3     8        3
# 3077     0           3     6        3
# 3078     0           3     7        3
# 3079     0           3     9        3
#
# [3080 rows x 13 columns]

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
print('실루엣 스코어는 : {0:.3f}'.format(silhouette_score(df,labels)))
# Out:
# 실루엣 스코어는 : 0.495

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(df_int)

# %%
df_int['pca_x'] = pca_transformed[:,0] #첫번째 값(X 좌표)
df_int['pca_y']=pca_transformed[:,1] #첫번째 값(y 좌표)
df.head(3)
# Out:
#    park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  play  \
# 0     3       0     0        0      2     4         1       0         0     1
# 1     3       0     0        0      2     4         1       0         0     1
# 2     4       0     0        0      2     6         1       0         0     1
#
#    restaurant  sell  cluster      pca_x     pca_y
# 0           3     5       19 -10.084941  5.055373
# 1           3     5       19 -10.084941  5.055373
# 2           3     5       19 -10.123725  5.214990

# %%
# 산점도로 표현 : 군집별로 다른 색상으로 표시
plt.scatter(x=df_int.loc[:,'pca_x'], y=df_int.loc[:,'pca_y'], c=df_int['cluster'])

# %%
#collections = ['park','beauty','equip','food','hospital','manage','pharmacy','sell','cluster']
collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage','pharmacy','play','restaurant','sell','cluster']
for collection in collections:
    print(df[collection].value_counts())
# Out:
# 2    1506
# 1     581
# 3     515
# 4     307
# 5     171
# Name: park, dtype: int64
# 2     636
# 3     452
# 1     346
# 6     312
# 0     286
# 4     281
# 5     253
# 7     185
# 8     165
# 9     104
# 10     51
# 11      9
# Name: beauty, dtype: int64
# 0    2258
# 1     749
# 2      73
# Name: cafe, dtype: int64
# 0    2586
# 1     295
# 3     198
# 4       1
# Name: deliver, dtype: int64
# 1    943
# 2    761
# 0    664
# 3    389
# 4    203
# 5     63
# 6     36
# 7     21
# Name: equip, dtype: int64
# 0    1124
# 1    1015
# 2     460
# 3     232
# 4     196
# 6      22
# 7      10
# 8       9
# 5       9
# 9       3
# Name: food, dtype: int64
# 2     803
# 3     569
# 1     555
# 0     407
# 4     255
# 6     183
# 7     125
# 5     117
# 8      49
# 9      15
# 10      2
# Name: hospital, dtype: int64
# 0    1239
# 1     876
# 2     557
# 3     321
# 4      85
# 5       2
# Name: manage, dtype: int64
# 4     578
# 2     441
# 0     330
# 5     298
# 7     280
# 6     260
# 3     249
# 8     227
# 1     147
# 9      89
# 10     80
# 11     41
# 14     35
# 12     17
# 13      8
# Name: pharmacy, dtype: int64
# 0    1480
# 1    1178
# 2     347
# 3      75
# Name: play, dtype: int64
# 1    1230
# 0    1051
# 3     509
# 2     290
# Name: restaurant, dtype: int64
# 5     415
# 7     351
# 3     338
# 6     267
# 4     239
# 8     212
# 2     204
# 1     185
# 0     157
# 9     156
# 10    130
# 11    107
# 12     80
# 20     52
# 13     40
# 19     29
# 15     24
# 16     23
# 17     23
# 18     21
# 14     18
# 21      6
# 22      3
# Name: sell, dtype: int64
# 8     260
# 12    254
# 3     233
# 0     229
# 6     223
# 14    185
# 9     172
# 17    162
# 4     158
# 10    152
# 11    152
# 2     142
# 13    133
# 18    129
# 1     106
# 19    101
# 7      76
# 5      75
# 16     72
# 15     66
# Name: cluster, dtype: int64

# %%
df[df['cluster']== 7]
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 2470     3       8     1        0      4     1         7       2        11
# 2580     3       9     0        1      4     1         7       3        10
# 2581     3       9     0        1      4     1         7       3        10
# 2582     3       9     0        1      4     1         7       3        10
# 2583     3       9     0        0      4     1         7       3        10
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 3028     3       7     0        1      6     0         6       3        14
# 3029     3       7     0        1      7     0         6       4        14
# 3030     3       7     0        1      7     0         6       4        12
# 3031     3       6     0        1      6     0         5       4        12
# 3032     3       6     0        1      6     0         4       4        12
#
#       play  restaurant  sell  cluster      pca_x     pca_y
# 2470     0           1    19        7  13.273555  8.255578
# 2580     0           1    20        7  14.010073  8.743620
# 2581     0           1    20        7  14.010073  8.743620
# 2582     0           1    20        7  14.010073  8.743620
# 2583     0           1    20        7  13.969355  8.700511
# ...    ...         ...   ...      ...        ...       ...
# 3028     0           1    20        7  14.537872  9.288534
# 3029     0           1    20        7  14.748388  9.457197
# 3030     0           1    17        7  12.425568  7.612264
# 3031     0           1    17        7  11.743764  7.035039
# 3032     0           1    17        7  11.519134  6.813146
#
# [76 rows x 15 columns]

# %%
df[df['cluster']== 2]
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 665      3       5     0        0      2     2         3       0         6
# 701      4       2     0        0      1     1         1       2         6
# 718      3       4     0        0      2     2         3       0         5
# 719      3       4     0        0      2     2         3       0         6
# 720      3       5     0        0      2     2         3       0         6
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 2233     1       3     0        1      3     2         2       1         6
# 2234     1       4     0        1      3     2         2       1         6
# 2235     1       4     0        1      3     2         2       1         6
# 2286     1       3     0        1      3     1         2       1         6
# 2287     1       4     0        1      3     1         2       1         6
#
#       play  restaurant  sell  cluster     pca_x     pca_y
# 665      2           0     5        2  4.327067 -5.055895
# 701      1           0     5        2  2.976539 -6.178063
# 718      2           0     4        2  3.115227 -6.000641
# 719      2           0     4        2  3.411769 -5.735802
# 720      2           0     5        2  4.327067 -5.055895
# ...    ...         ...   ...      ...       ...       ...
# 2233     1           1     5        2  3.794718 -5.689605
# 2234     1           1     6        2  4.710015 -5.009697
# 2235     1           1     6        2  4.710015 -5.009697
# 2286     0           2     5        2  3.869580 -5.697258
# 2287     0           2     6        2  4.784877 -5.017350
#
# [142 rows x 15 columns]

# %%
a[665]
# Out:
# (127.055633, 37.59048)

# %%
a[2287]
# Out:
# (127.054633, 37.60498)

# %%
def visualize_silhouette(cluster_lists, X_features): 
    
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
visualize_silhouette([5,6,7,8,9],df)

# %%
visualize_silhouette([10,11,12,13,14,15],df)

# %%
visualize_silhouette([16,17,18,19],df)

# %%
visualize_silhouette([20,21,22],df)

# %%
visualize_silhouette([23,24,25],df)

# %%
visualize_silhouette([35,36,37,38,39,40],df)

# %% [markdown]
# # DBScan

# %%
import pandas as pd
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
#df['cafe'] = counts3
#df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
#df['play'] = counts12
#df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1.5, min_samples =26, metric='euclidean')
dbscan_labels = dbscan.fit_predict(df)

# %%
df['dbscan_cluster'] = dbscan_labels

# %%
df
# Out:
#       park  beauty  equip  food  hospital  manage  pharmacy  sell  \
# 0        3       0      2     4         1       0         0     5
# 1        3       0      2     4         1       0         0     5
# 2        4       0      2     6         1       0         0     5
# 3        4       0      2     6         0       0         0     5
# 4        4       0      2     6         0       0         0     5
# ...    ...     ...    ...   ...       ...     ...       ...   ...
# 3075     2       5      3     4         4       1         8     8
# 3076     2       5      3     4         4       1        10     8
# 3077     2       5      3     4         4       0        10     6
# 3078     2       5      3     4         4       0        11     7
# 3079     1       6      2     4         4       1        11     9
#
#       dbscan_cluster
# 0                 -1
# 1                 -1
# 2                 -1
# 3                 -1
# 4                 -1
# ...              ...
# 3075              -1
# 3076              -1
# 3077              -1
# 3078              -1
# 3079              -1
#
# [3080 rows x 9 columns]

# %%
df['dbscan_cluster'].value_counts()
# Out:
# -1    1369
#  4     957
#  6     269
#  8     110
#  7     107
#  9      86
#  2      74
#  3      30
#  0      26
#  1      26
#  5      26
# Name: dbscan_cluster, dtype: int64

# %%
df[df['dbscan_cluster']==0]
# Out:
#      park  beauty  equip  food  hospital  manage  pharmacy  sell  \
# 27      5       2      4     4         2       2         8     5
# 28      5       2      4     3         2       2         8     5
# 29      5       2      4     3         2       2         8     4
# 30      5       2      4     2         2       2         7     4
# 31      5       2      4     3         2       2         8     4
# 32      5       2      4     3         2       2         8     5
# 33      5       2      4     3         2       2         8     5
# 34      5       2      4     3         2       2         8     5
# 35      5       2      3     3         2       2         7     5
# 83      5       2      4     4         2       2         7     5
# 84      5       2      4     3         2       2         7     5
# 85      5       2      4     2         2       2         7     4
# 86      5       2      4     2         2       2         7     4
# 87      5       2      4     2         2       2         7     5
# 88      5       2      4     3         2       2         8     5
# 89      5       2      4     3         2       2         8     5
# 90      5       2      4     3         2       2         6     5
# 91      5       2      3     3         2       2         6     5
# 138     4       2      4     4         2       2         7     5
# 139     5       2      4     3         2       2         7     5
# 140     5       2      4     2         2       2         7     5
# 141     5       2      4     2         2       2         7     4
# 142     5       2      4     2         2       2         7     5
# 144     5       2      4     2         2       2         6     5
# 145     5       2      4     2         2       2         6     5
# 146     5       2      3     3         2       2         6     5
#
#      dbscan_cluster
# 27                0
# 28                0
# 29                0
# 30                0
# 31                0
# 32                0
# 33                0
# 34                0
# 35                0
# 83                0
# 84                0
# 85                0
# 86                0
# 87                0
# 88                0
# 89                0
# 90                0
# 91                0
# 138               0
# 139               0
# 140               0
# 141               0
# 142               0
# 144               0
# 145               0
# 146               0

# %%
a[27]
# Out:
# (127.044633, 37.58498)

# %%
a[146]
# Out:
# (127.048133, 37.58598)
