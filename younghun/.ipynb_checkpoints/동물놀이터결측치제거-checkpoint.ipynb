# %%
import pandas as pd
df = pd.read_csv('./data/반려견놀이터.csv',encoding = 'utf-8')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# index         0
# name          0
# address       0
# lat           0
# long          0
# dtype: int64

# %%
df['type'] = '동물놀이터'

# %%
df
# Out:
#     Unnamed: 0  index                     name  \
# 0            0      0        월드컵공원반려견놀이터반려견놀이터
# 1            1      1              카페700반려견놀이터
# 2            2      2             마이댕댕스쿨반려견놀이터
# 3            3     15               까네지노반려견놀이터
# 4            4     16            도그어스플래닛반려견놀이터
# 5            5     17     어린이대공원 반려견 놀이터반려견놀이터
# 6            6     18        휘경2동 반려견놀이터반려견놀이터
# 7            7     19        초안산공공반려견놀이터반려견놀이터
# 8            8     20        당고개반려견임시놀이터반려견놀이터
# 9            9     22        스테이지28웁시데이지반려견놀이터
# 10          10     24  24개스트하우스 강남강아지유치원반려견놀이터
# 11          11     25          개러리아 삼성본점반려견놀이터
# 12          12     26              강남강아지반려견놀이터
# 13          13     28      보라매공원 반려견 놀이터반려견놀이터
# 14          14     30               개좋은날반려견놀이터
# 15          15     31               멍마르뜨반려견놀이터
#
#                                address        lat        long   type
# 0                     서울특별시 마포구 증산로 32  37.564134  126.892448  동물놀이터
# 1          서울특별시 강서구 곰달래로 104 3층 카페700  37.530306  126.844331  동물놀이터
# 2     서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨  37.545379  126.847042  동물놀이터
# 3                 서울특별시 동대문구 전농로 43 1층  37.568793  127.056653  동물놀이터
# 4            서울특별시 동대문구 고산자로36길 3 경동시장  37.579038  127.039143  동물놀이터
# 5                    서울특별시 광진구 능동로 216  37.552012  127.078772  동물놀이터
# 6                 서울특별시 동대문구 휘경동 산6-26  37.589811  127.068431  동물놀이터
# 7                서울특별시 도봉구 해등로3길 48-11  37.647494  127.041384  동물놀이터
# 8                 서울특별시 노원구 상계동 산158-1  37.675870  127.088353  동물놀이터
# 9           서울특별시 강동구 아리수로61길 91-14 2층  37.564722  127.146792  동물놀이터
# 10          서울특별시 강남구 봉은사로20길 52 지하 1층  37.503909  127.033359  동물놀이터
# 11                 서울특별시 강남구 선릉로122길 4  37.514470  127.042934  동물놀이터
# 12              서울특별시 강남구 언주로79길 14 2층  37.499331  127.042877  동물놀이터
# 13         서울특별시 동작구 여의대방로20길 33 보라매공원  37.494892  126.919491  동물놀이터
# 14  서울특별시 영등포구 여의대방로 249 우주마루에어스포렉스 1층  37.508136  126.922876  동물놀이터
# 15           서울특별시 강서구 양천로 132 2층 멍마르뜨  37.573127  126.818459  동물놀이터

# %%
df = df[['name','lat','long','address','type']]

# %%
df.rename(columns={'long':'lng'},inplace=True)
# df = df.rename(columns={'공원명':'name','위도':'lat','경도':'lng','공원주소':'address'})
# Out:
# D:\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%

# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name       0
# lat        0
# lng        0
# address    0
# type       0
# dtype: int64

# %%
df.to_csv('동물놀이터(utf-8)최종_영훈.csv',encoding='utf-8')

# %%
df
# Out:
#                        name        lat         lng  \
# 0         월드컵공원반려견놀이터반려견놀이터  37.564134  126.892448
# 1               카페700반려견놀이터  37.530306  126.844331
# 2              마이댕댕스쿨반려견놀이터  37.545379  126.847042
# 3                까네지노반려견놀이터  37.568793  127.056653
# 4             도그어스플래닛반려견놀이터  37.579038  127.039143
# 5      어린이대공원 반려견 놀이터반려견놀이터  37.552012  127.078772
# 6         휘경2동 반려견놀이터반려견놀이터  37.589811  127.068431
# 7         초안산공공반려견놀이터반려견놀이터  37.647494  127.041384
# 8         당고개반려견임시놀이터반려견놀이터  37.675870  127.088353
# 9         스테이지28웁시데이지반려견놀이터  37.564722  127.146792
# 10  24개스트하우스 강남강아지유치원반려견놀이터  37.503909  127.033359
# 11          개러리아 삼성본점반려견놀이터  37.514470  127.042934
# 12              강남강아지반려견놀이터  37.499331  127.042877
# 13      보라매공원 반려견 놀이터반려견놀이터  37.494892  126.919491
# 14               개좋은날반려견놀이터  37.508136  126.922876
# 15               멍마르뜨반려견놀이터  37.573127  126.818459
#
#                                address   type
# 0                     서울특별시 마포구 증산로 32  동물놀이터
# 1          서울특별시 강서구 곰달래로 104 3층 카페700  동물놀이터
# 2     서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨  동물놀이터
# 3                 서울특별시 동대문구 전농로 43 1층  동물놀이터
# 4            서울특별시 동대문구 고산자로36길 3 경동시장  동물놀이터
# 5                    서울특별시 광진구 능동로 216  동물놀이터
# 6                 서울특별시 동대문구 휘경동 산6-26  동물놀이터
# 7                서울특별시 도봉구 해등로3길 48-11  동물놀이터
# 8                 서울특별시 노원구 상계동 산158-1  동물놀이터
# 9           서울특별시 강동구 아리수로61길 91-14 2층  동물놀이터
# 10          서울특별시 강남구 봉은사로20길 52 지하 1층  동물놀이터
# 11                 서울특별시 강남구 선릉로122길 4  동물놀이터
# 12              서울특별시 강남구 언주로79길 14 2층  동물놀이터
# 13         서울특별시 동작구 여의대방로20길 33 보라매공원  동물놀이터
# 14  서울특별시 영등포구 여의대방로 249 우주마루에어스포렉스 1층  동물놀이터
# 15           서울특별시 강서구 양천로 132 2층 멍마르뜨  동물놀이터

# %%
len(df)
# Out:
# 131

# %%
import geojson
from geojson import Point, Feature, FeatureCollection, dump

# %%
features = []
for i in range(0,len(df)): 
    #print(coordinate_df.loc[i])
    #print(coordinate_df.loc[i]['위도'])
    #print(coordinate_df.loc[i]['경도'])
    point = Point((df.loc[i]['lng'],df.loc[i]['lat']))
    features.append(Feature(geometry=point, properties={"name": df.loc[i]['name'],"address":df.loc[i]['address'],"type":df.loc[i]['type']}))

with open('동물놀이터.txt', 'w') as f:
    for item in features:
        f.write("%s\n" % item)
