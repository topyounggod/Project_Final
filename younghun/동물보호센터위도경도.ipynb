# %%
import pandas as pd
import numpy as np

animal_safe = pd.read_csv('./data/동물보호센터최종(UTF-8).csv',encoding = 'utf-8')

# %%
animal_safe
# Out:
#      Unnamed: 0       관할구역       보호센터명          전화번호  \
# 0             0  대구광역시 수성구   (사)대구수의사회  053-764-3708
# 1             1   대구광역시 중구  (사)대구시수의사회  053-764-3708
# 2             2  부산광역시 사하구    (사)하얀비둘기  051-293-9779
# 3             3  대구광역시 달성군     119동물병원  053-585-1195
# 4             4  서울특별시 용산구    21세기동물병원   02-749-6750
# ..          ...        ...         ...           ...
# 300         300    강원도 홍천군  홍천군유기동물보호소  033-434-9435
# 301         301   전라남도 화순군  화순군유기동물보호소   ***********
# 302         302  대구광역시 달성군    화원연합동물병원  053-634-7975
# 303         303    강원도 화천군   화천군농업기술센터  033-440-2941
# 304         304    강원도 횡성군  횡성유기동물보호센터  033-731-1119
#
#                                                 보호센터주소
# 0                            대구광역시 북구 호국로 229 (서변동) 6층
# 1                  대구광역시 북구 호국로 229 (서변동) 대구경북수의사회관 6층
# 2                              부산광역시 강서구 제도로 726 (강동동)
# 3    대구광역시 달성군 다사읍 달구벌대로 893 (다사읍, 대실요양병원 장례식장) 다사읍 관할
# ...

# %%
import googlemaps
import pandas as pd
places = animal_safe['보호센터명']
my_key = ""
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 (사)대구수의사회의 위치를 찾고있습니다
# 2번 인덱스에서 (사)대구시수의사회의 위치를 찾고있습니다
# 3번 인덱스에서 (사)하얀비둘기의 위치를 찾고있습니다
# 4번 인덱스에서 119동물병원의 위치를 찾고있습니다
# 5번 인덱스에서 21세기동물병원의 위치를 찾고있습니다
# 6번 인덱스에서 24시아이동물메디컬의 위치를 찾고있습니다
# 7번 인덱스에서 C.T종합동물병원의 위치를 찾고있습니다
# 8번 인덱스에서 GD동물병원의 위치를 찾고있습니다
# 9번 인덱스에서 MK동물병원의 위치를 찾고있습니다
# 10번 인덱스에서 cj동물병원의 위치를 찾고있습니다
# 11번 인덱스에서 가나동물병원의 위치를 찾고있습니다
# 12번 인덱스에서 가온동물병원의 위치를 찾고있습니다
# 13번 인덱스에서 가정동물병원의 위치를 찾고있습니다
# 14번 인덱스에서 가평군유기동물보호소의 위치를 찾고있습니다
# 15번 인덱스에서 감자동물병원의 위치를 찾고있습니다
# 16번 인덱스에서 강남동물병원의 위치를 찾고있습니다
# 17번 인덱스에서 강동구청 반려동물팀의 위치를 찾고있습니다
# 18번 인덱스에서 강동리본센터(reborn)의 위치를 찾고있습니다
# 19번 인덱스에서 강릉시동물사랑센터의 위치를 찾고있습니다
# 20번 인덱스에서 강진군 유기견 보호소의 위치를 찾고있습니다
# 21번 인덱스에서 강현림동물병원의 위치를 찾고있습니다
# 22번 인덱스에서 거제시유기동물보호소의 위치를 찾고있습니다
# 23번 인덱스에서 경동동물병원의 위치를 찾고있습니다
# 24번 인덱스에서 경동동물병원의 위치를 찾고있습니다
# 25번 인덱스에서 경산시유기동물보호소의 위치를 찾고있습니다
# 26번 인덱스에서 경주시유기동물보호소의 위치를 찾고있습니다
# 27번 인덱스에서 계룡시유기동물보호소의 위치를 찾고있습니다
# 28번 인덱스에서 고성군유기동물보호소의 위치를 찾고있습니다
# 29번 인덱스에서 고양시동물보호센터의 위치를 찾고있습니다
# 30번 인덱스에서 고창동물병원의 위치를 찾고있습니다
# ...

# %%
df_fin = pd.concat([animal_safe,df],axis = 1)

df_fin.to_csv('동물보호센터(euc-kr).csv',encoding='euc-kr')
