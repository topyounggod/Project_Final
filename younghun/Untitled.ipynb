# %%
import pandas as pd
df1 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물미용업경도(euc-kr).csv',encoding='euc-kr')

# %%
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1             구분            업체명          전화번호  \
# 0              0             0             미용         사계절, 몽   ***********
# 1              1             1             미용           허그댕댕   ***********
# 2              2             2             미용  한국반려동물아카데미뷰티샵  02-6959-3965
# 3              3             3          판매 미용            레인독   ***********
# 4              4             4  판매 전시 위탁관리 미용          미션코리아   ***********
# ...          ...           ...            ...            ...           ...
# 8108        8108          8121        위탁관리 미용           이쁜이네   ***********
# 8109        8109          8122     위탁관리 미용 운송        제주애견카페왈   ***********
# 8110        8110          8123             미용         메이비펫살롱   ***********
# 8111        8111          8124        위탁관리 미용         몽블리 펫샵   ***********
# 8112        8112          8125        위탁관리 미용          도그스토리   ***********
#
# ...

# %%
df2 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물병원위도경도.csv',encoding='utf-8')

# %%
df2
# Out:
#       Unnamed: 0   개방자치단체코드          관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0              0  3170000.0  3.170000e+17  20180410.0      NaN     1.0  영업/정상
# 1              1  3040000.0  3.040000e+17  20030926.0      NaN     1.0  영업/정상
# 2              2  3220000.0  3.220000e+17  20210408.0      NaN     1.0  영업/정상
# 3              3  3090000.0  3.090000e+17  20190410.0      NaN     1.0  영업/정상
# 4              4  3130000.0  3.130000e+17  20000211.0      NaN     1.0  영업/정상
# ...          ...        ...           ...         ...      ...     ...    ...
# 1417        2005  3140000.0  3.140000e+17  20210820.0      NaN     1.0  영업/정상
# 1418        2006  3130000.0  3.130000e+17  20180720.0      NaN     1.0  영업/정상
# 1419        2007  3230000.0  3.230000e+17  20210824.0      NaN     1.0  영업/정상
# 1420        2008  3140000.0  3.140000e+17  20210825.0      NaN     1.0  영업/정상
# 1421        2009  3110000.0  3.110000e+17  20170308.0      NaN     1.0  영업/정상
#
# ...

# %%
df2 = df2[df2['상세영업상태명']=='정상']

# %%
df2
# Out:
#       Unnamed: 0   개방자치단체코드          관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0              0  3170000.0  3.170000e+17  20180410.0      NaN     1.0  영업/정상
# 1              1  3040000.0  3.040000e+17  20030926.0      NaN     1.0  영업/정상
# 2              2  3220000.0  3.220000e+17  20210408.0      NaN     1.0  영업/정상
# 3              3  3090000.0  3.090000e+17  20190410.0      NaN     1.0  영업/정상
# 4              4  3130000.0  3.130000e+17  20000211.0      NaN     1.0  영업/정상
# ...          ...        ...           ...         ...      ...     ...    ...
# 1417        2005  3140000.0  3.140000e+17  20210820.0      NaN     1.0  영업/정상
# 1418        2006  3130000.0  3.130000e+17  20180720.0      NaN     1.0  영업/정상
# 1419        2007  3230000.0  3.230000e+17  20210824.0      NaN     1.0  영업/정상
# 1420        2008  3140000.0  3.140000e+17  20210825.0      NaN     1.0  영업/정상
# 1421        2009  3110000.0  3.110000e+17  20170308.0      NaN     1.0  영업/정상
#
# ...

# %%
df2.to_csv('동물병원위도경도(UTF-8)정상.csv',encoding = 'utf-8')

# %%
df3 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물보호센터(euc-kr).csv',encoding='euc-kr')

# %%
df3
# Out:
#      Unnamed: 0  Unnamed: 0.1       관할구역       보호센터명          전화번호  \
# 0             0             0  대구광역시 수성구   (사)대구수의사회  053-764-3708
# 1             1             1   대구광역시 중구  (사)대구시수의사회  053-764-3708
# 2             2             2  부산광역시 사하구    (사)하얀비둘기  051-293-9779
# 3             3             3  대구광역시 달성군     119동물병원  053-585-1195
# 4             4             4  서울특별시 용산구    21세기동물병원   02-749-6750
# ..          ...           ...        ...         ...           ...
# 300         300           300    강원도 홍천군  홍천군유기동물보호소  033-434-9435
# 301         301           301   전라남도 화순군  화순군유기동물보호소   ***********
# 302         302           302  대구광역시 달성군    화원연합동물병원  053-634-7975
# 303         303           303    강원도 화천군   화천군농업기술센터  033-440-2941
# 304         304           304    강원도 횡성군  횡성유기동물보호센터  033-731-1119
#
#                                                 보호센터주소         위도          경도
# 0                            대구광역시 북구 호국로 229 (서변동) 6층  35.922346  128.599039
# ...

# %%
df4 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물운송업경도(euc-kr).csv',encoding='euc-kr')

# %%
df4
# Out:
#      Unnamed: 0  Unnamed: 0.1          구분          업체명          전화번호  \
# 0             0             0          운송       공병호펫택시   ***********
# 1             1             1          운송   GECOS(개코스)   ***********
# 2             2             2          운송          멍이요   ***********
# 3             3             3          운송        엔젤펫택시     1577-0423
# 4             4             4          운송           엔젤             -
# ..          ...           ...         ...          ...           ...
# 806         806           806          운송        제주펫스쿨             -
# 807         807           807  위탁관리 미용 운송     주식회사애니멀고   ***********
# 808         808           808     위탁관리 운송          펫소풍  064-792-4877
# 809         809           809          운송  제주애견카페왈 사계점   ***********
# 810         810           810  위탁관리 미용 운송      제주애견카페왈   ***********
#
#                       소재지               인허가번호         위도          경도
# 0          서울특별시 종로구 명륜3가  300000003720200001  37.570039  127.015377
# ...

# %%
df5 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물위탁관리업위경도(euc-kr).csv',encoding='euc-kr')

# %%
df5
# Out:
#       Unnamed: 0  Unnamed: 0.1             구분        업체명          전화번호  \
# 0              0             0           위탁관리     강아지대학로   ***********
# 1              1             1  판매 전시 위탁관리 미용      미션코리아   ***********
# 2              2             2        위탁관리 미용    누리봄동물병원   02-735-7530
# 3              3             3        위탁관리 미용  경희궁바른동물병원   02-735-9088
# 4              4             4        위탁관리 미용    월드펫동물병원   02-379-7575
# ...          ...           ...            ...        ...           ...
# 4807        4807          4814     위탁관리 미용 운송    제주애견카페왈   ***********
# 4808        4808          4815           위탁관리      개판오분전   ***********
# 4809        4809          4816        위탁관리 미용     몽블리 펫샵   ***********
# 4810        4810          4817        위탁관리 미용      도그스토리   ***********
# 4811        4811          4818           위탁관리    놀멍쉬멍고르멍  064-763-3420
#
#                        소재지               인허가번호         위도          경도
# ...

# %%
df6 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물장묘업경도(euc-kr).csv',encoding='euc-kr')
df6
# Out:
#     Unnamed: 0  Unnamed: 0.1             업체명          전화번호      소재지  \
# 0            0             0           무지개언덕  044-863-7075      세종시
# 1            1             1            파트라슈  051-723-2201   부산 기장군
# 2            2             2        센트럴파크(주)  051-728-5411   부산 기장군
# 3            3             3             아이별  051-727-4499   부산 기장군
# 4            4             4           대구러브펫  053-593-4900   대구 달서구
# 5            5             5             어게인  032-566-1936    인천 서구
# 6            6             6          ㈜더 포에버  032-713-5002    인천 서구
# 7            7             7            ㈜하늘펫  062-946-2626   광주 광산구
# 8            8             8            이별공간   ***********   울산 울주군
# 9            9             9           ㈜펫바라기  031-976-3179   경기 고양시
# 10          10            10          몽몽이엠파크     1811-1336  경기 남양주시
# 11          11            11             리멤버  080-200-5004   경기 용인시
# 12          12            12            씨엘로펫     1577-7332   경기 용인시
# ...

# %%
df7 = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/영훈_위경도/동물의료용구판매업(utf-8).csv',encoding='utf-8')
df7
# Out:
#      Unnamed: 0   개방자치단체코드          관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0             0  3130000.0  3.130000e+17  20210120.0      NaN     1.0  영업/정상
# 1             1  3200000.0  3.200000e+17  20210120.0      NaN     1.0  영업/정상
# 2             2  3210000.0  3.210000e+17  20130409.0      NaN     1.0  영업/정상
# 3             3  3210000.0  3.210000e+17  20140729.0      NaN     1.0  영업/정상
# 4             4  3210000.0  3.210000e+17  20021204.0      NaN     1.0  영업/정상
# ..          ...        ...           ...         ...      ...     ...    ...
# 371         390  3150000.0  3.150000e+17  20210810.0      NaN     1.0  영업/정상
# 372         391  3210000.0  3.210000e+17  20210811.0      NaN     1.0  영업/정상
# 373         392  3130000.0  3.130000e+17  20210819.0      NaN     1.0  영업/정상
# 374         393  3110000.0  3.110000e+17  20210823.0      NaN     1.0  영업/정상
# 375         395  3030000.0  3.030000e+17  20210827.0      NaN     1.0  영업/정상
#
# ...

# %%
df7 = df7[df7['상세영업상태명']=='정상']

# %%
df7
# Out:
#      Unnamed: 0   개방자치단체코드          관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0             0  3130000.0  3.130000e+17  20210120.0      NaN     1.0  영업/정상
# 1             1  3200000.0  3.200000e+17  20210120.0      NaN     1.0  영업/정상
# 2             2  3210000.0  3.210000e+17  20130409.0      NaN     1.0  영업/정상
# 3             3  3210000.0  3.210000e+17  20140729.0      NaN     1.0  영업/정상
# 4             4  3210000.0  3.210000e+17  20021204.0      NaN     1.0  영업/정상
# ..          ...        ...           ...         ...      ...     ...    ...
# 371         390  3150000.0  3.150000e+17  20210810.0      NaN     1.0  영업/정상
# 372         391  3210000.0  3.210000e+17  20210811.0      NaN     1.0  영업/정상
# 373         392  3130000.0  3.130000e+17  20210819.0      NaN     1.0  영업/정상
# 374         393  3110000.0  3.110000e+17  20210823.0      NaN     1.0  영업/정상
# 375         395  3030000.0  3.030000e+17  20210827.0      NaN     1.0  영업/정상
#
# ...

# %%
df7.to_csv('동물의료용구판매업(utf-8)정상.csv',encoding='utf-8')
