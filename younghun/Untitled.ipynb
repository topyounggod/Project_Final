# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import pandas as pd


beer_data = pd.read_csv('./Data/BeerProject.csv',encoding = 'latin-1')

# %%
beer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528870 entries, 0 to 528869
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   beer_ABV            508590 non-null  float64
#  1   beer_beerId         528870 non-null  int64
#  2   beer_brewerId       528870 non-null  int64
#  3   beer_name           528870 non-null  object
#  4   beer_style          528870 non-null  object
#  5   review_appearance   528870 non-null  float64
#  6   review_palette      528870 non-null  float64
#  7   review_overall      528870 non-null  float64
#  8   review_taste        528870 non-null  float64
#  9   review_profileName  528755 non-null  object
#  10  review_aroma        528870 non-null  float64
#  11  review_text         528751 non-null  object
#  12  review_time         528870 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 52.5+ MB

# %%
beer_data.isnull().sum()
# Out:
# beer_ABV              20280
# beer_beerId               0
# beer_brewerId             0
# beer_name                 0
# beer_style                0
# review_appearance         0
# review_palette            0
# review_overall            0
# review_taste              0
# review_profileName      115
# review_aroma              0
# review_text             119
# review_time               0
# dtype: int64

# %%
beer_data.groupby('review_profileName').count()
# Out:
#                     beer_ABV  beer_beerId  beer_brewerId  beer_name  \
# review_profileName
# 0110x011                  46           46             46         46
# 03SVTCobra                 3            3              3          3
# 04101Brewer                2            2              2          2
# 05Harley                  37           37             37         37
# 0runkp0s                   1            1              1          1
# ...                      ...          ...            ...        ...
# zymrgy                     2            2              2          2
# zymurgy4all               27           28             28         28
# zymurgywhiz                1            1              1          1
# zythus                     7            7              7          7
# zyzygy                     2            2              2          2
#
#                     beer_style  review_appearance  review_palette  \
# review_profileName
# ...

# %%
beer_data.groupby('beer_name').count()
# Out:
#                                         beer_ABV  beer_beerId  beer_brewerId  \
# beer_name
# "100" Pale Ale                                 1            1              1
# "33" Export                                    3            3              3
# "76" Anniversary Ale                           3            3              3
# "76" Anniversary Ale With English Hops         1            1              1
# "Fade To Black" Porter                         1            1              1
# ...                                          ...          ...            ...
# Über Pils                                    228          228            228
# ÜberFest Pilsner                               4            4              4
# ÜberSun (Imperial Summer Wheat Beer)         233          233            233
# à L'Agave Et Au Citron Vert                    2            2              2
# überPils                                       7            7              7
#
# ...

# %%
beer_data.groupby('beer_brewerId').count()
# Out:
#                beer_ABV  beer_beerId  beer_name  beer_style  \
# beer_brewerId
# 1                  1357         1357       1357        1357
# 2                     0           40         40          40
# 3                  4958         5357       5357        5357
# 5                   554          728        728         728
# 10                   56           56         56          56
# ...                 ...          ...        ...         ...
# 27870                 4            4          4           4
# 27879                 2            3          3           3
# 27917                 1            1          1           1
# 27922                 2            3          3           3
# 27980                 3            3          3           3
#
#                review_appearance  review_palette  review_overall  \
# beer_brewerId
# 1                           1357            1357            1357
# 2                             40              40              40
# ...

# %%
beer_data.groupby('beer_beerId').count()
# Out:
#              beer_ABV  beer_brewerId  beer_name  beer_style  \
# beer_beerId
# 3                   0              3          3           3
# 4                   0             10         10          10
# 5                 424            424        424         424
# 6                 877            877        877         877
# 7                 659            659        659         659
# ...               ...            ...        ...         ...
# 77302               1              1          1           1
# 77303               1              1          1           1
# 77305               1              1          1           1
# 77307               1              1          1           1
# 77310               1              1          1           1
#
#              review_appearance  review_palette  review_overall  review_taste  \
# beer_beerId
# 3                            3               3               3             3
# ...

# %%
font = {
        'color': 'white',
        'size' : 16
         }






plt.subplots(figsize=(20,9))

plt.tick_params(axis='x',labelcolor='white')
plt.tick_params(axis='y',labelcolor='white')

plt.xlabel('X-Axis', labelpad=20, fontdict=font)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font)
sns.heatmap(beer_data.corr(),annot = True )
InteractiveShell.ast_node_interactivity = "all"

# %%
beer_data.drop(['beer_beerId','beer_brewerId'],axis = 1,inplace=True)

# brewId, beerID 임시적으로 드랍 후 name으로 정렬

# %%
a = beer_data.groupby('beer_name').mean()
a
# Out:
#                                         beer_ABV  review_appearance  \
# beer_name
# "100" Pale Ale                               6.6           3.500000
# "33" Export                                  4.8           3.000000
# "76" Anniversary Ale                         7.6           3.666667
# "76" Anniversary Ale With English Hops       7.6           3.500000
# "Fade To Black" Porter                       5.6           4.000000
# ...                                          ...                ...
# Über Pils                                    5.2           3.925439
# ÜberFest Pilsner                             5.2           3.250000
# ÜberSun (Imperial Summer Wheat Beer)         8.0           4.015021
# à L'Agave Et Au Citron Vert                  5.0           2.500000
# überPils                                     7.6           3.928571
#
#                                         review_palette  review_overall  \
# beer_name
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

font = {
        'color': 'white',
        'size' : 16
         }






plt.subplots(figsize=(20,9))

plt.tick_params(axis='x',labelcolor='white')
plt.tick_params(axis='y',labelcolor='white')

plt.xlabel('X-Axis', labelpad=20, fontdict=font)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font)
sns.heatmap(a.corr(),annot = True )
# Out:
# (<Figure size 1440x648 with 1 Axes>, <AxesSubplot:>)
# Text(0.5, 0, 'X-Axis')
# Text(0, 0.5, 'Y-Axis')
# <AxesSubplot:>

# %%
beer_id = pd.read_csv('./Data/BeerProject.csv',encoding = 'latin-1')

# %%
beer_id.drop(['beer_name','beer_brewerId'],axis = 1,inplace=True)

b = beer_id.groupby('beer_beerId').mean()
b
# Out:
#              beer_ABV  review_appearance  review_palette  review_overall  \
# beer_beerId
# 3                 NaN           3.833333        4.000000        4.166667
# 4                 NaN           3.950000        3.800000        3.700000
# 5                 4.5           3.485849        3.205189        3.549528
# 6                 5.6           3.836374        3.515964        3.706956
# 7                 4.2           3.251138        3.179059        3.266313
# ...               ...                ...             ...             ...
# 77302             6.5           3.000000        3.000000        3.500000
# 77303             5.8           4.500000        4.500000        5.000000
# 77305             6.6           4.000000        4.000000        4.000000
# 77307             5.5           5.000000        4.000000        4.000000
# 77310             6.6           3.500000        3.500000        3.500000
#
#              review_taste  review_aroma   review_time
# beer_beerId
# ...

# %%
plt.subplots(figsize=(20,9))

plt.tick_params(axis='x',labelcolor='white')
plt.tick_params(axis='y',labelcolor='white')

plt.xlabel('X-Axis', labelpad=20, fontdict=font)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font)
sns.heatmap(b.corr(),annot = True )
# Out:
# (<Figure size 1440x648 with 1 Axes>, <AxesSubplot:>)
# Text(0.5, 0, 'X-Axis')
# Text(0, 0.5, 'Y-Axis')
# <AxesSubplot:>

# %%
beer_brewid = pd.read_csv('./Data/BeerProject.csv',encoding = 'latin-1')



beer_brewid.drop(['beer_name','beer_beerId'],axis = 1,inplace=True)

c = beer_brewid.groupby('beer_brewerId').mean()
c
# Out:
#                beer_ABV  review_appearance  review_palette  review_overall  \
# beer_brewerId
# 1              4.438688           3.681282        3.436625        3.820192
# 2                   NaN           3.425000        3.250000        3.162500
# 3              5.537475           3.592216        3.383984        3.558802
# 5              4.790072           3.669643        3.580357        3.652473
# 10             4.973214           3.982143        3.723214        3.955357
# ...                 ...                ...             ...             ...
# 27870          6.000000           4.375000        4.250000        4.500000
# 27879          5.500000           3.333333        3.333333        3.500000
# 27917          8.000000           4.500000        4.000000        4.000000
# 27922          7.450000           4.000000        3.833333        3.833333
# 27980          4.666667           3.333333        3.500000        3.500000
#
# ...

# %%
font = {
        'color': 'white',
        'size' : 16
         }






plt.subplots(figsize=(20,9))

plt.tick_params(axis='x',labelcolor='white')
plt.tick_params(axis='y',labelcolor='white')

plt.xlabel('X-Axis', labelpad=20, fontdict=font)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font)
sns.heatmap(c.corr(),annot = True )
# Out:
# (<Figure size 1440x648 with 1 Axes>, <AxesSubplot:>)
# Text(0.5, 0, 'X-Axis')
# Text(0, 0.5, 'Y-Axis')
# <AxesSubplot:>
