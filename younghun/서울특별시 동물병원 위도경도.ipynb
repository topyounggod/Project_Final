# %%
import pandas as pd
import numpy as np
 
animal_hospital = pd.read_csv('D:/OneDrive/DataScience/프로젝트(파이널)/Data/서울열린데이터광장/서울특별시 동물병원 인허가 정보.csv',encoding = 'euc-kr')

# %%
animal_hospital
# Out:
#       개방자치단체코드          관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  상세영업상태코드  \
# 0      3170000  3.170000e+17  20180410      NaN       1  영업/정상         0
# 1      3040000  3.040000e+17  20030926      NaN       1  영업/정상         0
# 2      3220000  3.220000e+17  20210408      NaN       1  영업/정상         0
# 3      3090000  3.090000e+17  20190410      NaN       1  영업/정상         0
# 4      3130000  3.130000e+17  20000211      NaN       1  영업/정상         0
# ...        ...           ...       ...      ...     ...    ...       ...
# 2005   3140000  3.140000e+17  20210820      NaN       1  영업/정상         0
# 2006   3130000  3.130000e+17  20180720      NaN       1  영업/정상         0
# 2007   3230000  3.230000e+17  20210824      NaN       1  영업/정상         0
# 2008   3140000  3.140000e+17  20210825      NaN       1  영업/정상         0
# 2009   3110000  3.110000e+17  20170308      NaN       1  영업/정상         0
#
#      상세영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자          전화번호   소재지면적  소재지우편번호  \
# ...

# %%
animal_hospital[animal_hospital['상세영업상태명']=='폐업']
# Out:
#       개방자치단체코드          관리번호     인허가일자  인허가취소일자  영업상태코드 영업상태명  상세영업상태코드  \
# 22     3000000  3.000000e+17  19950811      NaN       3    폐업         2
# 23     3000000  3.000000e+17  20130311      NaN       3    폐업         2
# 24     3000000  3.000000e+17  19750506      NaN       3    폐업         2
# 25     3000000  3.000000e+17  20130304      NaN       3    폐업         2
# 26     3000000  3.000000e+17  20070323      NaN       3    폐업         2
# ...        ...           ...       ...      ...     ...   ...       ...
# 1975   3150000  3.150000e+17  20180118      NaN       3    폐업         2
# 1976   3040000  3.040000e+17  20150721      NaN       3    폐업         2
# 1977   3110000  3.110000e+17  20150526      NaN       3    폐업         2
# 1979   3130000  3.130000e+17  20180831      NaN       3    폐업         2
# 1980   3130000  3.130000e+17  20140306      NaN       3    폐업         2
#
#      상세영업상태명        폐업일자  휴업시작일자  휴업종료일자  재개업일자         전화번호  소재지면적  소재지우편번호  \
# ...

# %%
animal_hospital = animal_hospital[animal_hospital['상세영업상태명']!='폐업']

# %%
animal_hospital
# Out:
#       개방자치단체코드          관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  상세영업상태코드  \
# 0      3170000  3.170000e+17  20180410      NaN       1  영업/정상         0
# 1      3040000  3.040000e+17  20030926      NaN       1  영업/정상         0
# 2      3220000  3.220000e+17  20210408      NaN       1  영업/정상         0
# 3      3090000  3.090000e+17  20190410      NaN       1  영업/정상         0
# 4      3130000  3.130000e+17  20000211      NaN       1  영업/정상         0
# ...        ...           ...       ...      ...     ...    ...       ...
# 2005   3140000  3.140000e+17  20210820      NaN       1  영업/정상         0
# 2006   3130000  3.130000e+17  20180720      NaN       1  영업/정상         0
# 2007   3230000  3.230000e+17  20210824      NaN       1  영업/정상         0
# 2008   3140000  3.140000e+17  20210825      NaN       1  영업/정상         0
# 2009   3110000  3.110000e+17  20170308      NaN       1  영업/정상         0
#
#      상세영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자          전화번호   소재지면적  소재지우편번호  \
# ...

# %%
import googlemaps
import pandas as pd
places = animal_hospital['도로명주소']
my_key = ""
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 서울특별시 금천구 시흥대로 172 서우빌딩 (시흥동)의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시 광진구 광나루로 507 (구의동)의 위치를 찾고있습니다
# 3번 인덱스에서 서울특별시 강남구 삼성로133길 7 베디베로스퀘어 5층 (청담동)의 위치를 찾고있습니다
# 4번 인덱스에서 서울특별시 도봉구 도봉로 669 1층 (방학동)의 위치를 찾고있습니다
# 5번 인덱스에서 서울특별시 마포구 독막로 45 (합정동)의 위치를 찾고있습니다
# 6번 인덱스에서 서울특별시 중구 을지로38길 20 뉴천지관광호텔 2층 (을지로5가)의 위치를 찾고있습니다
# 7번 인덱스에서 서울특별시 중구 을지로38길 20 뉴천지관광호텔 1층 (을지로5가)의 위치를 찾고있습니다
# 8번 인덱스에서 서울특별시 중구 을지로38길 20 뉴천지관광호텔 1층 (을지로5가)의 위치를 찾고있습니다
# 9번 인덱스에서 서울특별시 노원구 마들로3길 15 월계이마트 2층 (월계동)의 위치를 찾고있습니다
# 10번 인덱스에서 서울특별시 강남구 삼성로 11 상가동 103104호 (개포동 디에이치아너힐즈)의 위치를 찾고있습니다
# 11번 인덱스에서 서울특별시 서초구 강남대로 525-3 (반포동)의 위치를 찾고있습니다
# 12번 인덱스에서 서울특별시 은평구 연서로 137 (구산동)의 위치를 찾고있습니다
# 13번 인덱스에서 서울특별시 강북구 삼양로27길 35-21 미아프라자 106호 (미아동)의 위치를 찾고있습니다
# 14번 인덱스에서 서울특별시 종로구 자하문로 293 (홍지동)의 위치를 찾고있습니다
# 15번 인덱스에서 서울특별시 종로구 자하문로 305 (홍지동)의 위치를 찾고있습니다
# 16번 인덱스에서 서울특별시 종로구 진흥로 473 (신영동)의 위치를 찾고있습니다
# 17번 인덱스에서 서울특별시 성북구 동소문로 73 1층 (동소문동6가 시티플레이스)의 위치를 찾고있습니다
# 18번 인덱스에서 서울특별시 서초구 신반포로 162 (반포동 르본시티 2층)의 위치를 찾고있습니다
# ...

# %%
df_fin = pd.concat([animal_hospital,df],axis = 1)

df_fin.to_csv('동물병원위도경도.csv',encoding='utf-8')
