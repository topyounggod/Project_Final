# %%
import pandas as pd
import numpy as np

animal_beauty = pd.read_csv('./data/동물미용업최최종(utf-8).csv',encoding = 'utf-8')

# %%
animal_beauty
# Out:
#       Unnamed: 0             구분            업체명          전화번호  \
# 0              0             미용         사계절, 몽   ***********
# 1              1             미용           허그댕댕   ***********
# 2              2             미용  한국반려동물아카데미뷰티샵  02-6959-3965
# 3              3          판매 미용            레인독   ***********
# 4              4  판매 전시 위탁관리 미용          미션코리아   ***********
# ...          ...            ...            ...           ...
# 8108        8121        위탁관리 미용           이쁜이네   ***********
# 8109        8122     위탁관리 미용 운송        제주애견카페왈   ***********
# 8110        8123             미용         메이비펫살롱   ***********
# 8111        8124        위탁관리 미용         몽블리 펫샵   ***********
# 8112        8125        위탁관리 미용          도그스토리   ***********
#
#                        소재지               인허가번호
# 0            서울특별시 종로구 숭인동  300000003720210002
# 1            서울특별시 종로구 창신동  300000003720210001
# 2            서울특별시 종로구 숭인동  300000003720190006
# ...

# %%
import googlemaps
import pandas as pd
places = animal_beauty['업체명']
my_key = ""
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 사계절, 몽의 위치를 찾고있습니다
# 2번 인덱스에서 허그댕댕의 위치를 찾고있습니다
# 2번 인덱스 위치를 찾는데 실패했습니다.
# 3번 인덱스에서 한국반려동물아카데미뷰티샵의 위치를 찾고있습니다
# 4번 인덱스에서 레인독의 위치를 찾고있습니다
# 5번 인덱스에서 미션코리아의 위치를 찾고있습니다
# 6번 인덱스에서 Dog star의 위치를 찾고있습니다
# 7번 인덱스에서 광화문동물병원의 위치를 찾고있습니다
# 8번 인덱스에서 누리봄동물병원의 위치를 찾고있습니다
# 9번 인덱스에서 대학로동물병원의 위치를 찾고있습니다
# 10번 인덱스에서 홍주스컵의 위치를 찾고있습니다
# 11번 인덱스에서 경희궁바른동물병원의 위치를 찾고있습니다
# 12번 인덱스에서 아지나라의 위치를 찾고있습니다
# 13번 인덱스에서 월드펫동물병원의 위치를 찾고있습니다
# 14번 인덱스에서 이쁜아이의 위치를 찾고있습니다
# 15번 인덱스에서 북악동물병원의 위치를 찾고있습니다
# 16번 인덱스에서 서촌도그살롱의 위치를 찾고있습니다
# 17번 인덱스에서 나나애견미용의 위치를 찾고있습니다
# 18번 인덱스에서 스타독의 위치를 찾고있습니다
# 19번 인덱스에서 웰펫동물병원의 위치를 찾고있습니다
# 20번 인덱스에서 메종동물병원의 위치를 찾고있습니다
# 21번 인덱스에서 강아지 마법사 골드맘의 위치를 찾고있습니다
# 21번 인덱스 위치를 찾는데 실패했습니다.
# 22번 인덱스에서 애니컴 메디컬센터의 위치를 찾고있습니다
# 23번 인덱스에서 애뚜애뚜의 위치를 찾고있습니다
# 24번 인덱스에서 미래지동물의료센터의 위치를 찾고있습니다
# 25번 인덱스에서 좋아요동물병원의 위치를 찾고있습니다
# 26번 인덱스에서 백슬동물병원의 위치를 찾고있습니다
# 27번 인덱스에서 남산동물병원의 위치를 찾고있습니다
# 28번 인덱스에서 바른동물병원의 위치를 찾고있습니다
# 29번 인덱스에서 COZY의 위치를 찾고있습니다
# 30번 인덱스에서 바우미우동물병원의 위치를 찾고있습니다
# ...

# %%
df_fin = pd.concat([animal_beauty,df],axis = 1)

df_fin.to_csv('동물미용업경도(euc-kr).csv',encoding='euc-kr')
