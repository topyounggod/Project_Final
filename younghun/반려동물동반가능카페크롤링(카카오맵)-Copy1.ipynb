# %%
gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
           '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
           '강남구','서초구','관악구','동작구','영등포구','금천구','구로구','양천구','강서구']

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse


def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "})
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": ""})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long

gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
           '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
           '강남구','서초구','관악구','동작구','영등포구','금천구','구로구','양천구','강서구']

results = []

for find in gu_list : 
# find =  input('검색할 정보를 입력하세요 : ')
    time.sleep(10)

    driver = webdriver.Chrome(
        executable_path= "chromedriver.exe"
    )
    url = "https://m.map.naver.com/"
    driver.get(url)
    action = ActionChains(driver)

    time.sleep(4)
    driver.find_element_by_class_name('Nbox_input_text').click()

    driver.find_element_by_class_name('Nbox_input_text._search_input').send_keys(find + ' 애견동반 카페')
    driver.find_element_by_xpath('//*[@id="ct"]/div[1]/div[1]/form/div/div[2]/div/span[2]/button[2]').click()

    time.sleep(4)
    replys =driver.find_elements_by_xpath('//*[@id="ct"]/div[2]/ul/li')
    print(len(replys))

    for index, reply in enumerate(replys):
            name = reply.find_element_by_css_selector('div.item_tit').text
            address =reply.find_element_by_css_selector('div.wrap_item').text.split('\n')[2]
            latitude = address_to_latitude(address)
            longtitude = address_to_longtitude(address)
            results.append((name, address, latitude, longtitude))

results

import pandas as pd
data_frame = pd.DataFrame(results, columns=['name', 'address',"lat","long"])
data_frame
# Out:
# 32
# 28
# 18
# 12
# 8
# 16
# 16
# 11
# 9
# 17
# 7
# 7
# 7
# 3
# 12
# 20
# 30
# 20
# 6
# 8
# 25
# 2
# 5
# 9
# 10
#                name                             address               lat  \
# 0           풀스트릿브런치           서울특별시 마포구 동교로51안길 16 풀스트릿  37.5652702034365
# 1    인솔커피 상수점카페,디저트     서울특별시 마포구 독막로18길 16 1층 인솔커피 상수점   37.547120809022
# 2        코코샌드카페,디저트            서울특별시 마포구 양화로23길 22-7 2층   37.559672616523
# 3         연트럴다방베이커리              서울특별시 마포구 동교로41길 32 지층   37.563781611519
# 4     커피 벌스데이카페,디저트  서울특별시 마포구 와우산로29길 26-33 1층 커피 벌스데이  37.5555320036647
# ..              ...                                 ...               ...
# 333     냉큼오레오반려동물미용        서울특별시 강서구 화곡로58길 39 2층 냉큼오레오   37.552827477763
# 334          카페히든카페             서울특별시 양천구 목동동로 222-6 1층  37.5253195782646
# 335    카페 아리네카페,디저트               서울특별시 양천구 목동동로 222-11   37.525370422165
# 336    카페일월십일카페,디저트            서울특별시 양천구 목동중앙남로9길 41 1층  37.5378713602665
# 337     프로메나드카페,디저트           경기도 고양시 덕양구 행주산성로120번길 43  37.6010901044203
#
#                  long
# 0    126.924633178184
# 1    126.923551532294
# 2    126.925252364024
# 3    126.923564504764
# 4    126.928765669556
# ..                ...
# 333   126.85307945629
# 334   126.87218967494
# 335   126.87271563263
# 336   126.86414671847
# 337  126.816985086539
#
# [338 rows x 4 columns]

# %%
data_frame.drop_duplicates(ignore_index = True, inplace = True)

# %%
data_frame
# Out:
#                   name                                 address  \
# 0              풀스트릿브런치               서울특별시 마포구 동교로51안길 16 풀스트릿
# 1       인솔커피 상수점카페,디저트         서울특별시 마포구 독막로18길 16 1층 인솔커피 상수점
# 2           코코샌드카페,디저트                서울특별시 마포구 양화로23길 22-7 2층
# 3            연트럴다방베이커리                  서울특별시 마포구 동교로41길 32 지층
# 4        커피 벌스데이카페,디저트      서울특별시 마포구 와우산로29길 26-33 1층 커피 벌스데이
# ..                 ...                                     ...
# 116        OMW애견카페애견카페  서울특별시 강서구 화곡로 194-26 1층 OMW dog's cafe
# 117           커멍커멍애견카페       서울특별시 강서구 강서로 385 우성SB타워 10층 커멍커멍
# 118         지디파크카페,디저트               서울특별시 강서구 양천로27길 167 지디파크
# 119  댕댕브라더스 Cafe카페,디저트             서울특별시 강서구 공항대로7길 32 1층 102호
# 120        프로메나드카페,디저트               경기도 고양시 덕양구 행주산성로120번길 43
#
#                   lat              long
# 0    37.5652702034365  126.924633178184
# 1     37.547120809022  126.923551532294
# 2     37.559672616523  126.925252364024
# 3     37.563781611519  126.923564504764
# 4    37.5555320036647  126.928765669556
# ..                ...               ...
# 116  37.5419994925673  126.842613580388
# 117  37.5600926354663  126.838304106686
# 118  37.5804007829397  126.819472494423
# 119  37.5624219648256  126.813145790114
# 120  37.6010901044203  126.816985086539
#
# [121 rows x 4 columns]

# %%
data_frame.to_csv('withdogcafe.csv')
