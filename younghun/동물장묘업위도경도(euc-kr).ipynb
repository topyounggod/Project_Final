# %%
import pandas as pd
import numpy as np

animal_funeral = pd.read_csv('./data/동물장묘업최최종(UTF-8).csv',encoding = 'utf-8')

# %%
animal_funeral
# Out:
#     Unnamed: 0             업체명          전화번호      소재지            영업내용  \
# 0            0           무지개언덕  044-863-7075      세종시      장례, 화장, 봉안
# 1            1            파트라슈  051-723-2201   부산 기장군      장례, 화장, 봉안
# 2            2        센트럴파크(주)  051-728-5411   부산 기장군      장례, 화장, 봉안
# 3            3             아이별  051-727-4499   부산 기장군      장례, 화장, 봉안
# 4            4           대구러브펫  053-593-4900   대구 달서구              장례
# 5            5             어게인  032-566-1936    인천 서구              봉안
# 6            6          ㈜더 포에버  032-713-5002    인천 서구          장례, 봉안
# 7            7            ㈜하늘펫  062-946-2626   광주 광산구              장례
# 8            8            이별공간   ***********   울산 울주군      장례, 화장, 봉안
# 9            9           ㈜펫바라기  031-976-3179   경기 고양시      장례, 화장, 봉안
# 10          10          몽몽이엠파크     1811-1336  경기 남양주시      장례, 화장, 봉안
# 11          11             리멤버  080-200-5004   경기 용인시      장례, 화장, 봉안
# ...

# %%
import googlemaps
import pandas as pd
places = animal_funeral['업체명']
my_key = "AIzaSyDxJfWgx6JLsZb_neXxi6at2bfMsurvaO0"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 무지개언덕의 위치를 찾고있습니다
# 2번 인덱스에서 파트라슈의 위치를 찾고있습니다
# 3번 인덱스에서 센트럴파크(주)의 위치를 찾고있습니다
# 4번 인덱스에서 아이별의 위치를 찾고있습니다
# 5번 인덱스에서 대구러브펫의 위치를 찾고있습니다
# 6번 인덱스에서 어게인의 위치를 찾고있습니다
# 7번 인덱스에서 ㈜더 포에버의 위치를 찾고있습니다
# 8번 인덱스에서 ㈜하늘펫의 위치를 찾고있습니다
# 9번 인덱스에서 이별공간의 위치를 찾고있습니다
# 10번 인덱스에서 ㈜펫바라기의 위치를 찾고있습니다
# 11번 인덱스에서 몽몽이엠파크의 위치를 찾고있습니다
# 12번 인덱스에서 리멤버의 위치를 찾고있습니다
# 13번 인덱스에서 씨엘로펫의 위치를 찾고있습니다
# 14번 인덱스에서 ㈜아리아펫의 위치를 찾고있습니다
# 15번 인덱스에서 마스꼬따 휴㈜의 위치를 찾고있습니다
# 16번 인덱스에서 페트나라의 위치를 찾고있습니다
# 17번 인덱스에서 (주)하이루의 위치를 찾고있습니다
# 18번 인덱스에서 아이드림펫의 위치를 찾고있습니다
# 19번 인덱스에서 ㈜위디안(엔젤스톤)의 위치를 찾고있습니다
# 20번 인덱스에서 펫오케스트라의 위치를 찾고있습니다
# 21번 인덱스에서 강아지넷의 위치를 찾고있습니다
# 22번 인덱스에서 (주)우리반려동물문화원의 위치를 찾고있습니다
# 23번 인덱스에서 스토리펫의 위치를 찾고있습니다
# 24번 인덱스에서 ㈜펫포레스트의 위치를 찾고있습니다
# 25번 인덱스에서 21그램 반려동물 장례식장의 위치를 찾고있습니다
# 26번 인덱스에서 ㈜해피엔딩의 위치를 찾고있습니다
# 27번 인덱스에서 백꽃사랑하이빛의 위치를 찾고있습니다
# 28번 인덱스에서 하늘애의 위치를 찾고있습니다
# 29번 인덱스에서 러브펫의 위치를 찾고있습니다
# 30번 인덱스에서 더 고마워의 위치를 찾고있습니다
# 31번 인덱스에서 스타펫의 위치를 찾고있습니다
# 32번 인덱스에서 강릉 펫사랑의 위치를 찾고있습니다
# 33번 인덱스에서 펫 메모리얼의 위치를 찾고있습니다
# ...

# %%
df_fin = pd.concat([animal_funeral,df],axis = 1)

df_fin.to_csv('동물장묘업경도(euc-kr).csv',encoding='euc-kr')
