# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
db = client['practice_01']

# %%
park = db['park']
beauty = db['beauty']
cafe = db['cafe']
deliver = db['deliver']
equip = db['equip']
food = db['food']
# funeral = db['funeral']
hospital = db['hospital']
manage = db['manage']
# medical = db['medical_equip']
pharmacy = db['pharmacy']
play = db['play']
restaurant = db['restaurant']
sell = db['sell']
shelter = db['shelter']

# %%
collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage',
               'medical','pharmacy','play','restaurant','sell','shelter']

# %%
from pymongo import GEOSPHERE

for collection in collections :
    db[collection].create_index([('geometry',GEOSPHERE)])

# %%
a = []
# 0.0005 = 500m
x = 37.584980
y = 127.031133
while x < 37.612181:
    y = 127.031133
    while y < 127.058599:
        a.append((y,x))
        y += 0.0005
        y = round(y,6)
    a.append((y,x))
    x += 0.0005
    x = round(x,6)

# %%
len(a)
# Out:
# 3080

# %%
import numpy as np
from geojson import Point, Feature, FeatureCollection, dump
# a = np.random.randint(37584980, 37612181, size=5000) / 1000000
# b = np.random.randint(127031133,127058599,size = 5000) / 1000000
# 진짜 서울시 위도 경도
# a = np.random.randint(37413294, 37715133, size=10000) / 1000000
# b = np.random.randint(127269311,127734086,size = 10000) / 1000000


counts1 = []
for i in range(0,len(a)): 
    c = list(park.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
            
        }]
    ))
    counts1.append(len(c))

# %%
counts2 = []
for i in range(0,len(a)): 
    c = list(beauty.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts2.append(len(c))

# %%
counts3 = []
for i in range(0,len(a)): 
    c = list(cafe.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts3.append(len(c))

# %%
counts4 = []
for i in range(0,len(a)): 
    c = list(deliver.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts4.append(len(c))

# %%
counts5 = []
for i in range(0,len(a)): 
    c = list(equip.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts5.append(len(c))

# %%
counts6 = []
for i in range(0,len(a)): 
    c = list(food.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts6.append(len(c))

# %%
# counts7 = []
# for i in range(0,len(a)): 
#     c = list(funeral.aggregate(
#         [{
#             "$geoNear": {
#                 "near": { "type": "Point", "coordinates": a[i] },
#                 "distanceField": 'meters',
#                 "maxDistance": 2000
#             }
#         }]
#     ))
#     counts7.append(len(c))

# %%
counts8 = []
for i in range(0,len(a)): 
    c = list(hospital.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts8.append(len(c))

# %%
counts9 = []
for i in range(0,len(a)): 
    c = list(manage.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts9.append(len(c))

# %%
# counts10 = []
# for i in range(0,len(a)): 
#     c = list(medical.aggregate(
#         [{
#             "$geoNear": {
#                 "near": { "type": "Point", "coordinates": a[i] },
#                 "distanceField": 'meters',
#                 "maxDistance": 1500
#             }
#         }]
#     ))
#     counts10.append(len(c))

# %%
counts11 = []
for i in range(0,len(a)): 
    c = list(pharmacy.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts11.append(len(c))

# %%
counts12 = []
for i in range(0,len(a)): 
    c = list(play.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts12.append(len(c))

# %%
counts13 = []
for i in range(0,len(a)): 
    c = list(restaurant.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts13.append(len(c))

# %%
counts14 = []
for i in range(0,len(a)): 
    c = list(sell.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts14.append(len(c))

# %%
counts15 = []
for i in range(0,len(a)): 
    c = list(shelter.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts15.append(len(c))

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
df['cafe'] = counts3
df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
df['play'] = counts12
df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
df.mean()
# Out:
# park          2.344481
# beauty        3.699675
# cafe          0.290584
# deliver       0.289935
# equip         1.662987
# food          1.221104
# hospital      2.595130
# manage        1.072403
# pharmacy      4.468831
# play          0.680844
# restaurant    1.083442
# sell          6.261688
# dtype: float64

# %%
df1 = pd.DataFrame()

# %%
df1 = df.mean()

# %%
df1
# Out:
# park          2.344481
# beauty        3.699675
# cafe          0.290584
# deliver       0.289935
# equip         1.662987
# food          1.221104
# hospital      2.595130
# manage        1.072403
# pharmacy      4.468831
# play          0.680844
# restaurant    1.083442
# sell          6.261688
# dtype: float64

# %%
df_mean = (df - df1)/df1

# %%
df_mean
# Out:
#           park    beauty      cafe   deliver     equip      food  hospital  \
# 0     0.279601 -1.000000 -1.000000 -1.000000  0.202655  2.275725 -0.614663
# 1     0.279601 -1.000000 -1.000000 -1.000000  0.202655  2.275725 -0.614663
# 2     0.706135 -1.000000 -1.000000 -1.000000  0.202655  3.913587 -0.614663
# 3     0.706135 -1.000000 -1.000000 -1.000000  0.202655  3.913587 -1.000000
# 4     0.706135 -1.000000 -1.000000 -1.000000  0.202655  3.913587 -1.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 3075 -0.146933  0.351470  2.441341 -1.000000  0.803983  2.275725  0.541349
# 3076 -0.146933  0.351470  2.441341 -1.000000  0.803983  2.275725  0.541349
# 3077 -0.146933  0.351470  2.441341 -1.000000  0.803983  2.275725  0.541349
# 3078 -0.146933  0.351470  2.441341 -1.000000  0.803983  2.275725  0.541349
# 3079 -0.573466  0.621764  2.441341  2.449048  0.202655  2.275725  0.541349
#
#         manage  pharmacy      play  restaurant      sell
# 0    -1.000000 -1.000000  0.468765    1.768954 -0.201493
# 1    -1.000000 -1.000000  0.468765    1.768954 -0.201493
# 2    -1.000000 -1.000000  0.468765    1.768954 -0.201493
# 3    -1.000000 -1.000000  0.468765    1.768954 -0.201493
# 4    -1.000000 -1.000000  0.468765    1.768954 -0.201493
# ...        ...       ...       ...         ...       ...
# 3075 -0.067514  0.790177 -1.000000    1.768954  0.277611
# 3076 -0.067514  1.237722 -1.000000    1.768954  0.277611
# 3077 -1.000000  1.237722 -1.000000    1.768954 -0.041792
# 3078 -1.000000  1.461494 -1.000000    1.768954  0.117909
# 3079 -0.067514  1.461494 -1.000000    1.768954  0.437312
#
# [3080 rows x 12 columns]

# %%
# df_int = df

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kmeans = KMeans(n_clusters = 20)

# %%
kmeans.fit(df)
# Out:
# KMeans(n_clusters=20)

# %%
labels = kmeans.fit_predict(df)

# %%
df['cluster'] = kmeans.labels_

# %%
df
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 0        3       0     0        0      2     4         1       0         0
# 1        3       0     0        0      2     4         1       0         0
# 2        4       0     0        0      2     6         1       0         0
# 3        4       0     0        0      2     6         0       0         0
# 4        4       0     0        0      2     6         0       0         0
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 3075     2       5     1        0      3     4         4       1         8
# 3076     2       5     1        0      3     4         4       1        10
# 3077     2       5     1        0      3     4         4       0        10
# 3078     2       5     1        0      3     4         4       0        11
# 3079     1       6     1        1      2     4         4       1        11
#
#       play  restaurant  sell  cluster
# 0        1           3     5       12
# 1        1           3     5       12
# 2        1           3     5       12
# 3        1           3     5       12
# 4        1           3     5       12
# ...    ...         ...   ...      ...
# 3075     0           3     8       11
# 3076     0           3     8       11
# 3077     0           3     6       11
# 3078     0           3     7       11
# 3079     0           3     9       11
#
# [3080 rows x 13 columns]

# %%
# df.mean()

# %%
# park_m = df['park'].describe()['mean']
# beauty_m = df['beauty'].describe()['mean']
# cafe_m = df['cafe'].describe()['mean']
# deliver_m = df['deliver'].describe()['mean']
# equip_m = df['equip'].describe()['mean']
# food_m = df['food'].describe()['mean']
# hospital_m = df['hospital'].describe()['mean']
# manage_m = df['manage'].describe()['mean']
# pharmacy_m = df['pharmacy'].describe()['mean']
# play_m = df['play'].describe()['mean']
# restaurant_m = df['restaurant'].describe()['mean']
# sell_m = df['sell'].describe()['mean']

# %%
# type(park_m)

# %%
# print(park_m)

# %%
# print(a)
# 각 피쳐에서 평균 빼면 % 나옴

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
print('실루엣 스코어는 : {0:.3f}'.format(silhouette_score(df,labels)))
# Out:
# 실루엣 스코어는 : 0.458

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(df)

# %%
df['pca_x'] = pca_transformed[:,0] #첫번째 값(X 좌표)
df['pca_y']=pca_transformed[:,1] #첫번째 값(y 좌표)
df.head(3)
# Out:
#    park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  play  \
# 0     3       0     0        0      2     4         1       0         0     1
# 1     3       0     0        0      2     4         1       0         0     1
# 2     4       0     0        0      2     6         1       0         0     1
#
#    restaurant  sell  cluster     pca_x     pca_y
# 0           3     5       12 -1.727361 -5.087147
# 1           3     5       12 -1.727361 -5.087147
# 2           3     5       12 -1.667119 -5.112896

# %%
# 산점도로 표현 : 군집별로 다른 색상으로 표시
plt.scatter(x=df.loc[:,'pca_x'], y=df.loc[:,'pca_y'], c=df['cluster'])
# 조금 다름

# %%
#collections = ['park','beauty','equip','food','hospital','manage','pharmacy','sell','cluster']
collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage','pharmacy','play','restaurant','sell']
for collection in collections:
    print(df[collection].value_counts())
# Out:
# 2    1506
# 1     581
# 3     515
# 4     307
# 5     171
# Name: park, dtype: int64
# 2     636
# 3     452
# 1     346
# 6     312
# 0     286
# 4     281
# 5     253
# 7     185
# 8     165
# 9     104
# 10     51
# 11      9
# Name: beauty, dtype: int64
# 0    2258
# 1     749
# 2      73
# Name: cafe, dtype: int64
# 0    2586
# 1     295
# 3     198
# 4       1
# Name: deliver, dtype: int64
# 1    943
# 2    761
# 0    664
# 3    389
# 4    203
# 5     63
# 6     36
# 7     21
# Name: equip, dtype: int64
# 0    1124
# 1    1015
# 2     460
# 3     232
# 4     196
# 6      22
# 7      10
# 8       9
# 5       9
# 9       3
# Name: food, dtype: int64
# 2     803
# 3     569
# 1     555
# 0     407
# 4     255
# 6     183
# 7     125
# 5     117
# 8      49
# 9      15
# 10      2
# Name: hospital, dtype: int64
# 0    1239
# 1     876
# 2     557
# 3     321
# 4      85
# 5       2
# Name: manage, dtype: int64
# 4     578
# 2     441
# 0     330
# 5     298
# 7     280
# 6     260
# 3     249
# 8     227
# 1     147
# 9      89
# 10     80
# 11     41
# 14     35
# 12     17
# 13      8
# Name: pharmacy, dtype: int64
# 0    1480
# 1    1178
# 2     347
# 3      75
# Name: play, dtype: int64
# 1    1230
# 0    1051
# 3     509
# 2     290
# Name: restaurant, dtype: int64
# 5     415
# 7     351
# 3     338
# 6     267
# 4     239
# 8     212
# 2     204
# 1     185
# 0     157
# 9     156
# 10    130
# 11    107
# 12     80
# 20     52
# 13     40
# 19     29
# 15     24
# 16     23
# 17     23
# 18     21
# 14     18
# 21      6
# 22      3
# Name: sell, dtype: int64

# %%
# collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage','pharmacy','play','restaurant','sell','cluster']
# for collection in collections:
#     print(df[collection].value_counts())

# %%
# a = (df[collections]['park'].value_counts())
# print(a)

# %%
# for b in a:
#     print(((b-park_m)/park_m))

# %%
df[df['cluster']== 7]
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 1416     2       5     1        0      1     0         5       0         7
# 1417     2       5     1        0      1     0         5       0         7
# 1469     2       5     1        0      1     0         6       0         7
# 1470     2       5     1        0      1     0         6       0         7
# 1471     2       5     1        0      1     0         6       0         7
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 2089     2       7     1        0      2     1         5       1         7
# 2090     2       6     1        0      2     1         4       0         6
# 2145     2       7     1        0      2     1         5       1         6
# 2538     3       6     1        0      2     1         6       1         6
# 2645     3       6     1        0      4     1         6       2         7
#
#       play  restaurant  sell  cluster     pca_x     pca_y
# 1416     0           1     6        7  0.156111  2.609444
# 1417     0           1     6        7  0.156111  2.609444
# 1469     0           1     7        7  0.914883  3.335363
# 1470     0           1     7        7  0.914883  3.335363
# 1471     0           1     7        7  0.914883  3.335363
# ...    ...         ...   ...      ...       ...       ...
# 2089     0           1     9        7  2.590653  4.888636
# 2090     0           1     7        7  0.573014  3.120361
# 2145     0           1     9        7  2.252187  4.723353
# 2538     0           1     9        7  2.195697  4.642622
# 2645     0           1     9        7  2.876218  5.051765
#
# [127 rows x 15 columns]

# %%
df[df['cluster']== 2]
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 950      2       8     0        0      2     2         4       4         9
# 951      2       8     0        0      2     2         4       4        10
# 1004     2       8     0        0      2     2         4       4        10
# 1005     2       8     0        0      2     2         4       4        10
# 1006     2       8     0        0      2     2         4       4        10
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 2921     3       6     0        1      6     0         5       3        10
# 2977     3       5     0        1      6     0         4       3        11
# 2978     3       5     0        1      5     0         4       3         9
# 3033     3       5     0        1      5     0         4       3        11
# 3034     3       5     0        1      5     0         4       3        10
#
#       play  restaurant  sell  cluster     pca_x      pca_y
# 950      1           0    11        2  1.351857  10.107796
# 951      1           0    11        2  1.690322  10.273079
# 1004     1           0     9        2  0.629376   9.242636
# 1005     1           0     9        2  0.629376   9.242636
# 1006     1           0    11        2  1.690322  10.273079
# ...    ...         ...   ...      ...       ...        ...
# 2921     0           1    12        2  2.322675  10.875702
# 2977     0           1    14        2  3.189171  11.562898
# 2978     0           1    14        2  2.383868  11.142411
# 3033     0           1    12        2  1.999853  10.442535
# 3034     0           1    12        2  1.661387  10.277251
#
# [121 rows x 15 columns]

# %%
a[665]
# Out:
# (127.055633, 37.59048)

# %%
a[2287]
# Out:
# (127.054633, 37.60498)

# %%
def visualize_silhouette(cluster_lists, X_features): 
    
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
visualize_silhouette([5,6,7,8,9],df)

# %%
visualize_silhouette([10,11,12,13,14,15],df)

# %%
visualize_silhouette([16,17,18,19],df)

# %%
visualize_silhouette([20,21,22],df)

# %%
visualize_silhouette([23,24,25],df)

# %%
visualize_silhouette([35,36,37,38,39,40],df)

# %% [markdown]
# # DBScan

# %%
import pandas as pd
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
#df['cafe'] = counts3
#df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
#df['play'] = counts12
#df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1.5, min_samples =26, metric='euclidean')
dbscan_labels = dbscan.fit_predict(df)

# %%
df['dbscan_cluster'] = dbscan_labels

# %%
df

# %%
df['dbscan_cluster'].value_counts()

# %%
df[df['dbscan_cluster']==0]

# %%
a[27]

# %%
a[146]

# %%
# 값이 조금씩 다르게 나온다
