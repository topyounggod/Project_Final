# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
db = client['practice_01']

# %%
park = db['park']
beauty = db['beauty']
cafe = db['cafe']
deliver = db['deliver']
equip = db['equip']
food = db['food']
# funeral = db['funeral']
hospital = db['hospital']
manage = db['manage']
# medical = db['medical_equip']
pharmacy = db['pharmacy']
play = db['play']
restaurant = db['restaurant']
sell = db['sell']
shelter = db['shelter']

# %%
collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage',
               'medical','pharmacy','play','restaurant','sell','shelter']

# %%
from pymongo import GEOSPHERE

for collection in collections :
    db[collection].create_index([('geometry',GEOSPHERE)])

# %%
# a = []
# # 0.0005 = 500m
# x = 37.584980
# y = 127.031133
# while x < 37.612181:
#     y = 127.031133
#     while y < 127.058599:
#         a.append((y,x))
#         y += 0.0005
#         y = round(y,6)
#     a.append((y,x))
#     x += 0.0005
#     x = round(x,6)

# %%
a = []
# 0.000 = 500m
x = 37.493239
y = 126.859507
while x < 37.612256:
    y = 126.859507
    while y < 127.222113:
        a.append((y,x))
        y += 0.005
        y = round(y,6)
    a.append((y,x))
    x += 0.005
    x = round(x,6)

# %%
len(a)
# Out:
# 1776

# %%
import numpy as np
from geojson import Point, Feature, FeatureCollection, dump
# a = np.random.randint(37584980, 37612181, size=5000) / 1000000
# b = np.random.randint(127031133,127058599,size = 5000) / 1000000
# 진짜 서울시 위도 경도
# a = np.random.randint(37413294, 37715133, size=10000) / 1000000
# b = np.random.randint(127269311,127734086,size = 10000) / 1000000


counts1 = []
for i in range(0,len(a)): 
    c = list(park.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
            
        }]
    ))
    counts1.append(len(c))

# %%
counts2 = []
for i in range(0,len(a)): 
    c = list(beauty.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts2.append(len(c))

# %%
counts3 = []
for i in range(0,len(a)): 
    c = list(cafe.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts3.append(len(c))

# %%
counts4 = []
for i in range(0,len(a)): 
    c = list(deliver.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts4.append(len(c))

# %%
counts5 = []
for i in range(0,len(a)): 
    c = list(equip.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts5.append(len(c))

# %%
counts6 = []
for i in range(0,len(a)): 
    c = list(food.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts6.append(len(c))

# %%
# counts7 = []
# for i in range(0,len(a)): 
#     c = list(funeral.aggregate(
#         [{
#             "$geoNear": {
#                 "near": { "type": "Point", "coordinates": a[i] },
#                 "distanceField": 'meters',
#                 "maxDistance": 2000
#             }
#         }]
#     ))
#     counts7.append(len(c))

# %%
counts8 = []
for i in range(0,len(a)): 
    c = list(hospital.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts8.append(len(c))

# %%
counts9 = []
for i in range(0,len(a)): 
    c = list(manage.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts9.append(len(c))

# %%
# counts10 = []
# for i in range(0,len(a)): 
#     c = list(medical.aggregate(
#         [{
#             "$geoNear": {
#                 "near": { "type": "Point", "coordinates": a[i] },
#                 "distanceField": 'meters',
#                 "maxDistance": 1500
#             }
#         }]
#     ))
#     counts10.append(len(c))

# %%
counts11 = []
for i in range(0,len(a)): 
    c = list(pharmacy.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts11.append(len(c))

# %%
counts12 = []
for i in range(0,len(a)): 
    c = list(play.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts12.append(len(c))

# %%
counts13 = []
for i in range(0,len(a)): 
    c = list(restaurant.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts13.append(len(c))

# %%
counts14 = []
for i in range(0,len(a)): 
    c = list(sell.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts14.append(len(c))

# %%
counts15 = []
for i in range(0,len(a)): 
    c = list(shelter.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1000
            }
        }]
    ))
    counts15.append(len(c))

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
df['cafe'] = counts3
df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
df['play'] = counts12
df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
df.mean()
# Out:
# park           2.309122
# beauty         7.369369
# cafe           0.963401
# deliver        0.787162
# equip          4.565315
# food           5.859797
# hospital       4.370495
# manage         3.333333
# pharmacy       8.479167
# play           0.311374
# restaurant     3.664977
# sell          13.121622
# dtype: float64

# %%
df1 = pd.DataFrame()

# %%
df1 = df.mean()

# %%
df1
# Out:
# park           2.309122
# beauty         7.369369
# cafe           0.963401
# deliver        0.787162
# equip          4.565315
# food           5.859797
# hospital       4.370495
# manage         3.333333
# pharmacy       8.479167
# play           0.311374
# restaurant     3.664977
# sell          13.121622
# dtype: float64

# %%
df_mean = (df - df1)/df1

# %%
df_mean
# Out:
#           park    beauty  cafe   deliver     equip      food  hospital  \
# 0     0.299195  0.356968  -1.0  2.811159 -0.342871 -1.000000  0.144035
# 1     0.299195  0.221271  -1.0  0.270386 -0.780957 -1.000000  0.601649
# 2     0.299195 -0.457213  -1.0  0.270386 -1.000000 -0.146728 -0.084772
# 3    -0.566935 -0.864303  -1.0  0.270386 -0.780957  0.023926 -0.542386
# 4    -0.566935 -0.321516  -1.0  0.270386 -0.561914  0.535889  1.288070
# ...        ...       ...   ...       ...       ...       ...       ...
# 1771 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1772 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1773 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1774 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1775 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
#
#       manage  pharmacy  play  restaurant      sell
# 0       -0.4  0.297297  -1.0        -1.0  0.219361
# 1       -0.4  0.297297  -1.0        -1.0  0.066941
# 2       -0.7 -0.410319  -1.0        -1.0 -0.618950
# 3       -1.0 -0.764128  -1.0        -1.0 -0.466529
# 4       -0.7 -0.410319  -1.0        -1.0 -0.009269
# ...      ...       ...   ...         ...       ...
# 1771    -1.0 -1.000000  -1.0        -1.0 -1.000000
# 1772    -1.0 -1.000000  -1.0        -1.0 -1.000000
# 1773    -1.0 -1.000000  -1.0        -1.0 -1.000000
# 1774    -1.0 -1.000000  -1.0        -1.0 -1.000000
# 1775    -1.0 -1.000000  -1.0        -1.0 -1.000000
#
# [1776 rows x 12 columns]

# %%
# df_int = df

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kmeans = KMeans(n_clusters = 20)

# %%
kmeans.fit(df_mean)
# Out:
# KMeans(n_clusters=20)

# %%
labels = kmeans.fit_predict(df_mean)

# %%
df_mean['cluster'] = kmeans.labels_

# %%
df_mean
# Out:
#           park    beauty  cafe   deliver     equip      food  hospital  \
# 0     0.299195  0.356968  -1.0  2.811159 -0.342871 -1.000000  0.144035
# 1     0.299195  0.221271  -1.0  0.270386 -0.780957 -1.000000  0.601649
# 2     0.299195 -0.457213  -1.0  0.270386 -1.000000 -0.146728 -0.084772
# 3    -0.566935 -0.864303  -1.0  0.270386 -0.780957  0.023926 -0.542386
# 4    -0.566935 -0.321516  -1.0  0.270386 -0.561914  0.535889  1.288070
# ...        ...       ...   ...       ...       ...       ...       ...
# 1771 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1772 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1773 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1774 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
# 1775 -1.000000 -1.000000  -1.0 -1.000000 -1.000000 -1.000000 -1.000000
#
#       manage  pharmacy  play  restaurant      sell  cluster      pca_x  \
# 0       -0.4  0.297297  -1.0        -1.0  0.219361        0   1.558831
# 1       -0.4  0.297297  -1.0        -1.0  0.066941        8  -0.282948
# 2       -0.7 -0.410319  -1.0        -1.0 -0.618950       16 -10.539710
# 3       -1.0 -0.764128  -1.0        -1.0 -0.466529        3 -11.415807
# 4       -0.7 -0.410319  -1.0        -1.0 -0.009269        8  -1.789450
# ...      ...       ...   ...         ...       ...      ...        ...
# 1771    -1.0 -1.000000  -1.0        -1.0 -1.000000        3 -19.877085
# 1772    -1.0 -1.000000  -1.0        -1.0 -1.000000        3 -19.877085
# 1773    -1.0 -1.000000  -1.0        -1.0 -1.000000        3 -19.877085
# 1774    -1.0 -1.000000  -1.0        -1.0 -1.000000        3 -19.877085
# 1775    -1.0 -1.000000  -1.0        -1.0 -1.000000        3 -19.877085
#
#          pca_y
# 0    -5.895231
# 1    -4.976581
# 2     1.696415
# 3     1.623422
# 4     1.384688
# ...        ...
# 1771 -1.056212
# 1772 -1.056212
# 1773 -1.056212
# 1774 -1.056212
# 1775 -1.056212
#
# [1776 rows x 15 columns]

# %%
# df.mean()

# %%
# park_m = df['park'].describe()['mean']
# beauty_m = df['beauty'].describe()['mean']
# cafe_m = df['cafe'].describe()['mean']
# deliver_m = df['deliver'].describe()['mean']
# equip_m = df['equip'].describe()['mean']
# food_m = df['food'].describe()['mean']
# hospital_m = df['hospital'].describe()['mean']
# manage_m = df['manage'].describe()['mean']
# pharmacy_m = df['pharmacy'].describe()['mean']
# play_m = df['play'].describe()['mean']
# restaurant_m = df['restaurant'].describe()['mean']
# sell_m = df['sell'].describe()['mean']

# %%
# type(park_m)

# %%
# print(park_m)

# %%
# print(a)
# 각 피쳐에서 평균 빼면 % 나옴

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
print('실루엣 스코어는 : {0:.3f}'.format(silhouette_score(df_mean,labels)))
# Out:
# 실루엣 스코어는 : 0.478

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(df)

# %%
df_mean['pca_x'] = pca_transformed[:,0] #첫번째 값(X 좌표)
df_mean['pca_y']=pca_transformed[:,1] #첫번째 값(y 좌표)
df_mean.head(3)
# Out:
#        park    beauty  cafe   deliver     equip      food  hospital  manage  \
# 0  0.299195  0.356968  -1.0  2.811159 -0.342871 -1.000000  0.144035    -0.4
# 1  0.299195  0.221271  -1.0  0.270386 -0.780957 -1.000000  0.601649    -0.4
# 2  0.299195 -0.457213  -1.0  0.270386 -1.000000 -0.146728 -0.084772    -0.7
#
#    pharmacy  play  restaurant      sell  cluster      pca_x     pca_y
# 0  0.297297  -1.0        -1.0  0.219361        0   1.558831 -5.895231
# 1  0.297297  -1.0        -1.0  0.066941        8  -0.282948 -4.976581
# 2 -0.410319  -1.0        -1.0 -0.618950       16 -10.539710  1.696415

# %%
# 산점도로 표현 : 군집별로 다른 색상으로 표시
plt.scatter(x=df_mean.loc[:,'pca_x'], y=df_mean.loc[:,'pca_y'], c=df_mean['cluster'])
# 조금 다름

# %%
#collections = ['park','beauty','equip','food','hospital','manage','pharmacy','sell','cluster']
collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage','pharmacy','play','restaurant','sell']
for collection in collections:
    print(df_mean[collection].value_counts())
# Out:
# -1.000000    386
#  0.299195    381
# -0.133870    370
# -0.566935    244
#  0.732260    196
#  1.165326    106
#  1.598391     42
#  2.464521     24
#  2.031456     15
#  2.897586      9
#  3.330651      3
# Name: park, dtype: int64
# -1.000000    318
# -0.864303    113
# -0.185819    111
# -0.728606    110
# -0.592910     99
# -0.457213     98
# -0.050122     94
# -0.321516     93
#  0.356968     91
#  0.085575     84
#  0.221271     83
#  0.628362     54
#  0.899756     54
#  0.492665     52
#  0.764059     50
#  1.035452     48
#  1.171149     41
#  1.442543     29
#  1.578240     25
#  1.306846     23
#  2.121027     17
#  1.849633     15
#  1.713936     13
#  2.256724     12
#  1.985330     11
#  2.392421     11
#  2.528117      8
#  2.663814      6
#  4.156479      2
#  3.206601      2
#  2.799511      2
#  2.935208      2
#  3.070905      2
#  3.477995      1
#  4.020782      1
#  3.749389      1
# Name: beauty, dtype: int64
# -1.000000     948
#  0.037989     455
#  1.075979     178
#  2.113968      75
#  3.151958      38
#  4.189947      25
#  5.227937      22
#  6.265926      21
#  7.303916      10
#  8.341905       2
#  10.417884      1
#  9.379895       1
# Name: cafe, dtype: int64
# -1.000000    987
#  0.270386    453
#  1.540773    188
#  2.811159     81
#  4.081545     31
#  5.351931     21
#  6.622318      8
#  7.892704      7
# Name: deliver, dtype: int64
# -1.000000    390
# -0.780957    214
# -0.561914    172
# -0.342871    140
#  0.095215    138
# -0.123828    130
#  0.314258    117
#  0.752343     88
#  0.533300     86
#  0.971386     57
#  1.190429     42
#  1.409472     42
#  1.847558     28
#  1.628515     26
#  2.066601     21
#  2.285644     17
#  2.504687     14
#  2.723730     10
#  3.380858     10
#  3.161815      9
#  3.599901      7
#  2.942773      7
#  3.818944      5
#  4.257030      4
#  4.476073      1
#  4.037987      1
# Name: equip, dtype: int64
# -1.000000    553
# -0.658691    128
# -0.317383    107
# -0.488037    104
# -0.829346    101
# -0.146728     93
#  0.023926     83
#  0.365235     78
#  0.194581     76
#  0.535889     64
#  0.706544     57
#  1.047852     38
#  0.877198     38
#  1.218507     33
#  1.389161     27
#  1.730470     25
#  1.559816     21
#  1.901124     20
#  2.242433     17
#  2.925050     14
#  2.413087     13
#  2.071779     10
#  2.583742     10
#  3.437014      8
#  3.266359      8
#  2.754396      6
#  3.095705      6
#  4.972903      5
#  4.290285      5
#  3.778322      4
#  4.119631      4
#  3.607668      4
#  4.460940      3
#  6.167483      2
#  5.826175      2
#  3.948977      2
#  9.580571      2
#  5.655520      1
#  6.508792      1
#  6.679447      1
#  6.338138      1
#  7.020755      1
# Name: food, dtype: int64
# -1.000000    554
# -0.313579    137
#  0.144035    124
# -0.084772    124
#  0.372842    115
#  0.601649    113
# -0.771193    100
# -0.542386     98
#  1.059263     93
#  0.830456     85
#  1.288070     53
#  1.745684     38
#  1.516877     38
#  1.974491     37
#  2.203298     22
#  2.660912     16
#  2.432105     11
#  2.889719      7
#  3.118526      7
#  3.347333      2
#  3.804947      1
#  4.262561      1
# Name: hospital, dtype: int64
# -1.0    608
# -0.4    168
# -0.1    166
# -0.7    155
#  0.2    126
#  0.5    123
#  0.8    120
#  1.1     90
#  1.4     55
#  1.7     42
#  2.0     28
#  2.6     19
#  2.3     19
#  2.9     12
#  3.8      8
#  3.5      8
#  3.2      7
#  4.7      7
#  4.4      4
#  4.1      3
#  5.0      3
#  5.3      2
#  5.6      2
#  5.9      1
# Name: manage, dtype: int64
# -1.000000    500
#  0.297297     76
#  0.415233     72
#  0.061425     71
# -0.646192     70
# -0.410319     68
#  0.179361     66
#  0.533170     65
# -0.528256     62
# -0.174447     62
# -0.056511     62
# -0.882064     59
#  0.651106     56
# -0.764128     53
# -0.292383     53
#  0.769042     46
#  0.886978     44
#  1.122850     38
#  1.004914     35
#  1.476658     32
#  1.240786     25
#  1.358722     22
#  1.594595     19
#  1.948403     15
#  1.712531     15
#  1.830467     11
#  2.302211      9
#  2.184275      9
#  2.420147      8
#  2.656020      6
#  2.891892      6
#  2.066339      6
#  2.538084      5
#  3.599509      5
#  3.363636      4
#  4.071253      4
#  3.009828      3
#  3.245700      3
#  3.127764      3
#  2.773956      2
#  3.481572      2
#  4.189189      1
#  3.717445      1
#  3.953317      1
#  4.307125      1
# Name: pharmacy, dtype: int64
# -1.000000    1367
#  2.211573     292
#  5.423146      90
#  8.634720      27
# Name: play, dtype: int64
# -1.000000    482
# -0.727147    277
# -0.454294    258
# -0.181441    240
#  0.091412    123
#  0.364265    107
#  1.455677     34
#  0.637118     33
#  0.909971     26
#  3.365648     21
#  1.182824     18
#  1.728530     18
#  3.092795     17
#  2.819942     14
#  2.001383     14
#  3.638501     12
#  2.547089     12
#  2.274236     12
#  8.822707      7
#  4.184206      5
#  3.911354      5
#  5.821324      4
#  5.275618      4
#  4.729912      4
#  4.457059      4
#  7.731295      4
#  5.002765      3
#  5.548471      3
#  6.912736      3
#  6.367030      2
#  6.094177      2
#  8.277001      2
#  7.185589      1
#  8.004148      1
#  7.458442      1
#  9.095560      1
#  6.639883      1
#  8.549854      1
# Name: restaurant, dtype: int64
# -1.000000    475
# -0.923790     63
# -0.695160     52
# -0.237899     50
#  0.295572     50
#             ...
#  4.639547      1
#  3.953656      1
#  4.563337      1
#  3.572606      1
#  3.496395      1
# Name: sell, Length: 73, dtype: int64

# %%
# collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage','pharmacy','play','restaurant','sell','cluster']
# for collection in collections:
#     print(df[collection].value_counts())

# %%
# a = (df[collections]['park'].value_counts())
# print(a)

# %%
# for b in a:
#     print(((b-park_m)/park_m))

# %%
df[df_mean['cluster']== 2]
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 8        1       7     0        1      2    11         5       3        19
# 9        1       6     0        2      2     5         5       3        16
# 10       1       9     0        1      3     6         3       5        15
# 16       2       6     1        1      3     2         2       5         7
# 39       1      10     1        0      6    13         7       8        25
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 1596     2      10     0        1      7     7         9       7        12
# 1667     1       6     1        1      3     2         4       2         9
# 1668     1       7     1        1      3     5         4       4        12
# 1669     1       7     1        1      5     5         3       5        11
# 1670     1      12     1        1     11     8         4       6        11
#
#       play  restaurant  sell
# 8        1           1    15
# 9        1           3    16
# 10       1           3    18
# 16       1           5    24
# 39       1           0    15
# ...    ...         ...   ...
# 1596     1           2    23
# 1667     1           1    11
# 1668     1           2    17
# 1669     1           2    17
# 1670     1           2    27
#
# [119 rows x 12 columns]

# %%
df[df_mean['cluster']== 7]
# Out:
#      park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 108     1      21     2        6     15    44         9      15        43
# 109     1      26     2        5     14    35        11      18        43
# 110     1      25     2        5     15    31        13      18        34
# 181     0      25     2        5     21    26         9      15        39
# 182     1      33     2        7     21    27        10      19        43
# 183     1      35     1        6     19    32        11      20        42
# 184     2      28     1        4     13    27        12      17        28
# 255     0      31     2        6     22    18        10      16        32
# 256     1      38     3        7     22    20        12      22        30
# 257     2      38     2        5     20    22        15      23        29
# 329     1      30     4        5     20    20        18      18        37
# 330     1      31     4        5     21    23        16      19        36
# 331     3      37     2        4     21    24        21      22        17
# 403     1      26     5        2     14    19        17      20        44
# 404     1      25     6        3     13    17        17      20        45
# 405     3      16     1        3     15    13        16      16        29
# 406     3      25     1        2     24    17        23      21        22
# 407     3      26     1        3     19    19        19      21        25
#
#      play  restaurant  sell
# 108     2           6    49
# 109     3           6    50
# 110     3           4    42
# 181     2           8    66
# 182     3           7    74
# 183     3           7    69
# 184     3           6    54
# 255     3          14    80
# 256     3          13    86
# 257     3          14    83
# 329     2          16    80
# 330     3          15    77
# 331     3          15    73
# 403     2          16    67
# 404     2          16    64
# 405     2          15    48
# 406     2          15    55
# 407     2          10    55

# %%
a[665]
# Out:
# (127.224507, 37.533239)

# %%
a[1300]
# Out:
# (127.069507, 37.578239)

# %%
def visualize_silhouette(cluster_lists, X_features): 
    
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
visualize_silhouette([5,6,7,8,9],df_mean)

# %%
visualize_silhouette([10,11,12,13,14,15],df_mean)

# %%
visualize_silhouette([16,17,18,19],df_mean)

# %%
visualize_silhouette([20,21,22],df_mean)

# %%
visualize_silhouette([23,24,25],df_mean)

# %%
df_mean[df_mean['cluster']==0]
# Out:
# park          0.013372
# beauty        0.321687
# cafe         -0.148849
# deliver       2.646009
# equip         0.257306
# food          0.129732
# hospital      0.624530
# manage        0.245000
# pharmacy      0.355086
# play         -1.000000
# restaurant   -0.260568
# sell          0.451040
# cluster       0.000000
# pca_x         7.359513
# pca_y        -1.417629
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df_mean[df_mean['cluster']==0])
plt.show() # 용품,약국, 운동장
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_mean[df_mean['cluster']==0]
# Out:
#           park    beauty      cafe   deliver     equip      food  hospital  \
# 0     0.299195  0.356968 -1.000000  2.811159 -0.342871 -1.000000  0.144035
# 6    -1.000000  0.221271 -1.000000  1.540773 -0.123828  0.535889  1.516877
# 28   -1.000000  0.628362  0.037989  2.811159  0.314258  1.389161  0.372842
# 29   -1.000000 -0.185819 -1.000000  1.540773  0.314258  0.194581  0.144035
# 74    0.299195  1.035452 -1.000000  2.811159 -0.123828 -1.000000  0.601649
# ...        ...       ...       ...       ...       ...       ...       ...
# 1736 -0.133870  1.171149 -1.000000  4.081545  0.752343 -0.658691  1.974491
# 1737  0.299195  0.899756  0.037989  4.081545  0.533300 -0.658691  1.516877
# 1744 -0.566935  0.492665  0.037989  2.811159  2.066601  0.706544  0.372842
# 1745 -0.566935  0.492665 -1.000000  1.540773  2.285644  0.365235 -0.084772
# 1747 -0.566935  0.764059 -1.000000  1.540773  2.723730  0.194581  0.144035
#
#       manage  pharmacy  play  restaurant      sell  cluster      pca_x  \
# 0       -0.4  0.297297  -1.0   -1.000000  0.219361        0   1.558831
# 6       -0.1  0.651106  -1.0   -0.727147  0.447992        0   8.620941
# 28       0.8  0.533170  -1.0    0.091412  1.133883        0  17.441583
# 29       0.5  0.297297  -1.0   -0.727147  0.295572        0   4.057486
# 74      -0.4  0.651106  -1.0   -1.000000  0.371782        0   6.407438
# ...      ...       ...   ...         ...       ...      ...        ...
# 1736     0.8  1.358722  -1.0   -0.727147  1.362513        0  22.066217
# 1737     0.5  1.358722  -1.0   -0.727147  1.210093        0  19.256466
# 1744     0.5  0.533170  -1.0    0.364265  0.829042        0  14.750851
# 1745     0.5  0.061425  -1.0    0.364265  0.905252        0  13.055303
# 1747     0.5  0.179361  -1.0    0.637118  0.829042        0  13.830014
#
#          pca_y
# 0    -5.895231
# 6     1.221982
# 28    1.162241
# 29    0.244228
# 74   -6.989110
# ...        ...
# 1736 -8.720694
# 1737 -7.217230
# 1744 -0.048960
# 1745 -3.340242
# 1747 -3.906211
#
# [100 rows x 15 columns]

# %%
a[0]
# Out:
# (126.859507, 37.493239)

# %%
a[74]
# Out:
# (126.859507, 37.498239)

# %%
visualize_silhouette([35,36,37,38,39,40],df_mean)

# %% [markdown]
# # DBScan

# %%
# import pandas as pd
# df = pd.DataFrame()

# df['park'] = counts1
# df['beauty'] = counts2
# #df['cafe'] = counts3
# #df['deliver'] = counts4
# df['equip'] = counts5
# df['food'] = counts6
# #df['funeral'] = counts7
# df['hospital'] = counts8
# df['manage'] = counts9
# #df['medical'] = counts10
# df['pharmacy'] = counts11
# #df['play'] = counts12
# #df['restaurant'] = counts13
# df['sell'] = counts14
# #df['shelter'] = counts15

# %%
# from sklearn.cluster import DBSCAN

# dbscan = DBSCAN(eps=1.5, min_samples =26, metric='euclidean')
# dbscan_labels = dbscan.fit_predict(df)

# %%
# df['dbscan_cluster'] = dbscan_labels

# %%
# df

# %%
# df['dbscan_cluster'].value_counts()

# %%
# df[df['dbscan_cluster']==0]

# %%
# a[27]

# %%
# a[146]

# %%
# 값이 조금씩 다르게 나온다
