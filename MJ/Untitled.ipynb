# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('/Users/minji/PMJ/MJ/군집 마스터리.csv')
# Out:
#     mean Unnamed: 1 Unnamed: 2     2.34E+00     3.62E+00     2.91E-01  \
# 0    NaN         df        NaN         park       beauty         cafe
# 1    NaN        df1       mean            2    11.141844   0.91489362
# 2    NaN        df1        max            2           13            1
# 3    NaN       df10       mean  1.342105263  0.378947368            0
# 4    NaN       df10        max            2            2            0
# 5    NaN       df11       mean  3.699115044  1.982300885            0
# 6    NaN       df11        max            5            3            0
# 7    NaN       df12       mean   2.37037037            0            0
# 8    NaN       df12        max            3            0            0
# 9    NaN       df13        max            5            4            2
# 10   NaN       df13       mean  2.927038627  1.763948498  0.223175966
# 11   NaN       df14       mean  2.358208955  10.52238806  0.925373134
# ...
