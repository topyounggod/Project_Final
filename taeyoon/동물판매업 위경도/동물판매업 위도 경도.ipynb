# %%
import pandas as pd
import numpy as np

animal_sell = pd.read_csv('동물판매업(UTF-8).csv',encoding = 'utf-8')

# %%
animal_sell
# Out:
#        번호  구분              업체명         전화번호            소재지               인허가번호
# 0    4072  판매       닥터아이펫 동물병원            -  서울특별시 중랑구 상봉동  306000003720130003
# 1    4071  판매          펫시랑 상봉점  02-496-7649  서울특별시 중랑구 상봉동  306000003720130004
# 2    4070  판매              해피독    6401-9585  서울특별시 중랑구 망우동  306000003720130001
# 3    4069  판매     (주)에이플러스 면목점  ***********  서울특별시 중랑구 면목동  306000003720120004
# 4    4068  판매           (주)밀레펫  ***********  서울특별시 중랑구 망우동  306000003720120003
# ..    ...  ..              ...          ...            ...                 ...
# 985  2187  판매  도그마루 강아지고양이 평택점  ***********    경기도 평택시 비전동  391000003720200029
# 986  2186  판매            퍼스트 펫            -    경기도 평택시 이충동  391000003720200019
# 987  2185  판매         캣？ 고양이전문  ***********    경기도 평택시 비전동  391000003720200017
# 988  2184  판매  달루나캣츠 고양이전문 평택점  ***********    경기도 평택시 비전동  391000003720200007
# 989  2183  판매              팜스펫  ***********    경기도 평택시 모곡동  391000003720190094
#
# [990 rows x 6 columns]

# %%
import googlemaps
import pandas as pd
places = animal_sell['업체명']
my_key = "AIzaSyCCW8kON7zFB-euV3LPepp-6EGIUObUSyE"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 닥터아이펫 동물병원의 위치를 찾고있습니다
# 2번 인덱스에서 펫시랑 상봉점의 위치를 찾고있습니다
# 3번 인덱스에서 해피독의 위치를 찾고있습니다
# 4번 인덱스에서 (주)에이플러스 면목점의 위치를 찾고있습니다
# 5번 인덱스에서 (주)밀레펫의 위치를 찾고있습니다
# 6번 인덱스에서 안쌤러브애견의 위치를 찾고있습니다
# 7번 인덱스에서 큐티펫의 위치를 찾고있습니다
# 8번 인덱스에서 코타강쥐의 위치를 찾고있습니다
# 9번 인덱스에서 순진한 강아지의 위치를 찾고있습니다
# 10번 인덱스에서 꿀펫의 위치를 찾고있습니다
# 11번 인덱스에서 낭만고양이 성북점의 위치를 찾고있습니다
# 12번 인덱스에서 호펫 강아지 고양이 성신여대본점의 위치를 찾고있습니다
# 13번 인덱스에서 러블리펫의 위치를 찾고있습니다
# 14번 인덱스에서 페리독의 위치를 찾고있습니다
# 15번 인덱스에서 이마트 하월곡점의 위치를 찾고있습니다
# 16번 인덱스에서 (주)그린프레밀리의 위치를 찾고있습니다
# 16번 인덱스 위치를 찾는데 실패했습니다.
# 17번 인덱스에서 70dog의 위치를 찾고있습니다
# 18번 인덱스에서 퍼피돌의 위치를 찾고있습니다
# 19번 인덱스에서 요미독 성북구지점의 위치를 찾고있습니다
# 20번 인덱스에서 아름애견의 위치를 찾고있습니다
# 21번 인덱스에서 앙팡애견백화점의 위치를 찾고있습니다
# 22번 인덱스에서 쥬파크의 위치를 찾고있습니다
# 23번 인덱스에서 VELY DOG의 위치를 찾고있습니다
# 24번 인덱스에서 멍스의 위치를 찾고있습니다
# 25번 인덱스에서 아이러브 캣의 위치를 찾고있습니다
# 26번 인덱스에서 주토피아(zutopia)의 위치를 찾고있습니다
# 26번 인덱스 위치를 찾는데 실패했습니다.
# 27번 인덱스에서 펫맘애의 위치를 찾고있습니다
# 28번 인덱스에서 애니몰파크의 위치를 찾고있습니다
# 29번 인덱스에서 삼호동물판매소의 위치를 찾고있습니다
# 30번 인덱스에서 멍가네의 위치를 찾고있습니다
# ...

# %%
df_fin = pd.concat([animal_sell,df],axis = 1)

df_fin.to_csv('동물판매업경도(euc-kr).csv',encoding='euc-kr')
