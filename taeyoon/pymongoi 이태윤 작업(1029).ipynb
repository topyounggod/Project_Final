# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
db = client['local']

# %%
park = db['park']
beauty = db['beauty']
cafe = db['cafe']
deliver = db['deliver']
equip = db['equip']
food = db['food']
funeral = db['funeral']
hospital = db['hospital']
manage = db['manage']
medical = db['medical']
pharmacy = db['pharmacy']
play = db['play']
restaurant = db['restaurant']
sell = db['sell']
shelter = db['shelter']

# %%
collections = ['park','beauty','cafe','deliver','equip','food','funeral','hospital','manage',
               'medical','pharmacy','play','restaurant','sell','shelter']

# %%
from pymongo import GEOSPHERE

for collection in collections :
    db[collection].create_index([('geometry',GEOSPHERE)])

# %%
a = []
# 0.0005 = 500m
x = 37.584980
y = 127.031133
while x < 37.612181:
    y = 127.031133
    while y < 127.058599:
        a.append((y,x))
        y += 0.0005
        y = round(y,6)
    a.append((y,x))
    x += 0.0005
    x = round(x,6)

# %%
len(a)
# Out:
# 3080

# %%
import numpy as np
from geojson import Point, Feature, FeatureCollection, dump
# a = np.random.randint(37584980, 37612181, size=5000) / 1000000
# b = np.random.randint(127031133,127058599,size = 5000) / 1000000
# 진짜 서울시 위도 경도
# a = np.random.randint(37413294, 37715133, size=10000) / 1000000
# b = np.random.randint(127269311,127734086,size = 10000) / 1000000


counts1 = []
for i in range(0,len(a)): 
    c = list(park.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
            
        }]
    ))
    counts1.append(len(c))

# %%
counts2 = []
for i in range(0,len(a)): 
    c = list(beauty.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts2.append(len(c))

# %%
counts3 = []
for i in range(0,len(a)): 
    c = list(cafe.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts3.append(len(c))

# %%
counts4 = []
for i in range(0,len(a)): 
    c = list(deliver.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts4.append(len(c))

# %%
counts5 = []
for i in range(0,len(a)): 
    c = list(equip.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts5.append(len(c))

# %%
counts6 = []
for i in range(0,len(a)): 
    c = list(food.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts6.append(len(c))

# %%
counts7 = []
for i in range(0,len(a)): 
    c = list(funeral.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts7.append(len(c))

# %%
counts8 = []
for i in range(0,len(a)): 
    c = list(hospital.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts8.append(len(c))

# %%
counts9 = []
for i in range(0,len(a)): 
    c = list(manage.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts9.append(len(c))

# %%
counts10 = []
for i in range(0,len(a)): 
    c = list(medical.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 1500
            }
        }]
    ))
    counts10.append(len(c))

# %%
counts11 = []
for i in range(0,len(a)): 
    c = list(pharmacy.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts11.append(len(c))

# %%
counts12 = []
for i in range(0,len(a)): 
    c = list(play.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts12.append(len(c))

# %%
counts13 = []
for i in range(0,len(a)): 
    c = list(restaurant.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 2000
            }
        }]
    ))
    counts13.append(len(c))

# %%
counts14 = []
for i in range(0,len(a)): 
    c = list(sell.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts14.append(len(c))

# %%
counts15 = []
for i in range(0,len(a)): 
    c = list(shelter.aggregate(
        [{
            "$geoNear": {
                "near": { "type": "Point", "coordinates": a[i] },
                "distanceField": 'meters',
                "maxDistance": 700
            }
        }]
    ))
    counts15.append(len(c))

# %%
import pandas as pd
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
df['cafe'] = counts3
df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
df['play'] = counts12
df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
df_int = df

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kmeans = KMeans(n_clusters = 20)

# %%
kmeans.fit(df)
# Out:
# KMeans(n_clusters=20)

# %%
labels = kmeans.fit_predict(df)

# %%
df['cluster'] = kmeans.labels_

# %%
df
# Out:
#       park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  \
# 0        3       1     0        0      2     4         1       0         0
# 1        3       1     0        0      2     4         1       0         0
# 2        4       1     0        0      2     6         1       0         0
# 3        4       1     0        0      2     6         0       0         0
# 4        4       1     0        0      2     6         0       0         0
# ...    ...     ...   ...      ...    ...   ...       ...     ...       ...
# 3075     2      13     1        1      3     4         4       1         8
# 3076     2      13     1        1      3     4         4       1        10
# 3077     2       5     1        1      3     4         4       0        10
# 3078     2       5     1        1      3     4         4       0        11
# 3079     1       5     1        1      2     4         4       1        11
#
#       play  restaurant  sell  cluster
# ...

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
print('실루엣 스코어는 : {0:.3f}'.format(silhouette_score(df,labels)))
# Out:
# 실루엣 스코어는 : 0.500

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(df_int)

# %%
df_int['pca_x'] = pca_transformed[:,0] #첫번째 값(X 좌표)
df_int['pca_y']=pca_transformed[:,1] #첫번째 값(y 좌표)
df.head(3)
# Out:
#    park  beauty  cafe  deliver  equip  food  hospital  manage  pharmacy  play  \
# 0     3       1     0        0      2     4         1       0         0     1
# 1     3       1     0        0      2     4         1       0         0     1
# 2     4       1     0        0      2     6         1       0         0     1
#
#    restaurant  sell  cluster     pca_x     pca_y
# 0           3     5       17 -8.559645  3.180052
# 1           3     5       17 -8.559645  3.180052
# 2           3     5       14 -6.525876  0.985451

# %%
# 산점도로 표현 : 군집별로 다른 색상으로 표시
plt.scatter(x=df_int.loc[:,'pca_x'], y=df_int.loc[:,'pca_y'], c=df_int['cluster'])

# %%
#collections = ['park','beauty','equip','food','hospital','manage','pharmacy','sell','cluster']
collections = ['park','beauty','cafe','deliver','equip','food','hospital','manage','pharmacy','play','restaurant','sell','cluster']
for collection in collections:
    print(df[collection].value_counts())
# Out:
# 2    1506
# 1     581
# 3     515
# 4     307
# 5     171
# Name: park, dtype: int64
# 0     901
# 9     493
# 3     432
# 1     365
# 2     325
# 5     162
# 12    136
# 8     116
# 6      91
# 4      31
# 13     23
# 11      4
# 7       1
# Name: beauty, dtype: int64
# 0    2258
# 1     749
# 2      73
# Name: cafe, dtype: int64
# 0    2241
# 1     839
# Name: deliver, dtype: int64
# 1    943
# 2    761
# 0    664
# 3    389
# 4    203
# 5     63
# 6     36
# 7     21
# Name: equip, dtype: int64
# 0    1124
# 1    1015
# 2     460
# 3     232
# 4     196
# 6      22
# 7      10
# 8       9
# 5       9
# 9       3
# Name: food, dtype: int64
# 2     803
# 3     569
# 1     555
# 0     407
# 4     255
# 6     183
# 7     125
# 5     117
# 8      49
# 9      15
# 10      2
# Name: hospital, dtype: int64
# 0    1239
# 1     876
# 2     557
# 3     321
# 4      85
# 5       2
# Name: manage, dtype: int64
# 4     578
# 2     441
# 0     330
# 5     298
# 7     280
# 6     260
# 3     249
# ...

# %%
df.drop(['pca_x','pca_y'], axis=1, inplace= True)

# %%
df.mean()
# Out:
# park          2.344481
# beauty        3.616234
# cafe          0.290584
# deliver       0.272403
# equip         1.662987
# food          1.221104
# hospital      2.595130
# manage        1.072403
# pharmacy      4.468831
# play          0.680844
# restaurant    1.083442
# sell          6.261688
# cluster       9.167532
# dtype: float64

# %%
df0=df[df['cluster']== 0] # 약국이 많음

# %%
df1=df[df['cluster']== 1] # 미용, 병원, 약국, 판매 많음

# %%
df2=df[df['cluster']== 2] # 미용, 판매 높음,

# %%
df3=df[df['cluster']== 3] # 공원, 미용, 사료, 병원, 호텔 많음

# %%
df4=df[df['cluster']== 4] # 공원, 판매, 물품, 사료 높음

# %%
df5=df[df['cluster']== 5] # 물품, 병원, 약국, 동반 레스토랑 높음

# %%
df6=df[df['cluster']== 6] # 공원, 사료, 장비, 판매, 동반 레스토랑, 놀이터

# %%
df7=df[df['cluster']== 7] # 미용, 약국, 병원, 판매 많음

# %%
df8=df[df['cluster']== 8] # 공원, 미용, 물품, 사료, 병원, 약국, 판매 높음

# %%
df9=df[df['cluster']== 9] # 공원, 미용, 판매 높은, 동반 레스토랑 높음

# %%
df10=df[df['cluster']== 10] # 없음

# %%
df11=df[df['cluster']== 11] # 사료, 장비, 공원 높음

# %%
df12=df[df['cluster']== 12] # 병원, 약국, 판매 , 물품, 높음

# %%
df13=df[df['cluster']== 13] # 공원, 사료 높음

# %%
df14=df[df['cluster']== 14] # 미용 병원, 약국, 판매 높음

# %%
df15=df[df['cluster']== 15] # 없음 그나마 판매

# %%
df16=df[df['cluster']== 16] # 미용, 병원, 약국 많음

# %%
df17=df[df['cluster']== 17] # 미용, 약국, 판매 많음

# %%
df18=df[df['cluster']== 18]

# %%
df19=df[df['cluster']== 19] # 의미 없음

# %%
df0.describe()
# Out:
#              park      beauty        cafe  deliver       equip        food  \
# count  171.000000  171.000000  171.000000    171.0  171.000000  171.000000
# mean     4.461988    2.187135    0.374269      0.0    2.578947    3.309942
# std      0.696643    0.702984    0.782330      0.0    0.999071    1.238056
# min      2.000000    0.000000    0.000000      0.0    1.000000    1.000000
# 25%      4.000000    2.000000    0.000000      0.0    2.000000    3.000000
# 50%      5.000000    2.000000    0.000000      0.0    2.000000    3.000000
# 75%      5.000000    3.000000    0.000000      0.0    3.000000    4.000000
# max      5.000000    3.000000    2.000000      0.0    4.000000    9.000000
#
#          hospital      manage    pharmacy        play  restaurant        sell  \
# count  171.000000  171.000000  171.000000  171.000000  171.000000  171.000000
# mean     2.532164    1.619883    5.830409    1.877193    0.339181    5.064327
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# df : 데이터셋
# cluster : 데이터셋에서 클러스터 결과 컬럼명
cluster_size = df.groupby(['cluster'])['park'].count()    # 'id' 대신 아무 컬럼 이름을 적어도 무방
print(cluster_size)
cluster_size.plot(kind = 'bar')
# Out:
# cluster
# 0     171
# 1      75
# 2     145
# 3     335
# 4      94
# 5      53
# 6     209
# 7     126
# 8     225
# 9     203
# 10    124
# 11     91
# 12    223
# 13    251
# 14     85
# 15    232
# 16     94
# 17    158
# 18    112
# 19     74
# Name: park, dtype: int64
# <AxesSubplot:xlabel='cluster'>

# %%
for collection in collections :
    cluster_size = df.groupby(['cluster'])[collection].count()
    print(cluster_size)
cluster_size.plot(kind = 'bar')
# Out:
# cluster
# 0     171
# 1      75
# 2     145
# 3     335
# 4      94
# 5      53
# 6     209
# 7     126
# 8     225
# 9     203
# 10    124
# 11     91
# 12    223
# 13    251
# 14     85
# 15    232
# 16     94
# 17    158
# 18    112
# 19     74
# Name: park, dtype: int64
# cluster
# 0     171
# 1      75
# 2     145
# 3     335
# 4      94
# 5      53
# 6     209
# 7     126
# 8     225
# 9     203
# 10    124
# 11     91
# 12    223
# 13    251
# 14     85
# 15    232
# 16     94
# 17    158
# 18    112
# 19     74
# Name: beauty, dtype: int64
# cluster
# 0     171
# 1      75
# 2     145
# 3     335
# 4      94
# 5      53
# 6     209
# 7     126
# 8     225
# 9     203
# 10    124
# 11     91
# 12    223
# 13    251
# 14     85
# 15    232
# 16     94
# 17    158
# 18    112
# 19     74
# Name: cafe, dtype: int64
# cluster
# 0     171
# 1      75
# 2     145
# 3     335
# 4      94
# 5      53
# 6     209
# 7     126
# 8     225
# 9     203
# 10    124
# 11     91
# 12    223
# ...

# %%
# df : 데이터셋
# cluster : 데이터셋에서 클러스터 결과 컬럼명

# 평균 데이터 테이블 만들기
# 아래에서 데이터 스케일을 조정하는 이유는 히트맵을 그리면 값이 상대적으로 작은 변수의 클러스터간 특징 차이가 보이지 않기 때문입니다. 결국 눈에 잘 띄게 하기 위함!
temp = df.groupby(['cluster']).mean()    # 클러스터,변수별 평균 구하기
cluster_mean = temp.transpose()    # x축 ↔ y축 전환 (변수들이 y 축으로 배치되게끔)
mean_table = cluster_mean.div(cluster_mean.max(axis=1), axis=0)    # 모든 변수의 최대값이 1, 최소값이 0이 되도록 데이터 스케일 조정

# 히트맵으로 그리기
plt.figure(figsize = (20, 25))    # 히트맵 사이즈 설정
annot_kws= {'fontsize':12}    # 히트맵 폰트 사이즈 설정
sns.heatmap(mean_table,     # 히트맵 그릴 데이터셋
			annot=True,     # 레이블 표시 여부
            fmt='.3f',     # 레이블 표시 형식 (소숫점 3째자리까지)
            linewidths = 0.1,     # 히트맵 선 두께
            annot_kws = annot_kws,     # 아까 설정한 폰트 사이즈 적용
            cmap = 'RdYlBu_r')    # 컬러맵 설정
plt.title('클러스터 X 변수 mean table', fontsize=13)
plt.show()
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47084 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
figure,(ax1, ax2, ax3)= plt.subplots(nrows=1, ncols=3)   # 그래프를 2행 3열로 배치
figure.set_size_inches(30, 10)   # 그래프 전체 사이즈 설정

sns.barplot(data = df, y = 'cluster', x = 'park', orient = 'h', ax = ax1)   # x축:값, y축:클러스터
sns.barplot(data = df, y = 'cluster', x = 'beauty', orient = 'h', ax = ax2)
sns.barplot(data = df, y = 'cluster', x = 'cafe', orient = 'h', ax = ax3)   # boxplot
# Out:
# <AxesSubplot:xlabel='cafe', ylabel='cluster'>

# %%
figure,(ax1, ax2, ax3)= plt.subplots(nrows=1, ncols=3)   # 그래프를 2행 3열로 배치
figure.set_size_inches(30, 10)   # 그래프 전체 사이즈 설정
sns.barplot(data = df, y = 'cluster', x = 'deliver', orient = 'h', ax = ax1)
sns.barplot(data = df, y = 'cluster', x = 'equip', orient = 'h', ax = ax2)
sns.barplot(data = df, y = 'cluster', x = 'food', orient = 'h', ax = ax3)
# Out:
# <AxesSubplot:xlabel='food', ylabel='cluster'>

# %%
figure,(ax1, ax2, ax3)= plt.subplots(nrows=1, ncols=3)   # 그래프를 2행 3열로 배치
figure.set_size_inches(30, 10)   # 그래프 전체 사이즈 설정
sns.barplot(data = df, y = 'cluster', x = 'hospital', orient = 'h', ax = ax1)
sns.barplot(data = df, y = 'cluster', x = 'manage', orient = 'h', ax = ax2)
sns.barplot(data = df, y = 'cluster', x = 'pharmacy', orient = 'h', ax = ax3)
# Out:
# <AxesSubplot:xlabel='pharmacy', ylabel='cluster'>

# %%
figure,(ax1, ax2, ax3)= plt.subplots(nrows=1, ncols=3)   # 그래프를 2행 3열로 배치
figure.set_size_inches(30, 10)   # 그래프 전체 사이즈 설정
sns.barplot(data = df, y = 'cluster', x = 'play', orient = 'h', ax = ax1)
sns.barplot(data = df, y = 'cluster', x = 'restaurant', orient = 'h', ax = ax2)
sns.barplot(data = df, y = 'cluster', x = 'sell', orient = 'h', ax = ax3)
# Out:
# <AxesSubplot:xlabel='sell', ylabel='cluster'>

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df0)
sns.pointplot(data=df)
plt.show() # 용품,약국, 운동장
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df1)
sns.pointplot(data=df)
plt.show() # 미용, 카페, 운송, 병원, 약국, 판매
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df2)
sns.pointplot(data=df)
plt.show() #용품
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df3)
sns.pointplot(data=df)
plt.show() # 공원, 호텔, 놀이터
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df4)
sns.pointplot(data=df)
plt.show() # 판매, 동반 식당
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df5)
sns.pointplot(data=df)
plt.show() # 용품, 병원, 약국, 공원, 판매
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df6)
sns.pointplot(data=df)
plt.show() # 식당
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df7)
sns.pointplot(data=df)
plt.show() # 병원, 약국, 판매
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df8)
sns.pointplot(data=df)
plt.show() # 미용, 장비, 사료, 병원, 약국, 판매, 동반 식당
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df9)
sns.pointplot(data=df)
plt.show() # 운송, 미용
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df10)
sns.pointplot(data=df)
plt.show() # x
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df11)
sns.pointplot(data=df)
plt.show() # 공원, 용품, 사료, 놀이터, 식당, 판매
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df12)
sns.pointplot(data=df)
plt.show() # 판매, 용품, 병원, 호텔
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df13)
sns.pointplot(data=df)
plt.show() # 사료, 놀이터
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df14)
sns.pointplot(data=df)
plt.show() # 미용, 카페, 운송, 용품, 병원, 약국, 판매
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df15)
sns.pointplot(data=df)
plt.show() # 병원, 식당
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df16)
sns.pointplot(data=df)
plt.show()
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df17)
sns.pointplot(data=df)
plt.show() # 미용, 운송, 병원, 판매
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df18)
sns.pointplot(data=df)
plt.show() # 공원, 용품, 사료, 약국, 놀이터
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize = (10, 5))
plt.title("군집별 반려동물 산업 개체 계수")
sns.boxplot(data=df19)
sns.pointplot(data=df)
plt.show() #미용
# Out:
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ed/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
a[665]
# Out:
# (127.055633, 37.59048)

# %%
a[2287]
# Out:
# (127.054633, 37.60498)

# %%
def visualize_silhouette(cluster_lists, X_features): 
    
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
visualize_silhouette([5,6,7,8,9],df)

# %%
visualize_silhouette([10,11,12,13,14,15],df)

# %%
visualize_silhouette([16,17,18,19],df)

# %%
visualize_silhouette([20,21,22],df)

# %%
visualize_silhouette([23,24,25],df)

# %%
visualize_silhouette([35,36,37,38,39,40],df)

# %% [markdown]
# # DBScan

# %%
import pandas as pd
df = pd.DataFrame()

df['park'] = counts1
df['beauty'] = counts2
#df['cafe'] = counts3
#df['deliver'] = counts4
df['equip'] = counts5
df['food'] = counts6
#df['funeral'] = counts7
df['hospital'] = counts8
df['manage'] = counts9
#df['medical'] = counts10
df['pharmacy'] = counts11
#df['play'] = counts12
#df['restaurant'] = counts13
df['sell'] = counts14
#df['shelter'] = counts15

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1.5, min_samples =26, metric='euclidean')
dbscan_labels = dbscan.fit_predict(df)

# %%
df['dbscan_cluster'] = dbscan_labels

# %%
df

# %%
df['dbscan_cluster'].value_counts()

# %%
df[df['dbscan_cluster']==0]
# Out:
#      park  beauty  equip  food  hospital  manage  pharmacy  sell  \
# 27      5       2      4     4         2       2         8     5
# 28      5       2      4     3         2       2         8     5
# 29      5       2      4     3         2       2         8     4
# 30      5       2      4     2         2       2         7     4
# 31      5       2      4     3         2       2         8     4
# 32      5       2      4     3         2       2         8     5
# 33      5       2      4     3         2       2         8     5
# 34      5       2      4     3         2       2         8     5
# 35      5       2      3     3         2       2         7     5
# 83      5       2      4     4         2       2         7     5
# 84      5       2      4     3         2       2         7     5
# 85      5       2      4     2         2       2         7     4
# 86      5       2      4     2         2       2         7     4
# ...

# %%
a[27]
# Out:
# (127.044633, 37.58498)

# %%
a[146]
# Out:
# (127.048133, 37.58598)
