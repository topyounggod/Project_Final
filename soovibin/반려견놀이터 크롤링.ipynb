# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse


def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization":"KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long

gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
           '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
           '강남구','서초구','관악구','동작구','영등포구','금천구','구로구','양천구','강서구']

results = []

for find in gu_list : 
# find =  input('검색할 정보를 입력하세요 : ')
    time.sleep(10)

    driver = webdriver.Chrome(
        executable_path= "chromedriver.exe"
    )
    url = "https://m.map.naver.com/"
    driver.get(url)
    action = ActionChains(driver)

    time.sleep(4)
    driver.find_element_by_class_name('Nbox_input_text').click()

    driver.find_element_by_class_name('Nbox_input_text._search_input').send_keys(find + '반려견놀이터')
    driver.find_element_by_xpath('//*[@id="ct"]/div[1]/div[1]/form/div/div[2]/div/span[2]/button[2]').click()

    time.sleep(4)
    replys =driver.find_elements_by_xpath('//*[@id="ct"]/div[2]/ul/li')
    print(len(replys))

    for index, reply in enumerate(replys):
            name = reply.find_element_by_css_selector('div.item_tit').text
            address =reply.find_element_by_css_selector('div.wrap_item').text.split('\n')[2]
            latitude = address_to_latitude(address)
            longtitude = address_to_longtitude(address)
            results.append((name, address, latitude, longtitude))

results

import pandas as pd
data_frame = pd.DataFrame(results, columns=['name', 'address',"lat","long"])
data_frame
# Out:
# 3
# 1
# 5
# 0
# 8
# 0
# 2
# 2
# 3
# 3
# 1
# 1
# 3
# 1
# 1
# 2
# 4
# 3
# 3
# 2
# 3
# 3
# 0
# 2
# 3
#                        name                                  address  \
# 0         월드컵공원반려견놀이터반려견놀이터                         서울특별시 마포구 증산로 32
# 1               카페700반려견놀이터              서울특별시 강서구 곰달래로 104 3층 카페700
# 2              마이댕댕스쿨반려견놀이터         서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 3         월드컵공원반려견놀이터반려견놀이터                         서울특별시 마포구 증산로 32
# 4         월드컵공원반려견놀이터반려견놀이터                         서울특별시 마포구 증산로 32
# 5          덕수공원반려견놀이터반려견놀이터         경기도 고양시 덕양구 고양대로 1804-22 삼송배드민턴장
# 6               멍설유치원반려견놀이터                  경기도 고양시 덕양구 서삼릉길 357 1층
# 7           도래울반려견놀이터반려견놀이터                      경기도 고양시 덕양구 도내동 980
# 8       몰리스펫샵 스타필드고양점반려동물분양  경기도 고양시 덕양구 고양대로 1955 스타필드 고양점 1층 1100호
# 9                해리파크반려견놀이터                        인천광역시 중구 마시란로 284
# 10            독독 스타디움반려견놀이터                        인천광역시 중구 공항서로 519
# 11             송도도그파크반려견놀이터                인천광역시 연수구 센트럴로 350 달빛축제공원
# 12         하이포우반려견유치원반려견놀이터               인천광역시 연수구 하모니로 158 D동 412호
# 56  37.5303059811974  126.844330657306
# 57  37.5453792807017     126.847041591
# 58  37.5731267725651  126.818459482009

# %%
# pd.set_option('display.max_rows', None) # 전체행 출력해주는 설정명령어
pd.reset_option('display.max_rows', None) # 원래 설정으로
data_frame

# %%
# 중복 삭제
data_frame.drop_duplicates(ignore_index = True, inplace = True)
data_frame
# Out:
#                        name                                  address  \
# 0         월드컵공원반려견놀이터반려견놀이터                         서울특별시 마포구 증산로 32
# 1               카페700반려견놀이터              서울특별시 강서구 곰달래로 104 3층 카페700
# 2              마이댕댕스쿨반려견놀이터         서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 3          덕수공원반려견놀이터반려견놀이터         경기도 고양시 덕양구 고양대로 1804-22 삼송배드민턴장
# 4               멍설유치원반려견놀이터                  경기도 고양시 덕양구 서삼릉길 357 1층
# 5           도래울반려견놀이터반려견놀이터                      경기도 고양시 덕양구 도내동 980
# 6       몰리스펫샵 스타필드고양점반려동물분양  경기도 고양시 덕양구 고양대로 1955 스타필드 고양점 1층 1100호
# 7                해리파크반려견놀이터                        인천광역시 중구 마시란로 284
# 8             독독 스타디움반려견놀이터                        인천광역시 중구 공항서로 519
# 9              송도도그파크반려견놀이터                인천광역시 연수구 센트럴로 350 달빛축제공원
# 10         하이포우반려견유치원반려견놀이터               인천광역시 연수구 하모니로 158 D동 412호
# 11             아소비퍼피스반려견놀이터      인천광역시 연수구 아트센터대로 107 커낼워크 301동 513호
# 12            요미와 친구들반려견놀이터        인천광역시 연수구 신송로 165-14 2층 203호 더파라곤
# 13                멍살롱반려동물분양                     인천광역시 동구 송화로 15-2 1층
# 14                멍's반려동물호텔              인천광역시 서구 보석로18번안길 11 1층 멍's
# 15               까네지노반려견놀이터                     서울특별시 동대문구 전농로 43 1층
# 16            도그어스플래닛반려견놀이터                서울특별시 동대문구 고산자로36길 3 경동시장
# 17     어린이대공원 반려견 놀이터반려견놀이터                        서울특별시 광진구 능동로 216
# 18        휘경2동 반려견놀이터반려견놀이터                     서울특별시 동대문구 휘경동 산6-26
# 19        초안산공공반려견놀이터반려견놀이터                    서울특별시 도봉구 해등로3길 48-11
# 20        당고개반려견임시놀이터반려견놀이터                     서울특별시 노원구 상계동 산158-1
# 21             리틀원유치원반려견놀이터           경기도 남양주시 별내5로23번길 18-26 1층 리틀원
# 22        스테이지28웁시데이지반려견놀이터               서울특별시 강동구 아리수로61길 91-14 2층
# 23               놀아줄개반려견놀이터  경기도 성남시 수정구 위례광장로 320 아이에스센트럴타워 B1 106호
# 24  24개스트하우스 강남강아지유치원반려견놀이터               서울특별시 강남구 봉은사로20길 52 지하 1층
# 25          개러리아 삼성본점반려견놀이터                      서울특별시 강남구 선릉로122길 4
# 26              강남강아지반려견놀이터                   서울특별시 강남구 언주로79길 14 2층
# 27             삼막애견공원반려견놀이터                       경기도 안양시 만안구 석수동 18
# 28      보라매공원 반려견 놀이터반려견놀이터              서울특별시 동작구 여의대방로20길 33 보라매공원
# 29          광명시반려견놀이터반려견놀이터                          경기도 광명시 소하동 524
# 30               개좋은날반려견놀이터       서울특별시 영등포구 여의대방로 249 우주마루에어스포렉스 1층
# 31               멍마르뜨반려견놀이터                서울특별시 강서구 양천로 132 2층 멍마르뜨
#
#                  lat              long
# 0    37.564133892331   126.89244828144
# 1   37.5303059811974  126.844330657306
# 2   37.5453792807017     126.847041591
# 3   37.6414172824457  126.879209269479
# 4   37.6529930512718   126.87818524946
# 5   37.6268065379525   126.87428331328
# 6   37.6469771187284   126.89477806511
# 7   37.4415553578952  126.403419109378
# 8   37.4593419479238  126.401090087615
# 9   37.4078537544174  126.632509720043
# 10  37.3832947004154   126.64225604799
# 11  37.4009479998168   126.63861656794
# 12  37.3974040889539  126.647319505774
# 13  37.4786283268386  126.631575180006
# 14  37.5220360264811  126.625269754288
# 15  37.5687929283359  127.056652802451
# 16  37.5790377655561  127.039142935818
# 17  37.5520117024951  127.078772391405
# 18  37.5898105688087   127.06843114526
# 19  37.6474940352509  127.041384128711
# 20  37.6758701069494  127.088353072647
# 21  37.6525334981751  127.114675829876
# 22  37.5647216909849  127.146791775981
# 23  37.4722348733299  127.142663542049
# 24  37.5039094079839   127.03335865347
# 25  37.5144697845871  127.042933938902
# 26  37.4993308488849   127.04287698084
# 27  37.4289458125945  126.914862497173
# 28   37.494892120669  126.919491108563
# 29   37.443990193111  126.897534182853
# 30  37.5081360991077  126.922876163691
# 31  37.5731267725651  126.818459482009

# %%
# address 컬럼의 '인천'이 포함된 열 삭제

data_frame = data_frame[~data_frame['address'].str.contains('인천')]
data_frame

# address 컬럼의 '경기도'가 포함된 열 삭제

data_frame = data_frame[~data_frame['address'].str.contains('경기도')]
data_frame
# Out:
#                        name                             address  \
# 0         월드컵공원반려견놀이터반려견놀이터                    서울특별시 마포구 증산로 32
# 1               카페700반려견놀이터         서울특별시 강서구 곰달래로 104 3층 카페700
# 2              마이댕댕스쿨반려견놀이터    서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 15               까네지노반려견놀이터                서울특별시 동대문구 전농로 43 1층
# 16            도그어스플래닛반려견놀이터           서울특별시 동대문구 고산자로36길 3 경동시장
# 17     어린이대공원 반려견 놀이터반려견놀이터                   서울특별시 광진구 능동로 216
# 18        휘경2동 반려견놀이터반려견놀이터                서울특별시 동대문구 휘경동 산6-26
# 19        초안산공공반려견놀이터반려견놀이터               서울특별시 도봉구 해등로3길 48-11
# 20        당고개반려견임시놀이터반려견놀이터                서울특별시 노원구 상계동 산158-1
# 22        스테이지28웁시데이지반려견놀이터          서울특별시 강동구 아리수로61길 91-14 2층
# 24  24개스트하우스 강남강아지유치원반려견놀이터          서울특별시 강남구 봉은사로20길 52 지하 1층
# 25          개러리아 삼성본점반려견놀이터                 서울특별시 강남구 선릉로122길 4
# 26              강남강아지반려견놀이터              서울특별시 강남구 언주로79길 14 2층
# 28      보라매공원 반려견 놀이터반려견놀이터         서울특별시 동작구 여의대방로20길 33 보라매공원
# 30               개좋은날반려견놀이터  서울특별시 영등포구 여의대방로 249 우주마루에어스포렉스 1층
# 31               멍마르뜨반려견놀이터           서울특별시 강서구 양천로 132 2층 멍마르뜨
#
#                  lat              long
# 0    37.564133892331   126.89244828144
# 1   37.5303059811974  126.844330657306
# 2   37.5453792807017     126.847041591
# 15  37.5687929283359  127.056652802451
# 16  37.5790377655561  127.039142935818
# 17  37.5520117024951  127.078772391405
# 18  37.5898105688087   127.06843114526
# 19  37.6474940352509  127.041384128711
# 20  37.6758701069494  127.088353072647
# 22  37.5647216909849  127.146791775981
# 24  37.5039094079839   127.03335865347
# 25  37.5144697845871  127.042933938902
# 26  37.4993308488849   127.04287698084
# 28   37.494892120669  126.919491108563
# 30  37.5081360991077  126.922876163691
# 31  37.5731267725651  126.818459482009

# %%
# 순서대로 인덱싱
data_frame = data_frame.reset_index()
data_frame.drop(["index"], axis=1)
# Out:
#                        name                             address  \
# 0         월드컵공원반려견놀이터반려견놀이터                    서울특별시 마포구 증산로 32
# 1               카페700반려견놀이터         서울특별시 강서구 곰달래로 104 3층 카페700
# 2              마이댕댕스쿨반려견놀이터    서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 3                까네지노반려견놀이터                서울특별시 동대문구 전농로 43 1층
# 4             도그어스플래닛반려견놀이터           서울특별시 동대문구 고산자로36길 3 경동시장
# 5      어린이대공원 반려견 놀이터반려견놀이터                   서울특별시 광진구 능동로 216
# 6         휘경2동 반려견놀이터반려견놀이터                서울특별시 동대문구 휘경동 산6-26
# 7         초안산공공반려견놀이터반려견놀이터               서울특별시 도봉구 해등로3길 48-11
# 8         당고개반려견임시놀이터반려견놀이터                서울특별시 노원구 상계동 산158-1
# 9         스테이지28웁시데이지반려견놀이터          서울특별시 강동구 아리수로61길 91-14 2층
# 10  24개스트하우스 강남강아지유치원반려견놀이터          서울특별시 강남구 봉은사로20길 52 지하 1층
# 11          개러리아 삼성본점반려견놀이터                 서울특별시 강남구 선릉로122길 4
# 12              강남강아지반려견놀이터              서울특별시 강남구 언주로79길 14 2층
# 13      보라매공원 반려견 놀이터반려견놀이터         서울특별시 동작구 여의대방로20길 33 보라매공원
# 14               개좋은날반려견놀이터  서울특별시 영등포구 여의대방로 249 우주마루에어스포렉스 1층
# 15               멍마르뜨반려견놀이터           서울특별시 강서구 양천로 132 2층 멍마르뜨
#
#                  lat              long
# 0    37.564133892331   126.89244828144
# 1   37.5303059811974  126.844330657306
# 2   37.5453792807017     126.847041591
# 3   37.5687929283359  127.056652802451
# 4   37.5790377655561  127.039142935818
# 5   37.5520117024951  127.078772391405
# 6   37.5898105688087   127.06843114526
# 7   37.6474940352509  127.041384128711
# 8   37.6758701069494  127.088353072647
# 9   37.5647216909849  127.146791775981
# 10  37.5039094079839   127.03335865347
# 11  37.5144697845871  127.042933938902
# 12  37.4993308488849   127.04287698084
# 13   37.494892120669  126.919491108563
# 14  37.5081360991077  126.922876163691
# 15  37.5731267725651  126.818459482009

# %%
# csv 저장
data_frame.to_csv('./data/pet_ground.csv')

# %%
######## 카카오맵으로 다시
gu_list = ['마포구']
# gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
#            '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
#            '강남구','서초구','관악구','동작구','영등포구','금천구','구로구','양천구','강서구']

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse
import re
from bs4 import BeautifulSoup
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys



def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"}) # Rest API
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long


results = []

for find in gu_list : 
    time.sleep(10)

    driver = webdriver.Chrome(
        executable_path= "chromedriver.exe"
    )
    url = "https://map.kakao.com/"
    driver.get(url)
    action = ActionChains(driver)
    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]') # 검색 창
    search_area.send_keys(find + ' 반려견놀이터')  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    driver.implicitly_wait(3) # 기다려 주자
    more_page = driver.find_element_by_id("info.search.place.more")
    # more_page.click()
    more_page.send_keys(Keys.ENTER) # 더보기 누르고
    # 첫 번째 검색 페이지 끝
    # driver.implicitly_wait(5) # 기다려 주자
    time.sleep(1)

    # next 사용 가능?
    next_btn = driver.find_element_by_id("info.search.page.next")
    has_next = "disabled" not in next_btn.get_attribute("class").split(" ")
    Page = 1
    while True: # 다음 페이지가 있으면 loop
    # for i in range(2, 6): # 2, 3, 4, 5
        time.sleep(1)
        # place_lists = driver.find_elements_by_css_selector('#info\.search\.place\.list > li:nth-child(1)')
        # 페이지 루프
        #info\.search\.page\.no1 ~ .no5
        page_links = driver.find_elements_by_css_selector("#info\.search\.page a")
        pages = [link for link in page_links if "HIDDEN" not in link.get_attribute("class").split(" ")]
        print(len(pages), "개의 페이지 있음")
        # pages를 하나씩 클릭하면서
        for i in range(1, 6):
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            try:
                page = driver.find_element_by_xpath(xPath)
                page.send_keys(Keys.ENTER)
            except ElementNotInteractableException:
                print('End of Page')
                break;
            time.sleep(3)
            place_lists = driver.find_elements_by_css_selector('#info\.search\.place\.list > li')
            for p in place_lists: # WebElement
                # print(p.get_attribute('innerHTML'))
                # print("type of p:", type(p))
                store_html = p.get_attribute('innerHTML')
                store_info = BeautifulSoup(store_html, "html.parser")
                # BS -> 분석
                #
                place_name = store_info.select('.head_item > .tit_name > .link_name')
                
                if len(place_name) == 0:
                    continue # 광고
                name = store_info.select('.head_item > .tit_name > .link_name')[0].text
                address = store_info.select('.info_item > .addr > p')[0].text
                latitude = address_to_latitude(address)
                longtitude = address_to_longtitude(address)
                results.append((name, address, latitude, longtitude))

            print(i, ' of', ' [ ' , Page, ' ] ')
        next_btn = driver.find_element_by_id("info.search.page.next")
        has_next = "disabled" not in next_btn.get_attribute("class").split(" ")
        if not has_next:
            print('Arrow is Disabled')
            driver.close()
            break # 다음 페이지 없으니까 종료
        else: # 다음 페이지 있으면
            Page += 1
            next_btn.send_keys(Keys.ENTER)
    print("End of Crawl")

results

# import pandas as pd
# data_frame = pd.DataFrame(results, columns=['name', 'address',"lat","long"])
# data_frame
# Out:
# 1 개의 페이지 있음
# End of Page
# Arrow is Disabled
# End of Crawl
# []
