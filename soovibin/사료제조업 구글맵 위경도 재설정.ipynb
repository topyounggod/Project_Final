# %%
import pandas as pd
food = pd.read_csv("./data/서울특별시 사료제조업 인허가 정보.csv", index_col=0, encoding='CP949')

# %%
food = food.reset_index()
food
# Out:
#       개방자치단체코드                관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0      3220000  322000003420200001  20200609      NaN       1  영업/정상
# 1      3040000  304000003420190005  20191101      NaN       1  영업/정상
# 2      3050000  305000003420190001  20190826      NaN       1  영업/정상
# 3      3050000  305000003420190002  20190909      NaN       1  영업/정상
# 4      3060000  306000003420190001  20190925      NaN       1  영업/정상
# ...        ...                 ...       ...      ...     ...    ...
# 1305   3130000  313000003420210008  20210823      NaN       1  영업/정상
# 1306   3140000  314000003420210001  20210825      NaN       1  영업/정상
# 1307   6110000  611000050220210042  20210825      NaN       1  영업/정상
# 1308   6110000  611000050220210043  20210825      NaN       1  영업/정상
# 1309   6110000  611000050220210041  20210824      NaN       1  영업/정상
#
#       상세영업상태코드 상세영업상태명  폐업일자  휴업시작일자  ...  데이터갱신구분                데이터갱신일자  \
# ...

# %%
food = food[food['상세영업상태명']!='폐업']

# %%
import googlemaps
import pandas as pd
places = food['도로명주소']
my_key = ""
maps = googlemaps.Client(key='AIzaSyBe_EWzIxtwOQlPJAGqs7luMVboqNJAr0Y')  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 서울특별시 강남구 봉은사로 415 청림빌딩 지하1층 (삼성동)의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시 광진구 천호대로101길 6 2층 (중곡동)의 위치를 찾고있습니다
# 3번 인덱스에서 서울특별시 동대문구 고산자로36길 3 경동시장 신관 3층 70113호 (제기동)의 위치를 찾고있습니다
# 4번 인덱스에서 서울특별시 동대문구 답십리로 61-1 지하1층 (전농동)의 위치를 찾고있습니다
# 5번 인덱스에서 서울특별시 중랑구 상봉중앙로1길 12 (상봉동)의 위치를 찾고있습니다
# 6번 인덱스에서 서울특별시 강남구 테헤란로 230 인호IP빌딩 14층(역삼동)의 위치를 찾고있습니다
# 7번 인덱스에서 서울특별시 중랑구 망우로 385 (상봉동)의 위치를 찾고있습니다
# 8번 인덱스에서 서울특별시 중랑구 상봉중앙로8가길 46-1 1층 (상봉동)의 위치를 찾고있습니다
# 9번 인덱스에서 서울특별시 성북구 보문로13라길 14 2층 (보문동6가)의 위치를 찾고있습니다
# 10번 인덱스에서 서울특별시 성북구 화랑로39길 20 2층 (장위동)의 위치를 찾고있습니다
# 11번 인덱스에서 서울특별시 성북구 삼선교로11길 24 4층 (삼선동2가)의 위치를 찾고있습니다
# 12번 인덱스에서 서울특별시 성북구 동소문로2길 79 1층 (동소문동3가)의 위치를 찾고있습니다
# 13번 인덱스에서 서울특별시 종로구 낙산길 17 지하1층 (동숭동)의 위치를 찾고있습니다
# 14번 인덱스에서 서울특별시 종로구 자하문로 298 1층 (홍지동)의 위치를 찾고있습니다
# 15번 인덱스에서 서울특별시 종로구 사직로9길 6 (필운동)의 위치를 찾고있습니다
# 16번 인덱스에서 서울특별시 성북구 정릉로36길 24 1층 좌측호 (정릉동)의 위치를 찾고있습니다
# 17번 인덱스에서 서울특별시 성북구 보국문로24길 21-6 지층 (정릉동)의 위치를 찾고있습니다
# 18번 인덱스에서 서울특별시 중구 다산로28길 33 1층 (신당동)의 위치를 찾고있습니다
# ...

# %%
result = pd.concat([df,food], axis=1, sort=False)
result
# Out:
#              위도          경도  개방자치단체코드                관리번호     인허가일자  인허가취소일자  \
# 0     37.511071  127.045603   3220000  322000003420200001  20200609      NaN
# 1     37.559537  127.074822   3040000  304000003420190005  20191101      NaN
# 2     37.579201  127.039163   3050000  305000003420190001  20190826      NaN
# 3     37.575957  127.048123   3050000  305000003420190002  20190909      NaN
# 4     37.599598  127.087387   3060000  306000003420190001  20190925      NaN
# ...         ...         ...       ...                 ...       ...      ...
# 1305  37.569152  126.912899   3130000  313000003420210008  20210823      NaN
# 1306  37.527924    126.8532   3140000  314000003420210001  20210825      NaN
# 1307  37.587762  127.004916   6110000  611000050220210042  20210825      NaN
# 1308  37.498542  126.896452   6110000  611000050220210043  20210825      NaN
# 1309  37.553197  126.829835   6110000  611000050220210041  20210824      NaN
#
# ...

# %%
result = result.drop(['좌표정보(X)','좌표정보(Y)'], axis='columns')
result
# Out:
#              위도          경도  개방자치단체코드                관리번호     인허가일자  인허가취소일자  \
# 0     37.511071  127.045603   3220000  322000003420200001  20200609      NaN
# 1     37.559537  127.074822   3040000  304000003420190005  20191101      NaN
# 2     37.579201  127.039163   3050000  305000003420190001  20190826      NaN
# 3     37.575957  127.048123   3050000  305000003420190002  20190909      NaN
# 4     37.599598  127.087387   3060000  306000003420190001  20190925      NaN
# ...         ...         ...       ...                 ...       ...      ...
# 1305  37.569152  126.912899   3130000  313000003420210008  20210823      NaN
# 1306  37.527924    126.8532   3140000  314000003420210001  20210825      NaN
# 1307  37.587762  127.004916   6110000  611000050220210042  20210825      NaN
# 1308  37.498542  126.896452   6110000  611000050220210043  20210825      NaN
# 1309  37.553197  126.829835   6110000  611000050220210041  20210824      NaN
#
# ...

# %%
# csv 저장
result.to_csv('./data/pet_foodmake_raw.csv')
