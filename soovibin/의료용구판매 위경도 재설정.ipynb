# %%
import pandas as pd
medi = pd.read_csv("./data/서울특별시 동물용의료용구판매업 인허가 정보.csv", index_col=0, encoding='CP949')

# %%
pd.set_option('display.max_rows', None) # 전체행 출력해주는 설정명령어
# pd.reset_option('display.max_rows', None) # 원래 설정으로

# %%
medi = medi.reset_index()
medi
# Out:
#      개방자치단체코드                관리번호     인허가일자  인허가취소일자  영업상태코드           영업상태명  \
# 0     3130000  313000001320210002  20210120      NaN       1           영업/정상
# 1     3200000  320000001320210002  20210120      NaN       1           영업/정상
# 2     3210000  321000001320130001  20130409      NaN       1           영업/정상
# 3     3210000  321000001320140002  20140729      NaN       1           영업/정상
# 4     3210000  321000001320020002  20021204      NaN       1           영업/정상
# 5     3210000  321000001320090001  20090226      NaN       1           영업/정상
# 6     3210000  321000001320100001  20100312      NaN       1           영업/정상
# 7     3210000  321000001320110001  20111103      NaN       1           영업/정상
# 8     3210000  321000001319880001  19881105      NaN       1           영업/정상
# 9     3210000  321000001319980001  19980612      NaN       1           영업/정상
# 10    3040000  304000001320210003  20210906      NaN       1           영업/정상
# ...

# %%
medi = medi[medi['상세영업상태명']!='폐업']

# %%
medi = medi.reset_index()
# Out:
#      index  개방자치단체코드                관리번호     인허가일자  인허가취소일자  영업상태코드  \
# 0        0   3130000  313000001320210002  20210120      NaN       1
# 1        1   3200000  320000001320210002  20210120      NaN       1
# 2        2   3210000  321000001320130001  20130409      NaN       1
# 3        3   3210000  321000001320140002  20140729      NaN       1
# 4        4   3210000  321000001320020002  20021204      NaN       1
# 5        5   3210000  321000001320090001  20090226      NaN       1
# 6        6   3210000  321000001320100001  20100312      NaN       1
# 7        7   3210000  321000001320110001  20111103      NaN       1
# 8        8   3210000  321000001319880001  19881105      NaN       1
# 9        9   3210000  321000001319980001  19980612      NaN       1
# 10      10   3040000  304000001320210003  20210906      NaN       1
# 11      11   3210000  321000001320160001  20160531      NaN       1
# 12      12   3210000  321000001320160002  20160531      NaN       1
# ...

# %%
medi = medi.drop(['index'], axis='columns')
medi
# Out:
#      개방자치단체코드                관리번호     인허가일자  인허가취소일자  영업상태코드           영업상태명  \
# 0     3130000  313000001320210002  20210120      NaN       1           영업/정상
# 1     3200000  320000001320210002  20210120      NaN       1           영업/정상
# 2     3210000  321000001320130001  20130409      NaN       1           영업/정상
# 3     3210000  321000001320140002  20140729      NaN       1           영업/정상
# 4     3210000  321000001320020002  20021204      NaN       1           영업/정상
# 5     3210000  321000001320090001  20090226      NaN       1           영업/정상
# 6     3210000  321000001320100001  20100312      NaN       1           영업/정상
# 7     3210000  321000001320110001  20111103      NaN       1           영업/정상
# 8     3210000  321000001319880001  19881105      NaN       1           영업/정상
# 9     3210000  321000001319980001  19980612      NaN       1           영업/정상
# 10    3040000  304000001320210003  20210906      NaN       1           영업/정상
# ...

# %%
#설정변경코드
#변수 명이 두번 이상 출력되어도 모두 콘솔에서 보여줄 것
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
jibeon = medi[['지번주소']]
doro = medi[['도로명주소']]

# %%
medi[medi['지번주소'].isnull()]
medi[medi['도로명주소'].isnull()]
# Out:
#      개방자치단체코드                관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  상세영업상태코드  \
# 31    3220000  322000001320130001  20130401      NaN       1  영업/정상         0
# 65    3230000  323000001319980001  19980114      NaN       1  영업/정상         0
# 68    3230000  323000001320040001  20040219      NaN       1  영업/정상         0
# 71    3230000  323000001320130001  20130110      NaN       1  영업/정상         0
# 72    3230000  323000001320130002  20130225      NaN       1  영업/정상         0
# 73    3230000  323000001320130003  20130404      NaN       1  영업/정상         0
# 122   3050000  305000001320120001  20120427      NaN       1  영업/정상         0
# 123   3050000  305000001320150001  20151130      NaN       1  영업/정상         0
# 168   3160000  316000001320170002  20170728      NaN       1  영업/정상         0
# 181   3160000  316000001320170001  20170207      NaN       1  영업/정상         0
#
#     상세영업상태명  폐업일자  휴업시작일자  ...  데이터갱신구분                데이터갱신일자 업태구분명  \
# ...

# %%
import googlemaps
import pandas as pd
places = medi['지번주소']
my_key = ""
maps = googlemaps.Client(key='AIzaSyBe_EWzIxtwOQlPJAGqs7luMVboqNJAr0Y')  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df2 = pd.DataFrame({'위도':lat, '경도':lng})
df2
# Out:
# 1번 인덱스에서 서울특별시 마포구 망원동 394-118의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시 관악구 신림동 1730 신림푸르지오아파트 상가동의 위치를 찾고있습니다
# 3번 인덱스에서 서울특별시 서초구 잠원동 46-9번지 303호의 위치를 찾고있습니다
# 4번 인덱스에서 서울특별시 서초구 서초동 1556-2번지 의 위치를 찾고있습니다
# 5번 인덱스에서 서울특별시 서초구 양재동 275-2   번지 윈드스톤호피스텔 702호의 위치를 찾고있습니다
# 6번 인덱스에서 서울특별시 서초구 서초동 1588-3번지 로젠빌딩 1203호 의 위치를 찾고있습니다
# 7번 인덱스에서 서울특별시 서초구 방배동 752-36 B108호호의 위치를 찾고있습니다
# 8번 인덱스에서 서울특별시 서초구 서초동 1445-13번지 쌍용프래티넘 417호 의 위치를 찾고있습니다
# 9번 인덱스에서 서울특별시 서초구 서초동 1516-4번지 3층 의 위치를 찾고있습니다
# 10번 인덱스에서 서울특별시 서초구 잠원동 26-4   번지 5층 의 위치를 찾고있습니다
# 11번 인덱스에서 서울특별시 광진구 화양동 **-* 동신빌딩의 위치를 찾고있습니다
# 12번 인덱스에서 서울특별시 서초구 양재동 358-6번지 광산빌딩 의 위치를 찾고있습니다
# 13번 인덱스에서 서울특별시 서초구 양재동 358-6번지 광산빌딩 의 위치를 찾고있습니다
# 14번 인덱스에서 서울특별시 서초구 반포동 739-32번지 제이디 빌딩 의 위치를 찾고있습니다
# 15번 인덱스에서 서울특별시 서초구 원지동 312-3 솔향빌딩 2층 1호의 위치를 찾고있습니다
# 16번 인덱스에서 서울특별시 구로구 구로동 222-7 코오롱디지털타워빌란트 607호의 위치를 찾고있습니다
# 17번 인덱스에서 서울특별시 송파구 문정동 642 송파 테라타워2의 위치를 찾고있습니다
# 18번 인덱스에서 서울특별시 강남구 삼성동 159번지 코엑스인터콘티넨탈서울 의 위치를 찾고있습니다
# ...

# %%
result2 = pd.concat([df2,medi], axis=1, sort=False)
result2
# Out:
#             위도          경도  개방자치단체코드                관리번호     인허가일자  인허가취소일자  \
# 0    37.553094  126.905469   3130000  313000001320210002  20210120      NaN
# 1    37.479267  126.910368   3200000  320000001320210002  20210120      NaN
# 2    37.510369  127.017272   3210000  321000001320130001  20130409      NaN
# 3    37.491324  127.010686   3210000  321000001320140002  20140729      NaN
# 4    37.476879  127.044774   3210000  321000001320020002  20021204      NaN
# 5    37.485684  127.014190   3210000  321000001320090001  20090226      NaN
# 6    37.497799  126.984479   3210000  321000001320100001  20100312      NaN
# 7    37.484014  127.017342   3210000  321000001320110001  20111103      NaN
# 8    37.485284  127.004197   3210000  321000001319880001  19881105      NaN
# 9    37.514370  127.018263   3210000  321000001319980001  19980612      NaN
# 10   37.542012  127.065073   3040000  304000001320210003  20210906      NaN
# ...

# %%
import googlemaps
import pandas as pd
places = medi['도로명주소']
my_key = ""
maps = googlemaps.Client(key='AIzaSyBe_EWzIxtwOQlPJAGqs7luMVboqNJAr0Y')  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng})
df
# Out:
# 1번 인덱스에서 서울특별시 마포구 희우정로10길 28 (망원동)의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시 관악구 남부순환로 1430 상가동 지층 비101-4호 (신림동 신림푸르지오아파트)의 위치를 찾고있습니다
# 3번 인덱스에서 서울특별시 서초구 신반포로43길 11-11 303호 (잠원동)의 위치를 찾고있습니다
# 4번 인덱스에서 서울특별시 서초구 반포대로28길 43 (서초동)의 위치를 찾고있습니다
# 5번 인덱스에서 nan의 위치를 찾고있습니다
# 6번 인덱스에서 서울특별시 서초구 효령로55길 27 (서초동로젠빌딩 1203호)의 위치를 찾고있습니다
# 7번 인덱스에서 nan의 위치를 찾고있습니다
# 8번 인덱스에서 서울특별시 서초구 서초중앙로 18 (서초동)의 위치를 찾고있습니다
# 9번 인덱스에서 서울특별시 서초구 명달로 90 3층 (서초동)의 위치를 찾고있습니다
# 10번 인덱스에서 nan의 위치를 찾고있습니다
# 11번 인덱스에서 서울특별시 광진구 아차산로 *** 동신빌딩 지하 *층 (화양동)의 위치를 찾고있습니다
# 12번 인덱스에서 서울특별시 서초구 강남대로6길 66-18 (양재동 광산빌딩)의 위치를 찾고있습니다
# 13번 인덱스에서 서울특별시 서초구 강남대로6길 66-18 (양재동 광산빌딩)의 위치를 찾고있습니다
# 14번 인덱스에서 서울특별시 서초구 강남대로79길 32 제이디 빌딩 1층 (반포동)의 위치를 찾고있습니다
# 15번 인덱스에서 nan의 위치를 찾고있습니다
# 16번 인덱스에서 서울특별시 구로구 디지털로32길 30 코오롱디지털타워빌란트 607호 (구로동)의 위치를 찾고있습니다
# 17번 인덱스에서 서울특별시 송파구 송파대로 201 송파 테라타워2 B동 1515-2호 (문정동)의 위치를 찾고있습니다
# 18번 인덱스에서 서울특별시 강남구 봉은사로 524 코엑스인터콘티넨탈서울 지하2층 (삼성동)의 위치를 찾고있습니다
# ...

# %%
result = pd.concat([df,medi], axis=1, sort=False)
result
# Out:
#             위도          경도  개방자치단체코드                관리번호     인허가일자  인허가취소일자  \
# 0    37.553094  126.905469   3130000  313000001320210002  20210120      NaN
# 1    37.479267  126.910368   3200000  320000001320210002  20210120      NaN
# 2    37.510369  127.017272   3210000  321000001320130001  20130409      NaN
# 3    37.491324  127.010686   3210000  321000001320140002  20140729      NaN
# 4    36.127071  -79.860718   3210000  321000001320020002  20021204      NaN
# 5    37.485977  127.014097   3210000  321000001320090001  20090226      NaN
# 6    36.127071  -79.860718   3210000  321000001320100001  20100312      NaN
# 7    37.491592  127.015720   3210000  321000001320110001  20111103      NaN
# 8    37.485284  127.004197   3210000  321000001319880001  19881105      NaN
# 9    36.127071  -79.860718   3210000  321000001319980001  19980612      NaN
# 10   37.542012  127.065073   3040000  304000001320210003  20210906      NaN
# ...

# %%
result = result.drop(['좌표정보(X)','좌표정보(Y)'], axis='columns')
result
# Out:
#             위도          경도  개방자치단체코드                관리번호     인허가일자  인허가취소일자  \
# 0    37.553094  126.905469   3130000  313000001320210002  20210120      NaN
# 1    37.479267  126.910368   3200000  320000001320210002  20210120      NaN
# 2    37.510369  127.017272   3210000  321000001320130001  20130409      NaN
# 3    37.491324  127.010686   3210000  321000001320140002  20140729      NaN
# 4    36.127071  -79.860718   3210000  321000001320020002  20021204      NaN
# 5    37.485977  127.014097   3210000  321000001320090001  20090226      NaN
# 6    36.127071  -79.860718   3210000  321000001320100001  20100312      NaN
# 7    37.491592  127.015720   3210000  321000001320110001  20111103      NaN
# 8    37.485284  127.004197   3210000  321000001319880001  19881105      NaN
# 9    36.127071  -79.860718   3210000  321000001319980001  19980612      NaN
# 10   37.542012  127.065073   3040000  304000001320210003  20210906      NaN
# ...

# %%
merge = pd.merge(result, result2)
merge
# Out:
#             위도          경도  개방자치단체코드                관리번호     인허가일자  인허가취소일자  \
# 0    37.553094  126.905469   3130000  313000001320210002  20210120      NaN
# 1    37.479267  126.910368   3200000  320000001320210002  20210120      NaN
# 2    37.510369  127.017272   3210000  321000001320130001  20130409      NaN
# 3    37.491324  127.010686   3210000  321000001320140002  20140729      NaN
# 4    37.485284  127.004197   3210000  321000001319880001  19881105      NaN
# 5    37.542012  127.065073   3040000  304000001320210003  20210906      NaN
# 6    37.467779  127.044860   3210000  321000001320160001  20160531      NaN
# 7    37.467779  127.044860   3210000  321000001320160002  20160531      NaN
# 8    37.483354  126.896516   3160000  316000001320210003  20210120      NaN
# 9    37.487594  127.119173   3230000  323000001320210005  20210120      NaN
# 10   37.512619  127.057417   3220000  322000001320190008  20191128      NaN
# ...

# %%
# csv 저장
result.to_csv('./data/pet_medisales_raw.csv')
