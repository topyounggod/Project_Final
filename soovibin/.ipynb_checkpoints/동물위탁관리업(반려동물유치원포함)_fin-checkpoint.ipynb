# %%
import pandas as pd
a = pd.read_csv('./data/동물위탁관리업위경도(euc-kr).csv',encoding = 'CP949', index_col=0)

# %%
#설정변경코드
#변수 명이 두번 이상 출력되어도 모두 콘솔에서 보여줄 것
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
del a['Unnamed: 0.1']

# %%
pd.set_option('display.max_rows', None) # 전체행 출력해주는 설정명령어
# pd.reset_option('display.max_rows', None) # 원래 설정으로

# %%
# address 컬럼의 서울 제외지역이 포함된 열 삭제

a = a[~a['소재지'].str.contains('인천')]
a = a[~a['소재지'].str.contains('대구')]
a = a[~a['소재지'].str.contains('부산')]
a = a[~a['소재지'].str.contains('대전')]
a = a[~a['소재지'].str.contains('울산')]
a = a[~a['소재지'].str.contains('부산')]
a = a[~a['소재지'].str.contains('경기')]
a = a[~a['소재지'].str.contains('부산')]
a = a[~a['소재지'].str.contains('강원')]
a = a[~a['소재지'].str.contains('충청')]
a = a[~a['소재지'].str.contains('전라')]
a = a[~a['소재지'].str.contains('경상')]
a = a[~a['소재지'].str.contains('세종')]
a = a[~a['소재지'].str.contains('부산')]
a = a[~a['소재지'].str.contains('제주')]
a = a[~a['소재지'].str.contains('광주')]

# %%
import numpy as np

# %%
a
# Out:
#                           name        lat        long            address  \
# 0                       강아지대학로  37.580054   127.00368      서울특별시 종로구 동숭동
# 1                        미션코리아  37.572599   127.00217      서울특별시 종로구 효제동
# 2                      누리봄동물병원  37.575756  126.971025      서울특별시 종로구 내자동
# 3                    경희궁바른동물병원  37.571325  126.963565      서울특별시 종로구 홍파동
# 4                      월드펫동물병원  37.604919   126.96122      서울특별시 종로구 신영동
# 5                       북악동물병원  37.598864  126.960248      서울특별시 종로구 홍지동
# 6                       서촌도그살롱  37.575288  126.969615      서울특별시 종로구 필운동
# 7                          퍼플캣  37.576259  127.003653      서울특별시 종로구 이화동
# 8                  강아지 마법사 골드맘  37.562326  127.016662       서울특별시 중구 신당동
# 9                          강아지  37.551764  127.010867       서울특별시 중구 신당동
# 10                        애뚜애뚜  37.560998  127.018399       서울특별시 중구 신당동
# 11                   미래지동물의료센터  37.553641  127.009604       서울특별시 중구 신당동
# ...

# %%
import googlemaps
import pandas as pd

my_key = ""
maps = googlemaps.Client(key='AIzaSyBe_EWzIxtwOQlPJAGqs7luMVboqNJAr0Y')  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.
places = a['address']+a['name']

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng}, index=places)
print(df)
# Out:
# 1번 인덱스에서 서울특별시 종로구 동숭동강아지대학로의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시 종로구 효제동미션코리아의 위치를 찾고있습니다
# 3번 인덱스에서 서울특별시 종로구 내자동누리봄동물병원의 위치를 찾고있습니다
# 4번 인덱스에서 서울특별시 종로구 홍파동경희궁바른동물병원의 위치를 찾고있습니다
# 5번 인덱스에서 서울특별시 종로구 신영동월드펫동물병원의 위치를 찾고있습니다
# 6번 인덱스에서 서울특별시 종로구 홍지동북악동물병원의 위치를 찾고있습니다
# 7번 인덱스에서 서울특별시 종로구 필운동서촌도그살롱의 위치를 찾고있습니다
# 8번 인덱스에서 서울특별시 종로구 이화동퍼플캣의 위치를 찾고있습니다
# 9번 인덱스에서 서울특별시 중구 신당동강아지 마법사 골드맘의 위치를 찾고있습니다
# 10번 인덱스에서 서울특별시 중구 신당동강아지의 위치를 찾고있습니다
# 11번 인덱스에서 서울특별시 중구 신당동애뚜애뚜의 위치를 찾고있습니다
# 12번 인덱스에서 서울특별시 중구 신당동미래지동물의료센터의 위치를 찾고있습니다
# 13번 인덱스에서 서울특별시 중구 신당동남산동물병원의 위치를 찾고있습니다
# 14번 인덱스에서 서울특별시 중구 만리동2가백슬동물병원의 위치를 찾고있습니다
# 15번 인덱스에서 서울특별시 중구 신당동COZY의 위치를 찾고있습니다
# 16번 인덱스에서 서울특별시 중구 충무로4가대한동물병원의 위치를 찾고있습니다
# 17번 인덱스에서 서울특별시 용산구 이촌동금강동물병원의 위치를 찾고있습니다
# 18번 인덱스에서 서울특별시 용산구 이태원동케이나인클럽하우스(K9 ClubHouse)의 위치를 찾고있습니다
# 19번 인덱스에서 서울특별시 용산구 이태원동베럴라이프(BetterLife)의 위치를 찾고있습니다
# 20번 인덱스에서 서울특별시 용산구 한강로3가다줄의 위치를 찾고있습니다
# 21번 인덱스에서 서울특별시 용산구 이태원동아츠의 위치를 찾고있습니다
# 22번 인덱스에서 서울특별시 용산구 효창동도기캠프의 위치를 찾고있습니다
# ...

# %%
a
# Out:
#                           name        lat        long            address  \
# 0                       강아지대학로  37.580054  127.003680      서울특별시 종로구 동숭동
# 1                        미션코리아  37.572599  127.002170      서울특별시 종로구 효제동
# 2                      누리봄동물병원  37.575756  126.971025      서울특별시 종로구 내자동
# 3                    경희궁바른동물병원  37.571325  126.963565      서울특별시 종로구 홍파동
# 4                      월드펫동물병원  37.604919  126.961220      서울특별시 종로구 신영동
# 5                       북악동물병원  37.598864  126.960248      서울특별시 종로구 홍지동
# 6                       서촌도그살롱  37.575288  126.969615      서울특별시 종로구 필운동
# 7                          퍼플캣  37.576259  127.003653      서울특별시 종로구 이화동
# 8                  강아지 마법사 골드맘  37.562326  127.016662       서울특별시 중구 신당동
# 9                          강아지  37.551764  127.010867       서울특별시 중구 신당동
# 10                        애뚜애뚜  37.560998  127.018399       서울특별시 중구 신당동
# 11                   미래지동물의료센터  37.553641  127.009604       서울특별시 중구 신당동
# ...

# %%
df['위도'].index=range(0,len(df))
df['경도'].index=range(0,len(df))
a.index=range(0,len(a))

a['lat'] = df['위도']
a['long'] = df['경도']

# %%
a = a[['업체명', '위도', '경도', '소재지', '구분']]
a
# Out:
#                            업체명         위도          경도                소재지  \
# 0                       강아지대학로  37.580054   127.00368      서울특별시 종로구 동숭동
# 1                        미션코리아  37.572599   127.00217      서울특별시 종로구 효제동
# 2                      누리봄동물병원  37.575756  126.971025      서울특별시 종로구 내자동
# 3                    경희궁바른동물병원  37.571325  126.963565      서울특별시 종로구 홍파동
# 4                      월드펫동물병원  37.604919   126.96122      서울특별시 종로구 신영동
# 5                       북악동물병원  37.598864  126.960248      서울특별시 종로구 홍지동
# 6                       서촌도그살롱  37.575288  126.969615      서울특별시 종로구 필운동
# 7                          퍼플캣  37.576259  127.003653      서울특별시 종로구 이화동
# 8                  강아지 마법사 골드맘  37.562326  127.016662       서울특별시 중구 신당동
# 9                          강아지  37.551764  127.010867       서울특별시 중구 신당동
# 10                        애뚜애뚜  37.560998  127.018399       서울특별시 중구 신당동
# 11                   미래지동물의료센터  37.553641  127.009604       서울특별시 중구 신당동
# ...

# %%
ps = pd.read_csv("./data/pet_school.csv", index_col=0)

# %%
ps = ps[['name', 'lat', 'long', 'address', 'type']]

# %%
a = a.rename(columns={'업체명':'name', '위도':'lat', '경도':'lng', '소재지':'address', '구분':'type'})
a
# Out:
#                           name        lat        long            address  \
# 0                       강아지대학로  37.580054   127.00368      서울특별시 종로구 동숭동
# 1                        미션코리아  37.572599   127.00217      서울특별시 종로구 효제동
# 2                      누리봄동물병원  37.575756  126.971025      서울특별시 종로구 내자동
# 3                    경희궁바른동물병원  37.571325  126.963565      서울특별시 종로구 홍파동
# 4                      월드펫동물병원  37.604919   126.96122      서울특별시 종로구 신영동
# 5                       북악동물병원  37.598864  126.960248      서울특별시 종로구 홍지동
# 6                       서촌도그살롱  37.575288  126.969615      서울특별시 종로구 필운동
# 7                          퍼플캣  37.576259  127.003653      서울특별시 종로구 이화동
# 8                  강아지 마법사 골드맘  37.562326  127.016662       서울특별시 중구 신당동
# 9                          강아지  37.551764  127.010867       서울특별시 중구 신당동
# 10                        애뚜애뚜  37.560998  127.018399       서울특별시 중구 신당동
# 11                   미래지동물의료센터  37.553641  127.009604       서울특별시 중구 신당동
# ...

# %%
result = pd.concat([a,ps],axis=0)
result
# Out:
#                           name        lat        long  \
# 0                       강아지대학로  37.580054  127.003680
# 1                        미션코리아  37.572599  127.002170
# 2                      누리봄동물병원  37.575756  126.971025
# 3                    경희궁바른동물병원  37.571325  126.963565
# 4                      월드펫동물병원  37.604919  126.961220
# 5                       북악동물병원  37.598864  126.960248
# 6                       서촌도그살롱  37.575288  126.969615
# 7                          퍼플캣  37.576259  127.003653
# 8                  강아지 마법사 골드맘  37.562326  127.016662
# 9                          강아지  37.551764  127.010867
# 10                        애뚜애뚜  37.560998  127.018399
# 11                   미래지동물의료센터  37.553641  127.009604
# 12                      남산동물병원  37.549139  127.009382
# 13                      백슬동물병원  37.554325  126.965778
# 14                        COZY  37.557009  127.014661
# 15                      대한동물병원  37.562067  126.996906
# ...

# %%
# result = result.reset_index()
result = result.drop(["index"], axis=1)
result
# Out:
#                           name        lat        long  \
# 0                       강아지대학로  37.580054   127.00368
# 1                        미션코리아  37.572599   127.00217
# 2                      누리봄동물병원  37.575756  126.971025
# 3                    경희궁바른동물병원  37.571325  126.963565
# 4                      월드펫동물병원  37.604919   126.96122
# 5                       북악동물병원  37.598864  126.960248
# 6                       서촌도그살롱  37.575288  126.969615
# 7                          퍼플캣  37.576259  127.003653
# 8                  강아지 마법사 골드맘  37.562326  127.016662
# 9                          강아지  37.551764  127.010867
# 10                        애뚜애뚜  37.560998  127.018399
# 11                   미래지동물의료센터  37.553641  127.009604
# 12                      남산동물병원  37.549139  127.009382
# 13                      백슬동물병원  37.554325  126.965778
# 14                        COZY  37.557009  127.014661
# 15                      대한동물병원  37.562067  126.996906
# ...

# %%
result['type'] = '위탁관리업'
result
# Out:
#                           name        lat        long            address  \
# 0                       강아지대학로  37.580054   127.00368      서울특별시 종로구 동숭동
# 1                        미션코리아  37.572599   127.00217      서울특별시 종로구 효제동
# 2                      누리봄동물병원  37.575756  126.971025      서울특별시 종로구 내자동
# 3                    경희궁바른동물병원  37.571325  126.963565      서울특별시 종로구 홍파동
# 4                      월드펫동물병원  37.604919   126.96122      서울특별시 종로구 신영동
# 5                       북악동물병원  37.598864  126.960248      서울특별시 종로구 홍지동
# 6                       서촌도그살롱  37.575288  126.969615      서울특별시 종로구 필운동
# 7                          퍼플캣  37.576259  127.003653      서울특별시 종로구 이화동
# 8                  강아지 마법사 골드맘  37.562326  127.016662       서울특별시 중구 신당동
# 9                          강아지  37.551764  127.010867       서울특별시 중구 신당동
# 10                        애뚜애뚜  37.560998  127.018399       서울특별시 중구 신당동
# 11                   미래지동물의료센터  37.553641  127.009604       서울특별시 중구 신당동
# ...

# %%
# 저장
result.to_csv('./data/petconsign_fin.csv')

# %%
import json
import geojson
from geojson import Point, Feature, FeatureCollection, dump

# %%
result = a

# %%
a.isnull().sum()
# Out:
# name       0
# lat        4
# long       4
# address    0
# type       0
# dtype: int64

# %%
a[a['long'].isnull()]
a[a['lat'].isnull()]
a[a['address'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, lat, long, address, type]
# Index: []
# Empty DataFrame
# Columns: [name, lat, long, address, type]
# Index: []
# Empty DataFrame
# Columns: [name, lat, long, address, type]
# Index: []

# %%
a = a.dropna(axis=0)
a
# Out:
#                           name        lat        long            address  \
# 0                       강아지대학로  37.580054  127.003680      서울특별시 종로구 동숭동
# 1                        미션코리아  37.572599  127.002170      서울특별시 종로구 효제동
# 2                      누리봄동물병원  37.575756  126.971025      서울특별시 종로구 내자동
# 3                    경희궁바른동물병원  37.571325  126.963565      서울특별시 종로구 홍파동
# 4                      월드펫동물병원  37.604919  126.961220      서울특별시 종로구 신영동
# 5                       북악동물병원  37.598864  126.960248      서울특별시 종로구 홍지동
# 6                       서촌도그살롱  37.575288  126.969615      서울특별시 종로구 필운동
# 7                          퍼플캣  37.576259  127.003653      서울특별시 종로구 이화동
# 8                  강아지 마법사 골드맘  37.562326  127.016662       서울특별시 중구 신당동
# 9                          강아지  37.551764  127.010867       서울특별시 중구 신당동
# 10                        애뚜애뚜  37.560998  127.018399       서울특별시 중구 신당동
# 11                   미래지동물의료센터  37.553641  127.009604       서울특별시 중구 신당동
# ...

# %%
# 순서대로 인덱싱
a.index=range(0,len(a))

# %%
features = []
for i in range(0,len(a)): 
    point = Point((a.loc[i]["long"], a.loc[i]["lat"]))
    features.append(Feature(geometry=point, properties={"name": a.loc[i]["name"], "address":a.loc[i]["address"], "type":"위탁관리업"}))

with open('./data/위탁관리업.txt', 'w') as f:
    for item in features:
        f.write("%s\n" % item)
# Out:
# 279
# 273
# 286
# 298
# 285
# 280
# 280
# 262
# 294
# 256
# 262
# 292
# 274
# 281
# 242
# 281
# 279
# 318
# 292
# 263
# 262
# 268
# 275
# 286
# 300
# 268
# 287
# 292
# 280
# 286
# 274
# 277
# 307
# 280
# 293
# 292
# 286
# 292
# 274
# 275
# 268
# 275
# 276
# 372
# 269
# 269
# 287
# 301
# 290
# 286
# 250
# 293
# 287
# 286
# 310
# 287
# 287
# 280
# 292
# 266
# 285
# 293
# 297
# 284
# 315
# 254
# 289
# 256
# 281
# 262
# 261
# 281
# 262
# 261
# 273
# 273
# 285
# 280
# 280
# 286
# 295
# 274
# 288
# 268
# 268
# 280
# 304
# 292
# 300
# 273
# 280
# 268
# 299
# 280
# 304
# 286
# 268
# 281
# 280
# 262
# 263
# 268
# 280
# 281
# 299
# 313
# 301
# 279
# 268
# 287
# 287
# 318
# 299
# 299
# 292
# 299
# 299
# 299
# 299
# 281
# 280
# 301
# 268
# 277
# 268
# 285
# 268
# 268
# 262
# 268
# 267
# 286
# 274
# 299
# 268
# 280
# 268
# 323
# 280
# 261
# 256
# 274
# 261
# 281
# 280
# 262
# 287
# 280
# 262
# 300
# 306
# 251
# 293
# 280
# 286
# 276
# 286
# 299
# 338
# 294
# 293
# 286
# 316
# 291
# 275
# 294
# ...
