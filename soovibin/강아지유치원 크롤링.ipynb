# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse


def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization":"KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long

gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
           '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
           '강남구','서초구','관악구','동작구','영등포구','금천구','구로구','양천구','강서구']

results = []

for find in gu_list : 
# find =  input('검색할 정보를 입력하세요 : ')
    time.sleep(10)

    driver = webdriver.Chrome(
        executable_path= "chromedriver.exe"
    )
    url = "https://m.map.naver.com/"
    driver.get(url)
    action = ActionChains(driver)

    time.sleep(4)
    driver.find_element_by_class_name('Nbox_input_text').click()

    driver.find_element_by_class_name('Nbox_input_text._search_input').send_keys(find + ' 강아지유치원')
    driver.find_element_by_xpath('//*[@id="ct"]/div[1]/div[1]/form/div/div[2]/div/span[2]/button[2]').click()

    time.sleep(4)
    replys =driver.find_elements_by_xpath('//*[@id="ct"]/div[2]/ul/li')
    print(len(replys))

    for index, reply in enumerate(replys):
            name = reply.find_element_by_css_selector('div.item_tit').text
            address =reply.find_element_by_css_selector('div.wrap_item').text.split('\n')[2]
            latitude = address_to_latitude(address)
            longtitude = address_to_longtitude(address)
            results.append((name, address, latitude, longtitude))

results

import pandas as pd
pet_school = pd.DataFrame(results, columns=['name', 'address',"lat","long"])
pet_school
# Out:
# 12
# 4
# 5
# 6
# 10
# 6
# 9
# 7
# 8
# 9
# 6
# 3
# 9
# 2
# 6
# 11
# 26
# 21
# 9
# 9
# 11
# 5
# 5
# 9
# 11
#                 name                           address               lat  \
# 0           워킹페코반려동물     서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤  37.5544201275465
# 1        독핏 케어센터반려동물          서울특별시 마포구 희우정로1길 25 지하1층  37.5490501555058
# 2      하울 애견 유치원애견훈련    서울특별시 강서구 곰달래로 227 2층.3층 하울유치원  37.5318442820234
# 3          도그하우스애견훈련  서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층  37.5332609558462
# 4      키움반려견아카데미애견훈련            서울특별시 양천구 은행정로 94 201호   37.528196261865
# ..               ...                               ...               ...
# 214        댕댕당반려동물미용    경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층  37.6147823764541
# 215        도그하우스애견훈련  서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층  37.5332609558462
# 216    키움반려견아카데미애견훈련            서울특별시 양천구 은행정로 94 201호   37.528196261865
# 217     몽몽바블펫샵반려동물미용               서울특별시 양천구 중앙로36길 24  37.5195549672907
# 218  이든반려견문화센터반려동물미용                 서울특별시 양천구 은행정로 94   37.528196261865
#
#                  long
# 0     126.93035124604
# 1    126.906912467816
# 2    126.858304024983
# 3     126.86926696171
# 4    126.858790492656
# ..                ...
# 214  126.833181681644
# 215   126.86926696171
# 216  126.858790492656
# 217  126.856574713812
# 218  126.858790492656
#
# [219 rows x 4 columns]

# %%
# 중복 삭제
pet_school.drop_duplicates(ignore_index = True, inplace = True)
pet_school
# Out:
#              name                           address               lat  \
# 0        워킹페코반려동물     서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤  37.5544201275465
# 1     독핏 케어센터반려동물          서울특별시 마포구 희우정로1길 25 지하1층  37.5490501555058
# 2   하울 애견 유치원애견훈련    서울특별시 강서구 곰달래로 227 2층.3층 하울유치원  37.5318442820234
# 3       도그하우스애견훈련  서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층  37.5332609558462
# 4   키움반려견아카데미애견훈련            서울특별시 양천구 은행정로 94 201호   37.528196261865
# ..            ...                               ...               ...
# 90      몽이슈반려동물미용              경기도 광명시 광명로 855-1 3층  37.4756620142172
# 91    아름다울개반려동물미용                 경기도 광명시 도덕로 79 3층  37.4704011728529
# 92   몽몽바블펫샵반려동물미용               서울특별시 양천구 중앙로36길 24  37.5195549672907
# 93       포독반려동물미용         서울특별시 강서구 마곡동로10길 46 406호  37.5670117038671
# 94      댕댕당반려동물미용    경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층  37.6147823764541
#
#                 long
# 0    126.93035124604
# 1   126.906912467816
# 2   126.858304024983
# 3    126.86926696171
# 4   126.858790492656
# ..               ...
# 90  126.852398465616
# 91  126.856472210143
# 92  126.856574713812
# 93  126.839731201632
# 94  126.833181681644
#
# [95 rows x 4 columns]

# %%
### 주변이므로 포함시키자!!

# address 컬럼의 '인천'이 포함된 열 삭제

# pet_school = pet_school[~pet_school['address'].str.contains('인천')]
# pet_school

# # address 컬럼의 '경기도'가 포함된 열 삭제

# pet_school = pet_school[~pet_school['address'].str.contains('경기도')]
# pet_school
# Out:
#                        name                                     address  \
# 0                  워킹페코반려동물               서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤
# 1               독핏 케어센터반려동물                    서울특별시 마포구 희우정로1길 25 지하1층
# 2             하울 애견 유치원애견훈련              서울특별시 강서구 곰달래로 227 2층.3층 하울유치원
# 3                 도그하우스애견훈련            서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층
# 4             키움반려견아카데미애견훈련                      서울특별시 양천구 은행정로 94 201호
# 5           이든반려견문화센터반려동물미용                           서울특별시 양천구 은행정로 94
# 6                강아지정류장애견카페                           서울특별시 강서구 양천로 709
# 7                  도기캠프애견훈련  서울특별시 용산구 백범로 313 롯데캐슬상가 B2층 203,204호 도기캠프
# 9              곁에 있을개반려동물미용                        서울특별시 강서구 화곡로66길 162
# 10             마이댕댕스쿨반려견놀이터            서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 11                꽃길만가개반려동물                       서울특별시 강서구 화곡로42가길 5-7
# 12     박준훈련사애견유치원강아지훈련소애견훈련                           서울특별시 중구 세종대로 136
# 13         내생각애견호텔유치원반려동물호텔                        서울특별시 은평구 연서로 298 2층
# 17               강아지대학로애견카페                    서울특별시 종로구 대학로12길 92 지하1층
# 18           핫Dog 1호점반려동물미용                         서울특별시 강북구 노해로11길 41
# 19              GODOG반려동물미용                       서울특별시 성북구 삼양로 69 지상1층
# 20                 멍멍슈퍼반려동물                         서울특별시 강북구 노해로7길 7-1
# 21                 더케어코리아기업                   서울특별시 성북구 삼양로4길 3 한림빌딩 4F
# 32                 도기캠프애견훈련  서울특별시 용산구 백범로 313 롯데캐슬상가 B2층 203,204호 도기캠프
# 33          스타몽 강아지 유치원애견훈련               서울특별시 서초구 서초대로73길 12 세계빌딩 B1층
# 34            나밍밍강아지네반려동물미용           서울특별시 동작구 서달로 150 이랜드 해가든 상가 110호
# 35           프랑소와펫 아카데미애견훈련                       서울특별시 서초구 서래로 47 지하1층
# 36               브이케어반려동물미용                     서울특별시 서초구 강남대로79길 32 2층
# 37                  슈퍼독애견훈련                서울특별시 영등포구 여의동로 213 상가층 114호
# 38          바우라움 강아지유치원애견훈련                  서울특별시 성동구 왕십리로 241 4층 바우라움
# 81        하울팟 케어클럽 서초본점반려동물                   서울특별시 서초구 서초대로58길 36 4~5F
# 82                유어마이독반려동물                     서울특별시 서초구 도구로 128-13 1층
# 83                디어몽반려동물미용                          서울특별시 관악구 난곡로63길 6
# 84                투퍼피반려동물호텔                    서울특별시 관악구 신림로 387 3층 투퍼피
# 85              개라다이스반려동물호텔                      서울특별시 관악구 봉천로 283 대윤빌딩
# 86              태우하우스반려동물호텔                           서울특별시 관악구 신림로 242
# 87                다즐링반려동물미용                  서울특별시 영등포구 신길로 119 1층 121호
# 89        박준강아지유치원애견훈련소애견훈련                           서울특별시 영등포구 영중로 15
# 92             몽몽바블펫샵반려동물미용                         서울특별시 양천구 중앙로36길 24
# 93                 포독반려동물미용                   서울특별시 강서구 마곡동로10길 46 406호
#
#           lat        long
# 0   37.554420  126.930351
# 1   37.549050  126.906912
# 2   37.531844  126.858304
# 3   37.533261  126.869267
# 4   37.528196  126.858790
# 5   37.528196  126.858790
# 6   37.549923  126.874825
# 7   37.549923  126.874825
# 9   37.554540  126.861604
# 10  37.545379  126.847042
# 11  37.546245  126.846170
# 12  37.568423  126.978257
# 13  37.622098  126.927099
# 17  37.580098  127.003684
# 18  37.638785  127.020288
# 19  37.609162  127.022785
# 20  37.637767  127.022423
# 21  37.605817  127.024368
# 32  37.422577  126.647451
# 33  37.498550  127.025735
# 34  37.506627  126.962184
# 35  37.499166  126.998123
# 36  37.504720  127.022474
# 37  37.518595  126.939630
# 38  37.557154  127.040105
# 39  37.547460  127.044776
# 40  37.545677  127.042915
# 41  37.539258  127.044672
# 42  37.559255  127.076549
# 43  37.561882  127.082686
# 44  37.523545  127.029806
# 45  37.525217  127.055506
# 46  37.559541  127.087860
# 47  37.513713  127.061909
# 48  37.513752  127.104447
# 49  37.544043  127.121281
# 50  37.618412  127.036476
# 51  37.606177  127.061522
# 52  37.618734  127.045028
# 53  37.656642  127.062991
# 54  37.670375  127.082133
# 59  37.546365  127.134702
# 63  37.505370  127.085268
# 64  37.483756  127.129979
# 65  37.489003  127.124458
# 66  37.495209  127.126523
# 67  37.488586  127.124152
# 68  37.510023  127.079529
# 69  37.480834  127.121277
# 70  37.503909  127.033359
# 71  37.493616  127.035481
# 72  37.500024  127.036509
# 73  37.499331  127.042877
# 74  37.515576  127.030675
# 75  37.504616  127.034044
# 76  37.476438  127.046310
# 77  37.512018  127.041166
# 78  37.479534  127.042570
# 79  37.544043  127.121281
# 80  37.496233  126.997134
# 81  37.479534  127.042570
# 82  37.488285  126.986714
# 83  37.481158  126.914208
# 84  37.488656  126.928064
# 85  37.487661  126.932624
# 86  37.477920  126.934527
# 87  37.503510  126.909710
# 89  37.517233  126.903716
# 92  37.519555  126.856575
# 93  37.567012  126.839731

# %%
pet_school['address'].isnull().sum()
# Out:
# 0

# %%
## 위 데이터를 가지고 구글맵위경도를 뽑는다
import googlemaps
import pandas as pd

my_key = ""
maps = googlemaps.Client(key='AIzaSyBe_EWzIxtwOQlPJAGqs7luMVboqNJAr0Y')  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.
places = pet_school['address']

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng}, index=places)
df
# Out:
# 1번 인덱스에서 서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시 마포구 희우정로1길 25 지하1층의 위치를 찾고있습니다
# 3번 인덱스에서 서울특별시 강서구 곰달래로 227 2층.3층 하울유치원의 위치를 찾고있습니다
# 4번 인덱스에서 서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층의 위치를 찾고있습니다
# 5번 인덱스에서 서울특별시 양천구 은행정로 94 201호의 위치를 찾고있습니다
# 6번 인덱스에서 서울특별시 용산구 백범로 313 롯데캐슬상가 B2층 203,204호 도기캠프의 위치를 찾고있습니다
# 7번 인덱스에서 경기도 고양시 덕양구 꽃마을로 4 퍼스트타워 310호의 위치를 찾고있습니다
# 8번 인덱스에서 서울특별시 양천구 은행정로 94의 위치를 찾고있습니다
# 9번 인덱스에서 서울특별시 강서구 화곡로66길 162의 위치를 찾고있습니다
# 10번 인덱스에서 서울특별시 강서구 양천로 709의 위치를 찾고있습니다
# 11번 인덱스에서 서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨의 위치를 찾고있습니다
# 12번 인덱스에서 서울특별시 강서구 화곡로42가길 5-7의 위치를 찾고있습니다
# 13번 인덱스에서 서울특별시 중구 세종대로 136의 위치를 찾고있습니다
# 14번 인덱스에서 서울특별시 은평구 연서로 298 2층의 위치를 찾고있습니다
# 15번 인덱스에서 경기도 고양시 덕양구 서삼릉길 357 1층의 위치를 찾고있습니다
# 16번 인덱스에서 경기도 고양시 덕양구 통일로 210 1층의 위치를 찾고있습니다
# 17번 인덱스에서 경기도 고양시 덕양구 의장로 122 원프라자 4층의 위치를 찾고있습니다
# 18번 인덱스에서 서울특별시 종로구 대학로12길 92 지하1층의 위치를 찾고있습니다
# 19번 인덱스에서 서울특별시 강북구 노해로11길 41의 위치를 찾고있습니다
# 20번 인덱스에서 서울특별시 성북구 삼양로 69 지상1층의 위치를 찾고있습니다
# 21번 인덱스에서 서울특별시 강북구 노해로7길 7-1의 위치를 찾고있습니다
# 22번 인덱스에서 서울특별시 성북구 삼양로4길 3 한림빌딩 4F의 위치를 찾고있습니다
# 23번 인덱스에서 인천광역시 중구 월촌길 52의 위치를 찾고있습니다
# 24번 인덱스에서 인천광역시 중구 운중로 170 러블리독의 위치를 찾고있습니다
# 25번 인덱스에서 인천광역시 중구 운중로48번길 102의 위치를 찾고있습니다
# 26번 인덱스에서 인천광역시 중구 논골길 5의 위치를 찾고있습니다
# 27번 인덱스에서 인천광역시 연수구 하모니로 158 D동 412호의 위치를 찾고있습니다
# 28번 인덱스에서 인천광역시 서구 청라한내로100번길 8-28의 위치를 찾고있습니다
# 29번 인덱스에서 인천광역시 서구 청라한내로161번길 3-3 4층 아토사랑스러워의 위치를 찾고있습니다
# 30번 인덱스에서 인천광역시 연수구 하모니로188번길 17 SK뷰센트럴 상가 218호의 위치를 찾고있습니다
# 31번 인덱스에서 인천광역시 연수구 아트센터대로 107 커낼워크 301동 513호의 위치를 찾고있습니다
# 32번 인덱스에서 인천광역시 연수구 한나루로 87 주문빌딩5층의 위치를 찾고있습니다
# 33번 인덱스에서 서울특별시 용산구 백범로 313 롯데캐슬상가 B2층 203,204호 도기캠프의 위치를 찾고있습니다
# 34번 인덱스에서 서울특별시 서초구 서초대로73길 12 세계빌딩 B1층의 위치를 찾고있습니다
# 35번 인덱스에서 서울특별시 동작구 서달로 150 이랜드 해가든 상가 110호의 위치를 찾고있습니다
# 36번 인덱스에서 서울특별시 서초구 서래로 47 지하1층의 위치를 찾고있습니다
# 37번 인덱스에서 서울특별시 서초구 강남대로79길 32 2층의 위치를 찾고있습니다
# 38번 인덱스에서 서울특별시 영등포구 여의동로 213 상가층 114호의 위치를 찾고있습니다
# 39번 인덱스에서 서울특별시 성동구 왕십리로 241 4층 바우라움의 위치를 찾고있습니다
# 40번 인덱스에서 서울특별시 성동구 왕십리로 110 2층의 위치를 찾고있습니다
# 41번 인덱스에서 서울특별시 성동구 서울숲2길 32-14 101동 106~107호의 위치를 찾고있습니다
# 42번 인덱스에서 서울특별시 성동구 왕십리로 16 트리마제 상가 103호의 위치를 찾고있습니다
# 43번 인덱스에서 서울특별시 광진구 동일로62길 41의 위치를 찾고있습니다
# 44번 인덱스에서 서울특별시 광진구 긴고랑로 60 2층 뚜뚜미엘의 위치를 찾고있습니다
# 45번 인덱스에서 서울특별시 강남구 논현로164길 17의 위치를 찾고있습니다
# 46번 인덱스에서 서울특별시 강남구 영동대로142길 27 1층의 위치를 찾고있습니다
# 47번 인덱스에서 서울특별시 광진구 용마산로 66 3층 와사비네집의 위치를 찾고있습니다
# 48번 인덱스에서 서울특별시 강남구 봉은사로104길 10 동화빌딩 4층의 위치를 찾고있습니다
# 49번 인덱스에서 서울특별시 송파구 올림픽로 300의 위치를 찾고있습니다
# 50번 인덱스에서 서울특별시 강동구 천중로2길 57 노승빌딩 5층의 위치를 찾고있습니다
# 51번 인덱스에서 서울특별시 강북구 오현로 56 꿈의숲 롯데캐슬 101동 4호의 위치를 찾고있습니다
# 52번 인덱스에서 서울특별시 성북구 돌곶이로 19 한양빌딩 1층 골목 초입의 위치를 찾고있습니다
# 53번 인덱스에서 서울특별시 성북구 월계로32길 24의 위치를 찾고있습니다
# 54번 인덱스에서 서울특별시 노원구 상계로 71-1 2층의 위치를 찾고있습니다
# 55번 인덱스에서 서울특별시 노원구 덕릉로126길 12 병창빌딩의 위치를 찾고있습니다
# 56번 인덱스에서 경기도 남양주시 별내3로 334 다우프라자 2층 멍뭉유치원의 위치를 찾고있습니다
# 57번 인덱스에서 경기도 남양주시 별내5로23번길 18-26 1층 리틀원의 위치를 찾고있습니다
# 58번 인덱스에서 경기도 남양주시 불암로81번길 7의 위치를 찾고있습니다
# 59번 인덱스에서 경기도 남양주시 덕송2로10번길 15-94 102호의 위치를 찾고있습니다
# 60번 인덱스에서 서울특별시 강동구 구천면로42길 8 5층의 위치를 찾고있습니다
# 61번 인덱스에서 경기도 하남시 미사강변중앙로 189 에코브릿지2 308,309호의 위치를 찾고있습니다
# 62번 인덱스에서 경기도 하남시 미사강변한강로136번안길 9 1층의 위치를 찾고있습니다
# 63번 인덱스에서 경기도 하남시 미사강변중앙로 221 센트럴파크2 305호 안녕강아지의 위치를 찾고있습니다
# 64번 인덱스에서 서울특별시 송파구 백제고분로 165 서도빌딩의 위치를 찾고있습니다
# 65번 인덱스에서 서울특별시 송파구 새말로 146 하나빌딩 3층의 위치를 찾고있습니다
# 66번 인덱스에서 서울특별시 송파구 동남로4길 13 지하1층의 위치를 찾고있습니다
# 67번 인덱스에서 서울특별시 송파구 중대로16길 19-10의 위치를 찾고있습니다
# 68번 인덱스에서 서울특별시 송파구 문정로1길 26의 위치를 찾고있습니다
# 69번 인덱스에서 서울특별시 송파구 백제고분로7길 6-5 지하1층의 위치를 찾고있습니다
# 70번 인덱스에서 서울특별시 송파구 새말로 62 송파 푸르지오시티의 위치를 찾고있습니다
# 71번 인덱스에서 서울특별시 강남구 봉은사로20길 52 지하 1층의 위치를 찾고있습니다
# 72번 인덱스에서 서울특별시 강남구 역삼로14길 14 명진빌딩 3층의 위치를 찾고있습니다
# 73번 인덱스에서 서울특별시 강남구 테헤란로 152의 위치를 찾고있습니다
# 74번 인덱스에서 서울특별시 강남구 언주로79길 14 2층의 위치를 찾고있습니다
# 75번 인덱스에서 서울특별시 강남구 논현로134길 5의 위치를 찾고있습니다
# 76번 인덱스에서 서울특별시 강남구 논현로101길 10의 위치를 찾고있습니다
# 77번 인덱스에서 서울특별시 강남구 논현로 70 동성빌딩 2층의 위치를 찾고있습니다
# 78번 인덱스에서 서울특별시 강남구 선릉로115길 22의 위치를 찾고있습니다
# 79번 인덱스에서 서울특별시 서초구 양재천로 141의 위치를 찾고있습니다
# 80번 인덱스에서 서울특별시 서초구 서초대로58길 36 4~5F의 위치를 찾고있습니다
# 81번 인덱스에서 서울특별시 서초구 서래로1길 18 엠제이빌딩 1층, 지하1층의 위치를 찾고있습니다
# 82번 인덱스에서 서울특별시 서초구 서초대로58길 36 4~5F의 위치를 찾고있습니다
# 83번 인덱스에서 서울특별시 서초구 도구로 128-13 1층의 위치를 찾고있습니다
# 84번 인덱스에서 서울특별시 관악구 난곡로63길 6의 위치를 찾고있습니다
# 85번 인덱스에서 서울특별시 관악구 신림로 387 3층 투퍼피의 위치를 찾고있습니다
# 86번 인덱스에서 서울특별시 관악구 봉천로 283 대윤빌딩의 위치를 찾고있습니다
# 87번 인덱스에서 서울특별시 관악구 신림로 242의 위치를 찾고있습니다
# 88번 인덱스에서 서울특별시 영등포구 신길로 119 1층 121호의 위치를 찾고있습니다
# 89번 인덱스에서 경기도 광명시 금하로 534 종만빌딩 4층의 위치를 찾고있습니다
# 90번 인덱스에서 서울특별시 영등포구 영중로 15의 위치를 찾고있습니다
# 91번 인덱스에서 경기도 광명시 광명로 855-1 3층의 위치를 찾고있습니다
# 92번 인덱스에서 경기도 광명시 도덕로 79 3층의 위치를 찾고있습니다
# 93번 인덱스에서 서울특별시 양천구 중앙로36길 24의 위치를 찾고있습니다
# 94번 인덱스에서 서울특별시 강서구 마곡동로10길 46 406호의 위치를 찾고있습니다
# 95번 인덱스에서 경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층의 위치를 찾고있습니다
#                                          위도          경도
# address
# 서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤     37.554369  126.930353
# 서울특별시 마포구 희우정로1길 25 지하1층          37.549023  126.906857
# 서울특별시 강서구 곰달래로 227 2층.3층 하울유치원    37.531799  126.858282
# 서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층  37.533221  126.869255
# 서울특별시 양천구 은행정로 94 201호            37.528157  126.858781
# ...                                     ...         ...
# 경기도 광명시 광명로 855-1 3층              37.475617  126.852392
# 경기도 광명시 도덕로 79 3층                 37.470397  126.856084
# 서울특별시 양천구 중앙로36길 24               37.519515  126.856562
# 서울특별시 강서구 마곡동로10길 46 406호         37.559003  126.834321
# 경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층    37.614741  126.833169
#
# [95 rows x 2 columns]

# %%
df
# Out:
#                                          위도          경도
# address
# 서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤     37.554369  126.930353
# 서울특별시 마포구 희우정로1길 25 지하1층          37.549023  126.906857
# 서울특별시 강서구 곰달래로 227 2층.3층 하울유치원    37.531799  126.858282
# 서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층  37.533221  126.869255
# 서울특별시 양천구 은행정로 94 201호            37.528157  126.858781
# ...                                     ...         ...
# 경기도 광명시 광명로 855-1 3층              37.475617  126.852392
# 경기도 광명시 도덕로 79 3층                 37.470397  126.856084
# 서울특별시 양천구 중앙로36길 24               37.519515  126.856562
# 서울특별시 강서구 마곡동로10길 46 406호         37.559003  126.834321
# 경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층    37.614741  126.833169
#
# [95 rows x 2 columns]

# %%
# 순서대로 인덱싱
# pet_school = pet_school.reset_index()
# pet_school.drop(["index"], axis=1)
# Out:
#              name                           address               lat  \
# 0        워킹페코반려동물     서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤  37.5544201275465
# 1     독핏 케어센터반려동물          서울특별시 마포구 희우정로1길 25 지하1층  37.5490501555058
# 2   하울 애견 유치원애견훈련    서울특별시 강서구 곰달래로 227 2층.3층 하울유치원  37.5318442820234
# 3       도그하우스애견훈련  서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층  37.5332609558462
# 4   키움반려견아카데미애견훈련            서울특별시 양천구 은행정로 94 201호   37.528196261865
# ..            ...                               ...               ...
# 90      몽이슈반려동물미용              경기도 광명시 광명로 855-1 3층  37.4756620142172
# 91    아름다울개반려동물미용                 경기도 광명시 도덕로 79 3층  37.4704011728529
# 92   몽몽바블펫샵반려동물미용               서울특별시 양천구 중앙로36길 24  37.5195549672907
# 93       포독반려동물미용         서울특별시 강서구 마곡동로10길 46 406호  37.5670117038671
# 94      댕댕당반려동물미용    경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층  37.6147823764541
#
#                 long
# 0    126.93035124604
# 1   126.906912467816
# 2   126.858304024983
# 3    126.86926696171
# 4   126.858790492656
# ..               ...
# 90  126.852398465616
# 91  126.856472210143
# 92  126.856574713812
# 93  126.839731201632
# 94  126.833181681644
#
# [95 rows x 4 columns]

# %%
df['위도'].index=range(0,len(df))
df['경도'].index=range(0,len(df))

# %%
pet_school.index=range(0,len(pet_school))

# %%
pet_school['lat'] = df['위도']
pet_school['long'] = df['경도']

# %%
pet_school.columns
# Out:
# Index(['index', 'name', 'address', 'lat', 'long'], dtype='object')

# %%
a = pet_school[['index', 'lat', 'long', 'name', 'address']]

# %%
a = a.drop(['index'], axis=1)
a
# Out:
#           lat        long           name                           address
# 0   37.554369  126.930353       워킹페코반려동물     서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤
# 1   37.549023  126.906857    독핏 케어센터반려동물          서울특별시 마포구 희우정로1길 25 지하1층
# 2   37.531799  126.858282  하울 애견 유치원애견훈련    서울특별시 강서구 곰달래로 227 2층.3층 하울유치원
# 3   37.533221  126.869255      도그하우스애견훈련  서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층
# 4   37.528157  126.858781  키움반려견아카데미애견훈련            서울특별시 양천구 은행정로 94 201호
# ..        ...         ...            ...                               ...
# 90  37.475617  126.852392      몽이슈반려동물미용              경기도 광명시 광명로 855-1 3층
# 91  37.470397  126.856084    아름다울개반려동물미용                 경기도 광명시 도덕로 79 3층
# 92  37.519515  126.856562   몽몽바블펫샵반려동물미용               서울특별시 양천구 중앙로36길 24
# 93  37.559003  126.834321       포독반려동물미용         서울특별시 강서구 마곡동로10길 46 406호
# 94  37.614741  126.833169      댕댕당반려동물미용    경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층
#
# [95 rows x 4 columns]

# %%
a['type'] = '동물위탁관리업'

# %%
a
# Out:
#           lat        long           name                           address  \
# 0   37.554369  126.930353       워킹페코반려동물     서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤
# 1   37.549023  126.906857    독핏 케어센터반려동물          서울특별시 마포구 희우정로1길 25 지하1층
# 2   37.531799  126.858282  하울 애견 유치원애견훈련    서울특별시 강서구 곰달래로 227 2층.3층 하울유치원
# 3   37.533221  126.869255      도그하우스애견훈련  서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층
# 4   37.528157  126.858781  키움반려견아카데미애견훈련            서울특별시 양천구 은행정로 94 201호
# ..        ...         ...            ...                               ...
# 90  37.475617  126.852392      몽이슈반려동물미용              경기도 광명시 광명로 855-1 3층
# 91  37.470397  126.856084    아름다울개반려동물미용                 경기도 광명시 도덕로 79 3층
# 92  37.519515  126.856562   몽몽바블펫샵반려동물미용               서울특별시 양천구 중앙로36길 24
# 93  37.559003  126.834321       포독반려동물미용         서울특별시 강서구 마곡동로10길 46 406호
# 94  37.614741  126.833169      댕댕당반려동물미용    경기도 고양시 덕양구 무원로6번길 61 GL프라자 3층
#
#        type
# 0   동물위탁관리업
# 1   동물위탁관리업
# 2   동물위탁관리업
# 3   동물위탁관리업
# 4   동물위탁관리업
# ..      ...
# 90  동물위탁관리업
# 91  동물위탁관리업
# 92  동물위탁관리업
# 93  동물위탁관리업
# 94  동물위탁관리업
#
# [95 rows x 5 columns]

# %%
# 저장
a.to_csv('./data/pet_school.csv')

# %%
## 반려동물훈련 (***폐기***)

def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization":"KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long

gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
           '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
           '강남구','서초구','관악구','동작구','영등포구','금천구','구로구','양천구','강서구']

results = []

for find in gu_list : 
# find =  input('검색할 정보를 입력하세요 : ')
    time.sleep(10)

    driver = webdriver.Chrome(
        executable_path= "chromedriver.exe"
    )
    url = "https://m.map.naver.com/"
    driver.get(url)
    action = ActionChains(driver)

    time.sleep(4)
    driver.find_element_by_class_name('Nbox_input_text').click()

    driver.find_element_by_class_name('Nbox_input_text._search_input').send_keys(find + ' 반려동물훈련')
    driver.find_element_by_xpath('//*[@id="ct"]/div[1]/div[1]/form/div/div[2]/div/span[2]/button[2]').click()

    time.sleep(4)
    replys =driver.find_elements_by_xpath('//*[@id="ct"]/div[2]/ul/li')
    print(len(replys))

    for index, reply in enumerate(replys):
            name = reply.find_element_by_css_selector('div.item_tit').text
            address =reply.find_element_by_css_selector('div.wrap_item').text.split('\n')[2]
            latitude = address_to_latitude(address)
            longtitude = address_to_longtitude(address)
            results.append((name, address, latitude, longtitude))

results

import pandas as pd
data_frame_i = pd.DataFrame(results, columns=['name', 'address',"lat","long"])
data_frame_i
# Out:
# 0
# 2
# 1
# 0
# 11
# 1
# 2
# 5
# 1
# 1
# 0
# 1
# 4
# 2
# 4
# 9
# 10
# 5
# 1
# 0
# 2
# 2
# 0
# 6
# 4
#              name address               lat              long
# 0     연희동 미미네애견훈련    주소보기  37.5605683150719  127.075145570006
# 1       쓰담 에듀애견훈련    주소보기  37.5605683150719  127.075145570006
# 2          독티애견훈련    주소보기  37.5605683150719  127.075145570006
# 3     멜리애견유치원애견훈련    주소보기  37.5605683150719  127.075145570006
# 4       훈트가르텐애견훈련    주소보기  37.5605683150719  127.075145570006
# ..            ...     ...               ...               ...
# 69   이든애견미용반려동물미용    주소보기  37.5605683150719  127.075145570006
# 70  하울 애견 유치원애견훈련    주소보기  37.5605683150719  127.075145570006
# 71      독스네이처애견훈련    주소보기  37.5605683150719  127.075145570006
# 72     한양애견학교애견훈련    주소보기  37.5605683150719  127.075145570006
# 73   부산애견훈련학교애견훈련    주소보기  37.5605683150719  127.075145570006
#
# [74 rows x 4 columns]

# %%
# 중복 삭제
data_frame_i.drop_duplicates(ignore_index = True, inplace = True)
data_frame_i
# Out:
#              name address               lat              long
# 0     연희동 미미네애견훈련    주소보기  37.5605683150719  127.075145570006
# 1       쓰담 에듀애견훈련    주소보기  37.5605683150719  127.075145570006
# 2          독티애견훈련    주소보기  37.5605683150719  127.075145570006
# 3     멜리애견유치원애견훈련    주소보기  37.5605683150719  127.075145570006
# 4       훈트가르텐애견훈련    주소보기  37.5605683150719  127.075145570006
# ..            ...     ...               ...               ...
# 69   이든애견미용반려동물미용    주소보기  37.5605683150719  127.075145570006
# 70  하울 애견 유치원애견훈련    주소보기  37.5605683150719  127.075145570006
# 71      독스네이처애견훈련    주소보기  37.5605683150719  127.075145570006
# 72     한양애견학교애견훈련    주소보기  37.5605683150719  127.075145570006
# 73   부산애견훈련학교애견훈련    주소보기  37.5605683150719  127.075145570006
#
# [74 rows x 4 columns]

# %%
# csv 저장
data_frame_i.to_csv('./data/pet_training.csv')

# %%
pet_ground = pd.read_csv("./data/pet_ground.csv", index_col=0)
pet_school = pd.read_csv("./data/pet_school.csv", index_col=0)
# pet_training = pd.read_csv("./data/pet_training.csv", index_col=0) # 반려동물훈련학교는 주소가 없음 (****폐기****)

# %%
pd.set_option('display.max_rows', None) # 전체행 출력해주는 설정명령어
# pd.reset_option('display.max_rows', None) # 원래 설정으로

# %%
pet_ground
pet_school
# Out:
#     index                     name  \
# 0       0                 워킹페코반려동물
# 1       1              독핏 케어센터반려동물
# 2       2            하울 애견 유치원애견훈련
# 3       3                도그하우스애견훈련
# 4       4            키움반려견아카데미애견훈련
# 5       5          이든반려견문화센터반려동물미용
# 6       6               강아지정류장애견카페
# 7       7                 도기캠프애견훈련
# 8       9             곁에 있을개반려동물미용
# 9      10             마이댕댕스쿨반려견놀이터
# 10     11                꽃길만가개반려동물
# 11     12     박준훈련사애견유치원강아지훈련소애견훈련
# 12     13         내생각애견호텔유치원반려동물호텔
# 13     17               강아지대학로애견카페
# 14     18           핫Dog 1호점반려동물미용
# 15     19              GODOG반려동물미용
# 16     20                 멍멍슈퍼반려동물
# 17     21                 더케어코리아기업
# 18     32                 도기캠프애견훈련
# 19     33          스타몽 강아지 유치원애견훈련
# 20     34            나밍밍강아지네반려동물미용
# 21     35           프랑소와펫 아카데미애견훈련
# 22     36               브이케어반려동물미용
# 23     37                  슈퍼독애견훈련
# 24     38          바우라움 강아지유치원애견훈련
# 25     39             댕댕이하우스반려동물미용
# 26     40              9PETS반려동물미용
# 27     41               모동모동반려동물미용
# 28     42                  키즈멍애견훈련
# 29     43               뚜뚜미엘반려동물미용
# 30     44                  필스타반려동물
# 31     45                  바라봄애견카페
# 32     46                와사비네집애견훈련
# 33     47          강아지유치원 퍼피스쿨반려동물
# 34     48        박준애견유치원강아지훈련소애견훈련
# 35     49        한강펫케어센터 강동점반려동물호텔
# 36     50               코코퍼피반려동물미용
# 37     51               마이도그반려동물미용
# 38     52           땡일리 강아지유치원애견훈련
# 39     53             도니바니애견카페애견카페
# 40     54                포레스트독반려동물
# 41     59             제제네멍치원반려동물호텔
# 42     63             MM애견공방반려동물미용
# 43     64             펫도그 애견스쿨애견훈련
# 44     65                  힐링몽애견훈련
# 45     66             멍찌네하우스반려동물호텔
# 46     67              멍돌하우스반려동물호텔
# 47     68                 돌봄반려동물호텔
# 48     69             갓독애견호텔반려동물호텔
# 49     70  24개스트하우스 강남강아지유치원반려견놀이터
# 50     71        멍투게더 강아지유치원반려동물호텔
# 51     72         준애견훈련소강아지유치원애견훈련
# 52     73              강남강아지반려견놀이터
# 53     74                 해피퍼피애견훈련
# 54     75             스타일리다독반려동물미용
# 55     76            나나리펫하우스반려동물호텔
# 56     77               전설의강아지애견카페
# 57     78        야옹아멍멍해봐 양재점반려동물분양
# 58     79        하울팟 케어클럽 서초본점반려동물
# 7      19        초안산공공반려견놀이터반려견놀이터
# 8      20        당고개반려견임시놀이터반려견놀이터
# 9      22        스테이지28웁시데이지반려견놀이터
# 10     24  24개스트하우스 강남강아지유치원반려견놀이터
# 11     25          개러리아 삼성본점반려견놀이터
# 12     26              강남강아지반려견놀이터
# 13     28      보라매공원 반려견 놀이터반려견놀이터
# 14     30               개좋은날반려견놀이터
# 15     31               멍마르뜨반려견놀이터
# 0       0                 워킹페코반려동물
# 1       1              독핏 케어센터반려동물
# 2       2            하울 애견 유치원애견훈련
# 3       3                도그하우스애견훈련
# 4       4            키움반려견아카데미애견훈련
# 5       5          이든반려견문화센터반려동물미용
# 6       6               강아지정류장애견카페
# 7       7                 도기캠프애견훈련
# 8       9             곁에 있을개반려동물미용
# 9      10             마이댕댕스쿨반려견놀이터
# 10     11                꽃길만가개반려동물
# 11     12     박준훈련사애견유치원강아지훈련소애견훈련
# 12     13         내생각애견호텔유치원반려동물호텔
# 13     17               강아지대학로애견카페
# 14     18           핫Dog 1호점반려동물미용
# 15     19              GODOG반려동물미용
# 16     20                 멍멍슈퍼반려동물
# 17     21                 더케어코리아기업
# 18     32                 도기캠프애견훈련
# 19     33          스타몽 강아지 유치원애견훈련
# 20     34            나밍밍강아지네반려동물미용
# 21     35           프랑소와펫 아카데미애견훈련
# 22     36               브이케어반려동물미용
# 23     37                  슈퍼독애견훈련
# 24     38          바우라움 강아지유치원애견훈련
# 25     39             댕댕이하우스반려동물미용
# 26     40              9PETS반려동물미용
# 27     41               모동모동반려동물미용
# 28     42                  키즈멍애견훈련
# 29     43               뚜뚜미엘반려동물미용
# 30     44                  필스타반려동물
# 31     45                  바라봄애견카페
# 32     46                와사비네집애견훈련
# 33     47          강아지유치원 퍼피스쿨반려동물
# 34     48        박준애견유치원강아지훈련소애견훈련
# 35     49        한강펫케어센터 강동점반려동물호텔
# 36     50               코코퍼피반려동물미용
# 37     51               마이도그반려동물미용
# 38     52           땡일리 강아지유치원애견훈련
# 39     53             도니바니애견카페애견카페
# 40     54                포레스트독반려동물
# 41     59             제제네멍치원반려동물호텔
# 42     63             MM애견공방반려동물미용
# 43     64             펫도그 애견스쿨애견훈련
# 44     65                  힐링몽애견훈련
# 45     66             멍찌네하우스반려동물호텔
# 46     67              멍돌하우스반려동물호텔
# 47     68                 돌봄반려동물호텔
# 48     69             갓독애견호텔반려동물호텔
# 49     70  24개스트하우스 강남강아지유치원반려견놀이터
# 50     71        멍투게더 강아지유치원반려동물호텔
# 51     72         준애견훈련소강아지유치원애견훈련
# 52     73              강남강아지반려견놀이터
# 53     74                 해피퍼피애견훈련
# 54     75             스타일리다독반려동물미용
# 55     76            나나리펫하우스반려동물호텔
# 56     77               전설의강아지애견카페
# 57     78        야옹아멍멍해봐 양재점반려동물분양
# 58     79        하울팟 케어클럽 서초본점반려동물
# 59     80          프랑소와펫 서래점반려동물미용
# 60     81        하울팟 케어클럽 서초본점반려동물
# 61     82                유어마이독반려동물
# 62     83                디어몽반려동물미용
# 63     84                투퍼피반려동물호텔
# 63                    서울특별시 관악구 신림로 387 3층 투퍼피  37.488656  126.928064
# 64                      서울특별시 관악구 봉천로 283 대윤빌딩  37.487661  126.932624
# 65                           서울특별시 관악구 신림로 242  37.477920  126.934527
# 66                  서울특별시 영등포구 신길로 119 1층 121호  37.503510  126.909710
# 67                           서울특별시 영등포구 영중로 15  37.517233  126.903716
# 68                         서울특별시 양천구 중앙로36길 24  37.519555  126.856575
# 69                   서울특별시 강서구 마곡동로10길 46 406호  37.567012  126.839731

# %%
result = result.reset_index()

result=result.drop(["index"], axis=1, inplace=True)

# %%
result
# Out:
#                        name                                     address  \
# 0         월드컵공원반려견놀이터반려견놀이터                            서울특별시 마포구 증산로 32
# 1               카페700반려견놀이터                 서울특별시 강서구 곰달래로 104 3층 카페700
# 2              마이댕댕스쿨반려견놀이터            서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 3                까네지노반려견놀이터                        서울특별시 동대문구 전농로 43 1층
# 4             도그어스플래닛반려견놀이터                   서울특별시 동대문구 고산자로36길 3 경동시장
# 5      어린이대공원 반려견 놀이터반려견놀이터                           서울특별시 광진구 능동로 216
# 6         휘경2동 반려견놀이터반려견놀이터                        서울특별시 동대문구 휘경동 산6-26
# 7         초안산공공반려견놀이터반려견놀이터                       서울특별시 도봉구 해등로3길 48-11
# 8         당고개반려견임시놀이터반려견놀이터                        서울특별시 노원구 상계동 산158-1
# 9         스테이지28웁시데이지반려견놀이터                  서울특별시 강동구 아리수로61길 91-14 2층
# 10  24개스트하우스 강남강아지유치원반려견놀이터                  서울특별시 강남구 봉은사로20길 52 지하 1층
# 11          개러리아 삼성본점반려견놀이터                         서울특별시 강남구 선릉로122길 4
# 12              강남강아지반려견놀이터                      서울특별시 강남구 언주로79길 14 2층
# 13      보라매공원 반려견 놀이터반려견놀이터                 서울특별시 동작구 여의대방로20길 33 보라매공원
# 14               개좋은날반려견놀이터          서울특별시 영등포구 여의대방로 249 우주마루에어스포렉스 1층
# 15               멍마르뜨반려견놀이터                   서울특별시 강서구 양천로 132 2층 멍마르뜨
# 16                 워킹페코반려동물               서울특별시 마포구 서강로9길 59 3층, 핑크색 문❤
# 17              독핏 케어센터반려동물                    서울특별시 마포구 희우정로1길 25 지하1층
# 18            하울 애견 유치원애견훈련              서울특별시 강서구 곰달래로 227 2층.3층 하울유치원
# 19                도그하우스애견훈련            서울특별시 양천구 목동중앙서로 47 성보주상복합아파트 1층
# 20            키움반려견아카데미애견훈련                      서울특별시 양천구 은행정로 94 201호
# 21          이든반려견문화센터반려동물미용                           서울특별시 양천구 은행정로 94
# 22               강아지정류장애견카페                           서울특별시 강서구 양천로 709
# 23                 도기캠프애견훈련  서울특별시 용산구 백범로 313 롯데캐슬상가 B2층 203,204호 도기캠프
# 24             곁에 있을개반려동물미용                        서울특별시 강서구 화곡로66길 162
# 25             마이댕댕스쿨반려견놀이터            서울특별시 강서구 까치산로 75 호왕빌딩 7층 마이댕댕스쿨
# 26                꽃길만가개반려동물                       서울특별시 강서구 화곡로42가길 5-7
# 27     박준훈련사애견유치원강아지훈련소애견훈련                           서울특별시 중구 세종대로 136
# 38  37.504720  127.022474
# 39  37.518595  126.939630
# 40  37.557154  127.040105
# 41  37.547460  127.044776
# 42  37.545677  127.042915
# 43  37.539258  127.044672
# 44  37.559255  127.076549
# 45  37.561882  127.082686
# 46  37.523545  127.029806
# 47  37.525217  127.055506
# 48  37.559541  127.087860
# 49  37.513713  127.061909
# 50  37.513752  127.104447
# 51  37.544043  127.121281
# 52  37.618412  127.036476
# 53  37.606177  127.061522
# 54  37.618734  127.045028
# 55  37.656642  127.062991
# 56  37.670375  127.082133
# 57  37.546365  127.134702
# 58  37.505370  127.085268
# 59  37.483756  127.129979
# 60  37.489003  127.124458
# 61  37.495209  127.126523
# 62  37.488586  127.124152
# 63  37.510023  127.079529
# 64  37.480834  127.121277
# 65  37.503909  127.033359
# 66  37.493616  127.035481
# 67  37.500024  127.036509
# 68  37.499331  127.042877
# 69  37.515576  127.030675
# 70  37.504616  127.034044
# 71  37.476438  127.046310
# 72  37.512018  127.041166
# 73  37.479534  127.042570
# 74  37.544043  127.121281
# 75  37.496233  126.997134
# 76  37.479534  127.042570
# 77  37.488285  126.986714
# 78  37.481158  126.914208
# 79  37.488656  126.928064
# 80  37.487661  126.932624
# 81  37.477920  126.934527
# 82  37.503510  126.909710
# 83  37.517233  126.903716
# 84  37.519555  126.856575
# 85  37.567012  126.839731

# %%
# csv 저장
result.to_csv('./data/pet_sch_ground.csv')

# %%
################ 구글맵으로 다시!
gu_list = ['마포구','서대문구','은평구','종로구','중구','용산구','성동구','광진구',
           '동대문구','성북구','강북구','도봉구','노원구','중랑구','강동구','송파구',
           '강남구','서초구','관악구','동작구','영등포구','양천구','강서구']

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse
import re
from bs4 import BeautifulSoup
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys



def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"}) # Rest API
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 96d7359a39d27a12d4ccddf4bf82f85b"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long


results = []

for find in gu_list : 
    time.sleep(10)

    driver = webdriver.Chrome(
        executable_path= "chromedriver.exe"
    )
    url = "https://map.kakao.com/"
    driver.get(url)
    action = ActionChains(driver)
    search_area = driver.find_element_by_xpath('//*[@id="search.keyword.query"]') # 검색 창
    search_area.send_keys(find + ' 반려견유치원')  # 검색어 입력
    driver.find_element_by_xpath('//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    driver.implicitly_wait(3) # 기다려 주자
    more_page = driver.find_element_by_id("info.search.place.more")
    # more_page.click()
    more_page.send_keys(Keys.ENTER) # 더보기 누르고
    # 첫 번째 검색 페이지 끝
    # driver.implicitly_wait(5) # 기다려 주자
    time.sleep(1)

    # next 사용 가능?
    next_btn = driver.find_element_by_id("info.search.page.next")
    has_next = "disabled" not in next_btn.get_attribute("class").split(" ")
    Page = 1
    while True: # 다음 페이지가 있으면 loop
    # for i in range(2, 6): # 2, 3, 4, 5
        time.sleep(1)
        # place_lists = driver.find_elements_by_css_selector('#info\.search\.place\.list > li:nth-child(1)')
        # 페이지 루프
        #info\.search\.page\.no1 ~ .no5
        page_links = driver.find_elements_by_css_selector("#info\.search\.page a")
        pages = [link for link in page_links if "HIDDEN" not in link.get_attribute("class").split(" ")]
        print(len(pages), "개의 페이지 있음")
        # pages를 하나씩 클릭하면서
        for i in range(1, 6):
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            try:
                page = driver.find_element_by_xpath(xPath)
                page.send_keys(Keys.ENTER)
            except ElementNotInteractableException:
                print('End of Page')
                break;
            time.sleep(3)
            place_lists = driver.find_elements_by_css_selector('#info\.search\.place\.list > li')
            for p in place_lists: # WebElement
                # print(p.get_attribute('innerHTML'))
                # print("type of p:", type(p))
                store_html = p.get_attribute('innerHTML')
                store_info = BeautifulSoup(store_html, "html.parser")
                # BS -> 분석
                #
                place_name = store_info.select('.head_item > .tit_name > .link_name')
                
                if len(place_name) == 0:
                    continue # 광고
                name = store_info.select('.head_item > .tit_name > .link_name')[0].text
                address = store_info.select('.info_item > .addr > p')[0].text
                latitude = address_to_latitude(address)
                longtitude = address_to_longtitude(address)
                results.append((name, address, latitude, longtitude))

            print(i, ' of', ' [ ' , Page, ' ] ')
        next_btn = driver.find_element_by_id("info.search.page.next")
        has_next = "disabled" not in next_btn.get_attribute("class").split(" ")
        if not has_next:
            print('Arrow is Disabled')
            driver.close()
            break # 다음 페이지 없으니까 종료
        else: # 다음 페이지 있으면
            Page += 1
            next_btn.send_keys(Keys.ENTER)
    print("End of Crawl")

results
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-1-375204efaa09> in <module>
#      55     more_page = driver.find_element_by_id("info.search.place.more")
#      56     # more_page.click()
# ---> 57     more_page.send_keys(Keys.ENTER) # 더보기 누르고
#      58     # 첫 번째 검색 페이지 끝
#      59     # driver.implicitly_wait(5) # 기다려 주자
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     475                 value = self._upload(local_file)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#     479                        'value': keys_to_typing(value)})
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=94.0.4606.81)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 크롤링 할 경로 설정
url = 'https://www.google.com/search?tbs=lf:1,lf_ui:14&tbm=lcl&sxsrf=AOaemvKtwPs7trzpfSHdRdNKplxAyOiYYg:1634376490717&q=%EA%B0%95%EC%95%84%EC%A7%80%EC%9C%A0%EC%B9%98%EC%9B%90&rflfq=1&num=10&sa=X&ved=2ahUKEwjyv6Hxzs7zAhVTwosBHXTeC3EQjGp6BAgNEFY&biw=1745&bih=852&dpr=1.1#rlfi=hd:;si:;mv:[[37.6987495,127.0872961],[37.2332872,126.6132021]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!1m4!1u2!2m2!2m1!1e1!2m1!1e2!2m1!1e3!3sIAE,lf:1,lf_ui:14'

# %%
# BeautifulSoup 라이브러리를 이용하여 html 문서 가져오기
result = urlopen(url)
html = result.read()
soup = BeautifulSoup(html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-08ee59c7172d> in <module>
#       1 # BeautifulSoup 라이브러리를 이용하여 html 문서 가져오기
# ----> 2 result = urlopen(url)
#       3 html = result.read()
#       4 soup = BeautifulSoup(html, 'html.parser')
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden
